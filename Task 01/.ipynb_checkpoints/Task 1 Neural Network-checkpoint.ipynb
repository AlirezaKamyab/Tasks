# %% [markdown]
# # King County - Neural Network

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Normalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.regularizers import L2
import seaborn as sns
import time
from k_mean_cluster_util import k_mean_optimization, k_mean, random_initial_centroids

# %% [markdown]
# ## Getting data ready
# First We'll have some intuition on the data and set the "id" as index value. Also remove duplicate values.

# %%
df = pd.read_csv('./kc_house_data.csv')
df.set_index('id', inplace=True)
df = df[~df.index.duplicated(keep='first')]
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 5631500400              0      1933             0    98028  47.7379 -122.233
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 1954400510              0      1987             0    98074  47.6168 -122.045
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639
# 5631500400           2720        8062
# 2487200875           1360        5000
# 1954400510           1800        7503

# %% [markdown]
# From date which is an object, "str" in this dataset, we'll have to convert to date and take year and month which is important to our model.

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df = df.drop('date', axis=1)
prices = df['price']
df = df.drop('price', axis=1)
df['price'] = prices
df.head()
# Out:
#             bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# id
# 7129300520         3       1.00         1180      5650     1.0           0
# 6414100192         3       2.25         2570      7242     2.0           0
# 5631500400         2       1.00          770     10000     1.0           0
# 2487200875         4       3.00         1960      5000     1.0           0
# 1954400510         3       2.00         1680      8080     1.0           0
#
#             view  condition  grade  sqft_above  ...  yr_built  yr_renovated  \
# id                                              ...
# 7129300520     0          3      7        1180  ...      1955             0
# 6414100192     0          3      7        2170  ...      1951          1991
# 5631500400     0          3      6         770  ...      1933             0
# 2487200875     0          5      7        1050  ...      1965             0
# 1954400510     0          3      8        1680  ...      1987             0
#
#             zipcode      lat     long  sqft_living15  sqft_lot15  year  month  \
# id
# 7129300520    98178  47.5112 -122.257           1340        5650  2014     10
# 6414100192    98125  47.7210 -122.319           1690        7639  2014     12
# 5631500400    98028  47.7379 -122.233           2720        8062  2015      2
# 2487200875    98136  47.5208 -122.393           1360        5000  2014     12
# 1954400510    98074  47.6168 -122.045           1800        7503  2015      2
#
#                price
# id
# 7129300520  221900.0
# 6414100192  538000.0
# 5631500400  180000.0
# 2487200875  604000.0
# 1954400510  510000.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Have an intuition on what columns contain null values and what their Dtypes are

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21436 entries, 7129300520 to 1523300157
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       21436 non-null  int64
#  1   bathrooms      21436 non-null  float64
#  2   sqft_living    21436 non-null  int64
#  3   sqft_lot       21436 non-null  int64
#  4   floors         21436 non-null  float64
#  5   waterfront     21436 non-null  int64
#  6   view           21436 non-null  int64
#  7   condition      21436 non-null  int64
#  8   grade          21436 non-null  int64
#  9   sqft_above     21436 non-null  int64
#  10  sqft_basement  21436 non-null  int64
#  11  yr_built       21436 non-null  int64
#  12  yr_renovated   21436 non-null  int64
#  13  zipcode        21436 non-null  int64
#  14  lat            21436 non-null  float64
#  15  long           21436 non-null  float64
#  16  sqft_living15  21436 non-null  int64
#  17  sqft_lot15     21436 non-null  int64
#  18  year           21436 non-null  int64
#  19  month          21436 non-null  int64
#  20  price          21436 non-null  float64
# dtypes: float64(5), int64(16)
# memory usage: 3.6 MB

# %%
df.describe().T
# Out:
#                  count           mean            std         min          25%  \
# bedrooms       21436.0       3.371571       0.929205      0.0000       3.0000
# bathrooms      21436.0       2.117349       0.769913      0.0000       1.7500
# sqft_living    21436.0    2082.704936     919.146469    290.0000    1430.0000
# sqft_lot       21436.0   15135.637852   41538.620606    520.0000    5040.0000
# floors         21436.0       1.496198       0.540388      1.0000       1.0000
# waterfront     21436.0       0.007604       0.086871      0.0000       0.0000
# view           21436.0       0.235118       0.767092      0.0000       0.0000
# condition      21436.0       3.410384       0.650235      1.0000       3.0000
# grade          21436.0       7.661737       1.174256      1.0000       7.0000
# sqft_above     21436.0    1790.960440     829.026491    290.0000    1200.0000
# sqft_basement  21436.0     291.744495     442.781983      0.0000       0.0000
# yr_built       21436.0    1971.098433      29.385277   1900.0000    1952.0000
# yr_renovated   21436.0      84.729800     402.431012      0.0000       0.0000
# zipcode        21436.0   98077.862288      53.469371  98001.0000   98033.0000
# lat            21436.0      47.560156       0.138601     47.1559      47.4711
# long           21436.0    -122.213697       0.140896   -122.5190    -122.3280
# sqft_living15  21436.0    1988.314378     685.699093    399.0000    1490.0000
# sqft_lot15     21436.0   12785.961280   27375.467469    651.0000    5100.0000
# year           21436.0    2014.318949       0.466080   2014.0000    2014.0000
# month          21436.0       6.590782       3.108176      1.0000       4.0000
# price          21436.0  540529.287180  367689.296471  75000.0000  322150.0000
#
#                       50%         75%           max
# bedrooms            3.000       4.000  3.300000e+01
# bathrooms           2.250       2.500  8.000000e+00
# sqft_living      1920.000    2550.000  1.354000e+04
# sqft_lot         7614.000   10696.250  1.651359e+06
# floors              1.500       2.000  3.500000e+00
# waterfront          0.000       0.000  1.000000e+00
# view                0.000       0.000  4.000000e+00
# condition           3.000       4.000  5.000000e+00
# grade               7.000       8.000  1.300000e+01
# sqft_above       1560.000    2220.000  9.410000e+03
# sqft_basement       0.000     560.000  4.820000e+03
# yr_built         1975.000    1997.000  2.015000e+03
# yr_renovated        0.000       0.000  2.015000e+03
# zipcode         98065.000   98117.000  9.819900e+04
# lat                47.572      47.678  4.777760e+01
# long             -122.230    -122.124 -1.213150e+02
# sqft_living15    1840.000    2370.000  6.210000e+03
# sqft_lot15       7620.000   10087.250  8.712000e+05
# year             2014.000    2015.000  2.015000e+03
# month               6.000       9.000  1.200000e+01
# price          450000.000  645000.000  7.700000e+06

# %%
(df == 0).sum()
# Out:
# bedrooms            13
# bathrooms           10
# sqft_living          0
# sqft_lot             0
# floors               0
# waterfront       21273
# view             19320
# condition            0
# grade                0
# sqft_above           0
# sqft_basement    13015
# yr_built             0
# yr_renovated     20526
# zipcode              0
# lat                  0
# long                 0
# sqft_living15        0
# sqft_lot15           0
# year                 0
# month                0
# price                0
# dtype: int64

# %% [markdown]
# Correlation of two values gives a great insight on what features impact the values of each other

# %%
df.corr()
# Out:
#                bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# bedrooms       1.000000   0.516772     0.577512  0.031719  0.175207
# bathrooms      0.516772   1.000000     0.754422  0.087143  0.499863
# sqft_living    0.577512   0.754422     1.000000  0.171957  0.352867
# sqft_lot       0.031719   0.087143     0.171957  1.000000 -0.005950
# floors         0.175207   0.499863     0.352867 -0.005950  1.000000
# waterfront    -0.006685   0.063734     0.103902  0.021571  0.023473
# view           0.079542   0.186684     0.283753  0.075012  0.028211
# condition      0.027896  -0.127839    -0.060973 -0.009298 -0.266543
# grade          0.358396   0.664727     0.762402  0.112541  0.457475
# sqft_above     0.478441   0.684994     0.876683  0.182581  0.522648
# sqft_basement  0.303035   0.283539     0.434419  0.015107 -0.246066
# yr_built       0.153745   0.505092     0.316544  0.052447  0.489062
# yr_renovated   0.018435   0.051101     0.055084  0.007636  0.005626
# zipcode       -0.153621  -0.202958    -0.198621 -0.129411 -0.058108
# lat           -0.010228   0.023444     0.051118 -0.085992  0.049279
# long           0.129836   0.221935     0.239214  0.229555  0.124285
# sqft_living15  0.393161   0.568194     0.756205  0.143650  0.278854
# sqft_lot15     0.029117   0.086627     0.182775  0.718097 -0.011917
# year          -0.010065  -0.023215    -0.025818  0.005981 -0.018709
# month         -0.000413   0.005427     0.010058 -0.002557  0.011864
# price          0.309007   0.525453     0.701993  0.088895  0.256278
#
#                waterfront      view  condition     grade  sqft_above  ...  \
# bedrooms        -0.006685  0.079542   0.027896  0.358396    0.478441  ...
# bathrooms        0.063734  0.186684  -0.127839  0.664727    0.684994  ...
# sqft_living      0.103902  0.283753  -0.060973  0.762402    0.876683  ...
# sqft_lot         0.021571  0.075012  -0.009298  0.112541    0.182581  ...
# floors           0.023473  0.028211  -0.266543  0.457475    0.522648  ...
# waterfront       1.000000  0.403025   0.016607  0.082841    0.072021  ...
# view             0.403025  1.000000   0.045051  0.249890    0.166930  ...
# condition        0.016607  0.045051   1.000000 -0.148248   -0.160782  ...
# grade            0.082841  0.249890  -0.148248  1.000000    0.756068  ...
# sqft_above       0.072021  0.166930  -0.160782  0.756068    1.000000  ...
# sqft_basement    0.080838  0.276482   0.174463  0.167032   -0.052456  ...
# yr_built        -0.026537 -0.055153  -0.364947  0.445329    0.422838  ...
# yr_renovated     0.093025  0.103633  -0.061136  0.014357    0.022666  ...
# zipcode          0.030558  0.087096   0.004509 -0.182675   -0.260420  ...
# lat             -0.014395  0.005671  -0.015402  0.113332   -0.001652  ...
# long            -0.042188 -0.079720  -0.107780  0.196572    0.343115  ...
# sqft_living15    0.086558  0.279077  -0.095002  0.712507    0.731992  ...
# sqft_lot15       0.030694  0.072867  -0.003731  0.118313    0.193413  ...
# year            -0.003444  0.003066  -0.044611 -0.025513   -0.020437  ...
# month            0.007724 -0.006918   0.021396  0.005161    0.007820  ...
# price            0.266961  0.396933   0.035089  0.667496    0.605495  ...
#
#                yr_built  yr_renovated   zipcode       lat      long  \
# bedrooms       0.153745      0.018435 -0.153621 -0.010228  0.129836
# bathrooms      0.505092      0.051101 -0.202958  0.023444  0.221935
# sqft_living    0.316544      0.055084 -0.198621  0.051118  0.239214
# sqft_lot       0.052447      0.007636 -0.129411 -0.085992  0.229555
# floors         0.489062      0.005626 -0.058108  0.049279  0.124285
# waterfront    -0.026537      0.093025  0.030558 -0.014395 -0.042188
# view          -0.055153      0.103633  0.087096  0.005671 -0.079720
# condition     -0.364947     -0.061136  0.004509 -0.015402 -0.107780
# grade          0.445329      0.014357 -0.182675  0.113332  0.196572
# sqft_above     0.422838      0.022666 -0.260420 -0.001652  0.343115
# sqft_basement -0.134590      0.071909  0.075283  0.109208 -0.145846
# yr_built       1.000000     -0.225697 -0.345819 -0.148606  0.408531
# yr_renovated  -0.225697      1.000000  0.064347  0.029206 -0.068736
# zipcode       -0.345819      0.064347  1.000000  0.267020 -0.564588
# lat           -0.148606      0.029206  0.267020  1.000000 -0.136369
# long           0.408531     -0.068736 -0.564588 -0.136369  1.000000
# sqft_living15  0.324568     -0.002677 -0.278160  0.047668  0.333652
# sqft_lot15     0.070307      0.007870 -0.146991 -0.086505  0.254280
# year           0.007719     -0.022968 -0.001229 -0.028499  0.002119
# month         -0.009216      0.012444  0.001956  0.014594 -0.009681
# price          0.052967      0.127002 -0.052171  0.306057  0.020571
#
#                sqft_living15  sqft_lot15      year     month     price
# bedrooms            0.393161    0.029117 -0.010065 -0.000413  0.309007
# bathrooms           0.568194    0.086627 -0.023215  0.005427  0.525453
# sqft_living         0.756205    0.182775 -0.025818  0.010058  0.701993
# sqft_lot            0.143650    0.718097  0.005981 -0.002557  0.088895
# floors              0.278854   -0.011917 -0.018709  0.011864  0.256278
# waterfront          0.086558    0.030694 -0.003444  0.007724  0.266961
# view                0.279077    0.072867  0.003066 -0.006918  0.396933
# condition          -0.095002   -0.003731 -0.044611  0.021396  0.035089
# grade               0.712507    0.118313 -0.025513  0.005161  0.667496
# sqft_above          0.731992    0.193413 -0.020437  0.007820  0.605495
# sqft_basement       0.199247    0.017283 -0.015328  0.006239  0.323552
# yr_built            0.324568    0.070307  0.007719 -0.009216  0.052967
# yr_renovated       -0.002677    0.007870 -0.022968  0.012444  0.127002
# zipcode            -0.278160   -0.146991 -0.001229  0.001956 -0.052171
# lat                 0.047668   -0.086505 -0.028499  0.014594  0.306057
# long                0.333652    0.254280  0.002119 -0.009681  0.020571
# sqft_living15       1.000000    0.182441 -0.018751  0.000374  0.584688
# sqft_lot15          0.182441    1.000000  0.000349  0.003426  0.082038
# year               -0.018751    0.000349  1.000000 -0.780760  0.004800
# month               0.000374    0.003426 -0.780760  1.000000 -0.010684
# price               0.584688    0.082038  0.004800 -0.010684  1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(df.corr(), cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='price', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
sns.boxplot(data=df, x='price', ax=ax)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='sqft_living', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='sqft_living15', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.scatterplot(data=df, x='sqft_living', y='price', ax=ax[0], alpha=0.3, color='red')
sns.scatterplot(data=df, x='sqft_living15', y='price', ax=ax[1], alpha=0.3, color='green')
# Out:
# <AxesSubplot:xlabel='sqft_living15', ylabel='price'>

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(data=df, x='long', y='lat', hue='price', palette='rocket_r',);

# %% [markdown]
# ### Should we remove outliers?
# For housing prices, a house could have been sold for a value less than what it worths. Or the house could've been sold more than what it worths. According to the red graph, some house with 13.5k sqft_living has been sold for about 2m dollars but some other house with about 12k sqft_living has been sold for about 7.5m dollars. This case could be seen as an outlier but there are other factors that have impact on the price.

# %%
df[df['sqft_living'] > 12000].T
# Out:
# id               6762700020    1225069038
# bedrooms       6.000000e+00  7.000000e+00
# bathrooms      8.000000e+00  8.000000e+00
# sqft_living    1.205000e+04  1.354000e+04
# sqft_lot       2.760000e+04  3.077520e+05
# floors         2.500000e+00  3.000000e+00
# waterfront     0.000000e+00  0.000000e+00
# view           3.000000e+00  4.000000e+00
# condition      4.000000e+00  3.000000e+00
# grade          1.300000e+01  1.200000e+01
# sqft_above     8.570000e+03  9.410000e+03
# sqft_basement  3.480000e+03  4.130000e+03
# yr_built       1.910000e+03  1.999000e+03
# yr_renovated   1.987000e+03  0.000000e+00
# zipcode        9.810200e+04  9.805300e+04
# lat            4.762980e+01  4.766750e+01
# long          -1.223230e+02 -1.219860e+02
# sqft_living15  3.940000e+03  4.850000e+03
# sqft_lot15     8.800000e+03  2.178000e+05
# year           2.014000e+03  2.014000e+03
# month          1.000000e+01  5.000000e+00
# price          7.700000e+06  2.280000e+06

# %% [markdown]
# Two houses are somewhat the same and in the same area according to their lat and long. <br>
# - More expensive one is older than the new one
# - More expensive one's grade is greater than the other by 1 values
# - sqft_lot15 is very large compared to the other one
# - In 1987, the expensive house has been renovated but the other one hasn't been renovated
# <br>
# Other than these, the other house is better in every aspect. So why it is less expensive or not at all expensive? <br>
# I'd say the first one is expensive because it is near the lake.

# %%
def remove_outliers(df, columns='all'):
    columns = df.columns if columns == 'all' else columns
    for c in columns:
        df = remove_columns_outlier(df, c)
    return df

def remove_columns_outlier(df, column):
    column = df[column]
    column_norm = (column - np.mean(column)) / np.std(column)
    column_norm = column_norm[~((column_norm >= 3) | (column_norm <= -3))]
    return df.loc[df.index[df.index.value_counts() == 1]]

def remove_outliers_per(df, column, per_column):
    fraction = column / per_column
    frac_norm = (fraction - np.mean(fraction)) / np.std(fraction)
    frac_norm = frac_norm[~((frac_norm >= 3) | (frac_norm <= -3))]
    return df.loc[list(frac_norm.index)]

def percentage_from_right(df, column, from_value):
    per = df[df[column] > from_value].size / df.size
    per = per * 100
    return per

def percentage_from_left(df, column, from_value):
    per = df[df[column] < from_value].size / df.size
    per = per * 100
    return per
    
def drop_tail_right(df, column, from_value, max_percentage=5, verbos=True):
    per = percentage_from_right(df, column, from_value)
    if per > max_percentage: raise ValueError(f'Percentage ({per:.2f}%) greater than {max_percentage:.2f}%')
    if verbos: print(f'dropping {per:.2f}% data')
    return df[df[column] < from_value]

def drop_tail_left(df, column, from_value, max_percentage=5, verbos=True):
    per = percentage_from_left(df, column, from_value)
    if per > max_percentage: raise ValueError(f'Percentage ({per:.2f}%) greater than {max_percentage:.2f}%')
    if verbos: print(f'dropping {per:.2f}% data')
    return df[df[column] > from_value]


def remove_outliers_IQR(df, column, verbos=True):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    IQR = q3 - q1
    res = drop_tail_right(df, column, q3 + 1.5 * IQR, 100, False)
    res = drop_tail_left(res, column, q1 - 1.5 * IQR, 100, False)
    per = percentage_from_right(df, column, q3 + 1.5 * IQR) + percentage_from_left(df, column, q1 - 1.5 * IQR)
    if verbos: print(f'dropping {per:.2f}% data')
    return res

# %%
#df = remove_outliers(df, ['price'])
#df = remove_outliers_per(df, df['price'], df['sqft_living'])
#df = remove_outliers_per(df, df['price'], df['sqft_above'])
#df = remove_outliers_per(df, df['price'], df['sqft_living15'])

#df = drop_tail_right(df, 'price', 969000, 8)
#df = drop_tail_right(df, 'sqft_living', 3850, 3)
#df = drop_tail_right(df, 'sqft_living15', 3500, 3)
#df = drop_tail_left(df, 'grade', 5, 5)
#df = drop_tail_right(df, 'grade', 11, 5)

df = remove_outliers_IQR(df, 'price')
#df = remove_outliers_IQR(df, 'sqft_living')
df = df.drop('sqft_above', axis=1)
# Out:
# dropping 5.31% data

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='price', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='sqft_living', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='sqft_living15', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.scatterplot(data=df, x='sqft_living', y='price', ax=ax[0], alpha=0.3, color='red')
sns.scatterplot(data=df, x='sqft_living15', y='price', ax=ax[1], alpha=0.3, color='green')
# Out:
# <AxesSubplot:xlabel='sqft_living15', ylabel='price'>

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(data=df, x='long', y='lat', hue='price', palette='rocket_r',);

# %% [markdown]
# As it seems some regions here, have expensive houses, So we'll try to cluster each region.<br>
# We'll use "lat" and "long" and "price" to cluster each using K_mean clustering algorithm.

# %%
selected = df[['lat', 'long', 'price']]
ids = selected.index.values
selected = selected.values
selected.shape
# Out:
# (20297, 3)

# %%
centeroids, idx = k_mean_optimization(selected, 10, 30, 50)
# Out:
# Iteration 1/50
# Distortion: 707310668.7708312
# Iteration 2/50
# Distortion: 810350044.6137305
# Iteration 3/50
# Distortion: 701793526.0552312
# Iteration 4/50
# Distortion: 696126975.4212805
# Iteration 5/50
# Distortion: 709215471.3737988
# Iteration 6/50
# Distortion: 692476457.817591
# Iteration 7/50
# Distortion: 694442247.7172449
# Iteration 8/50
# Distortion: 791387605.0446197
# Iteration 9/50
# Distortion: 716438408.1521646
# Iteration 10/50
# Distortion: 745613070.0222051
# Iteration 11/50
# Distortion: 748003573.7390859
# Iteration 12/50
# Distortion: 783713905.2493602
# Iteration 13/50
# Distortion: 713885159.4115958
# Iteration 14/50
# Distortion: 769205711.0918163
# Iteration 15/50
# Distortion: 695823874.9965652
# Iteration 16/50
# Distortion: 696839588.6763926
# Iteration 17/50
# Distortion: 701790802.03629
# Iteration 18/50
# Distortion: 817692427.2051225
# Iteration 19/50
# Distortion: 694575371.7594604
# Iteration 20/50
# Distortion: 701788784.4559438
# Iteration 21/50
# Distortion: 701401526.7628156
# Iteration 22/50
# Distortion: 707555682.8317287
# Iteration 23/50
# Distortion: 886301746.5762907
# Iteration 24/50
# Distortion: 698330127.4130217
# Iteration 25/50
# Distortion: 696839588.6763926
# Iteration 26/50
# Distortion: 721517082.2073119
# Iteration 27/50
# Distortion: 728771022.3507862
# Iteration 28/50
# Distortion: 717553048.9233866
# Iteration 29/50
# Distortion: 752312124.5265415
# Iteration 30/50
# Distortion: 744722372.1721027
# Iteration 31/50
# Distortion: 732833827.7658001
# Iteration 32/50
# Distortion: 767811829.4873985
# Iteration 33/50
# Distortion: 696410630.6721027
# Iteration 34/50
# Distortion: 760159399.5087811
# Iteration 35/50
# Distortion: 757691800.089525
# Iteration 36/50
# Distortion: 788035028.5785488
# Iteration 37/50
# Distortion: 691696541.3829736
# Iteration 38/50
# Distortion: 692415594.8806227
# Iteration 39/50
# Distortion: 814482665.5036701
# Iteration 40/50
# Distortion: 771797129.4762281
# Iteration 41/50
# Distortion: 696839588.6763926
# Iteration 42/50
# Distortion: 719212892.3815938
# Iteration 43/50
# Distortion: 720576616.7909367
# Iteration 44/50
# Distortion: 715697206.8010422
# Iteration 45/50
# Distortion: 812850564.8105174
# Iteration 46/50
# Distortion: 797345890.512295
# Iteration 47/50
# Distortion: 691257138.8464516
# Iteration 48/50
# Distortion: 693707988.0861796
# Iteration 49/50
# Distortion: 788380424.7222438
# Iteration 50/50
# Distortion: 699256924.7120914
#
# Distortion 691257138.8464516 is chosen!

# %%
selected = np.c_[ids, selected, idx]
selected = pd.DataFrame(selected, columns=['id', 'lat', 'long', 'price', 'cluster'])
selected
# Out:
#                  id      lat     long     price  cluster
# 0      7.129301e+09  47.5112 -122.257  221900.0      4.0
# 1      6.414100e+09  47.7210 -122.319  538000.0      0.0
# 2      5.631500e+09  47.7379 -122.233  180000.0      4.0
# 3      2.487201e+09  47.5208 -122.393  604000.0      0.0
# 4      1.954401e+09  47.6168 -122.045  510000.0      2.0
# ...             ...      ...      ...       ...      ...
# 20292  2.630000e+08  47.6993 -122.346  360000.0      8.0
# 20293  6.600060e+09  47.5107 -122.362  400000.0      1.0
# 20294  1.523300e+09  47.5944 -122.299  402101.0      1.0
# 20295  2.913101e+08  47.5345 -122.069  400000.0      1.0
# 20296  1.523300e+09  47.5941 -122.299  325000.0      8.0
#
# [20297 rows x 5 columns]

# %%
selected.set_index('id', inplace=True)
selected
# Out:
#                   lat     long     price  cluster
# id
# 7.129301e+09  47.5112 -122.257  221900.0      4.0
# 6.414100e+09  47.7210 -122.319  538000.0      0.0
# 5.631500e+09  47.7379 -122.233  180000.0      4.0
# 2.487201e+09  47.5208 -122.393  604000.0      0.0
# 1.954401e+09  47.6168 -122.045  510000.0      2.0
# ...               ...      ...       ...      ...
# 2.630000e+08  47.6993 -122.346  360000.0      8.0
# 6.600060e+09  47.5107 -122.362  400000.0      1.0
# 1.523300e+09  47.5944 -122.299  402101.0      1.0
# 2.913101e+08  47.5345 -122.069  400000.0      1.0
# 1.523300e+09  47.5941 -122.299  325000.0      8.0
#
# [20297 rows x 4 columns]

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(data=selected, x='long', y='lat', hue='cluster', palette='tab10', size='price');

# %%
clusters = pd.get_dummies(data=selected.cluster, drop_first=True, prefix='cluster')
df = pd.concat([df, clusters], axis=1)

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), cmap='Blues');

# %%
df.describe().T
# Out:
#                  count           mean            std         min          25%  \
# bedrooms       20297.0       3.330246       0.911846      0.0000       3.0000
# bathrooms      20297.0       2.054084       0.711399      0.0000       1.5000
# sqft_living    20297.0    1978.235158     775.491728    290.0000    1400.0000
# sqft_lot       20297.0   14646.335173   40247.208902    520.0000    5000.0000
# floors         20297.0       1.477854       0.537484      1.0000       1.0000
# waterfront     20297.0       0.003005       0.054740      0.0000       0.0000
# view           20297.0       0.173622       0.642417      0.0000       0.0000
# condition      20297.0       3.407499       0.646790      1.0000       3.0000
# grade          20297.0       7.535498       1.038258      1.0000       7.0000
# sqft_basement  20297.0     267.498596     409.367450      0.0000       0.0000
# yr_built       20297.0    1970.910874      29.168739   1900.0000    1952.0000
# yr_renovated   20297.0      74.916539     379.343170      0.0000       0.0000
# zipcode        20297.0   98078.456373      53.304558  98001.0000   98033.0000
# lat            20297.0      47.556983       0.141081     47.1559      47.4604
# long           20297.0    -122.213026       0.142481   -122.5190    -122.3300
# sqft_living15  20297.0    1924.116126     615.531752    399.0000    1470.0000
# sqft_lot15     20297.0   12466.256590   26609.851181    651.0000    5040.0000
# year           20297.0    2014.318520       0.465914   2014.0000    2014.0000
# month          20297.0       6.595359       3.110196      1.0000       4.0000
# price          20297.0  477262.096369  208498.449648  75000.0000  315000.0000
# cluster_1.0    20297.0       0.148051       0.355160      0.0000       0.0000
# cluster_2.0    20297.0       0.113810       0.317588      0.0000       0.0000
# cluster_3.0    20297.0       0.050697       0.219384      0.0000       0.0000
# cluster_4.0    20297.0       0.089422       0.285359      0.0000       0.0000
# cluster_5.0    20297.0       0.069961       0.255088      0.0000       0.0000
# cluster_6.0    20297.0       0.031630       0.175018      0.0000       0.0000
# cluster_7.0    20297.0       0.152929       0.359928      0.0000       0.0000
# cluster_8.0    20297.0       0.157265       0.364059      0.0000       0.0000
# cluster_9.0    20297.0       0.083017       0.275915      0.0000       0.0000
#
#                        50%          75%           max
# bedrooms            3.0000       4.0000  3.300000e+01
# bathrooms           2.0000       2.5000  7.500000e+00
# sqft_living      1860.0000    2440.0000  7.480000e+03
# sqft_lot         7500.0000   10321.0000  1.651359e+06
# floors              1.0000       2.0000  3.500000e+00
# waterfront          0.0000       0.0000  1.000000e+00
# view                0.0000       0.0000  4.000000e+00
# condition           3.0000       4.0000  5.000000e+00
# grade               7.0000       8.0000  1.200000e+01
# sqft_basement       0.0000     510.0000  2.720000e+03
# yr_built         1975.0000    1996.0000  2.015000e+03
# yr_renovated        0.0000       0.0000  2.015000e+03
# zipcode         98065.0000   98118.0000  9.819900e+04
# lat                47.5671      47.6798  4.777760e+01
# long             -122.2310    -122.1220 -1.213150e+02
# sqft_living15    1800.0000    2280.0000  5.380000e+03
# sqft_lot15       7539.0000    9891.0000  8.712000e+05
# year             2014.0000    2015.0000  2.015000e+03
# month               6.0000       9.0000  1.200000e+01
# price          437850.0000  601000.0000  1.127500e+06
# cluster_1.0         0.0000       0.0000  1.000000e+00
# cluster_2.0         0.0000       0.0000  1.000000e+00
# cluster_3.0         0.0000       0.0000  1.000000e+00
# cluster_4.0         0.0000       0.0000  1.000000e+00
# cluster_5.0         0.0000       0.0000  1.000000e+00
# cluster_6.0         0.0000       0.0000  1.000000e+00
# cluster_7.0         0.0000       0.0000  1.000000e+00
# cluster_8.0         0.0000       0.0000  1.000000e+00
# cluster_9.0         0.0000       0.0000  1.000000e+00

# %% [markdown]
# ## Getting Data ready for trainning

# %%
X_train = df.drop(['price'], axis=1).values
y_train = df['price'].values

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.8, random_state=123)
X_test, X_cv, y_test, y_cv = train_test_split(X_test, y_test, test_size=0.5, random_state=10)

# %%
print(f'X_train shape is {X_train.shape} and y_train shape is {y_train.shape}')
print(f'y_cv shape is {X_cv.shape} and y_cv shape is {y_cv.shape}')
print(f'X_test shape is {X_test.shape} and y_test shape is {y_test.shape}')
# Out:
# X_train shape is (16237, 28) and y_train shape is (16237,)
# y_cv shape is (2030, 28) and y_cv shape is (2030,)
# X_test shape is (2030, 28) and y_test shape is (2030,)

# %% [markdown]
# ### Normalize the data

# %%
norm = Normalization()
norm.adapt(X_train)
Xn_train = norm(X_train)
Xn_cv = norm(X_cv)
Xn_test = norm(X_test)

# %% [markdown]
# ## Training

# %%
regs = [0, 0.1, 1, 10, 100, 1e3, 1e4, 1e5, 1e6, 1e7]
hist = []
for reg in regs:
    print(f'applying regularization parameter {reg}')
    s = time.time() # calculating duration
    model = Sequential([
        tf.keras.Input(shape=(Xn_train.shape[1],)),
        Dense(units=200, activation='relu', name='layer1', kernel_regularizer=L2(reg)),
        Dense(units=100, activation='relu', name='layer2', kernel_regularizer=L2(reg)),
        Dense(units=50, activation='relu', name='layer3', kernel_regularizer=L2(reg)),
        Dense(units=1, activation='linear', name='output')
    ], name='My_Model')

    model.compile(
        loss=MeanSquaredError(),
        optimizer=Adam(learning_rate=0.05),
        metrics=[tf.keras.metrics.MeanAbsoluteError()]
    )

    model.fit(Xn_train, y_train, validation_data=[Xn_cv, y_cv], epochs=200, verbose=False)
    hist.append([
        model.evaluate(Xn_train, y_train),
        model.evaluate(Xn_cv, y_cv), 
        model.evaluate(Xn_test, y_test)
    ])
    e = time.time() # calculating duration
    print(f'duration ~ {e - s : 0.2f}')
# Out:
# applying regularization parameter 0
# 508/508 [==============================] - 0s 677us/step - loss: 487838304.0000 - mean_absolute_error: 17370.6484
# 64/64 [==============================] - 0s 681us/step - loss: 767139072.0000 - mean_absolute_error: 21505.5762
# 64/64 [==============================] - 0s 665us/step - loss: 768233216.0000 - mean_absolute_error: 21534.5742
# duration ~  85.26
# applying regularization parameter 0.1
# 508/508 [==============================] - 0s 657us/step - loss: 512989760.0000 - mean_absolute_error: 18119.7812
# 64/64 [==============================] - 0s 665us/step - loss: 873398848.0000 - mean_absolute_error: 23184.3770
# 64/64 [==============================] - 0s 681us/step - loss: 847939072.0000 - mean_absolute_error: 22762.0879
# duration ~  86.32
# applying regularization parameter 1
# 508/508 [==============================] - 0s 651us/step - loss: 574732544.0000 - mean_absolute_error: 19078.0078
# 64/64 [==============================] - 0s 649us/step - loss: 829588096.0000 - mean_absolute_error: 22544.1836
# 64/64 [==============================] - 0s 649us/step - loss: 807167232.0000 - mean_absolute_error: 22190.6387
# duration ~  86.64
# applying regularization parameter 10
# 508/508 [==============================] - 0s 643us/step - loss: 585599744.0000 - mean_absolute_error: 19168.6309
# 64/64 [==============================] - 0s 649us/step - loss: 845603840.0000 - mean_absolute_error: 22656.9629
# 64/64 [==============================] - 0s 665us/step - loss: 792454784.0000 - mean_absolute_error: 22060.1387
# duration ~  85.83
# applying regularization parameter 100
# 508/508 [==============================] - 0s 645us/step - loss: 593703040.0000 - mean_absolute_error: 19321.7207
# 64/64 [==============================] - 0s 665us/step - loss: 740568704.0000 - mean_absolute_error: 21230.0312
# 64/64 [==============================] - 0s 649us/step - loss: 713870336.0000 - mean_absolute_error: 20999.3145
# duration ~  86.74
# applying regularization parameter 1000.0
# 508/508 [==============================] - 0s 647us/step - loss: 681692864.0000 - mean_absolute_error: 20500.5957
# 64/64 [==============================] - 0s 649us/step - loss: 727399104.0000 - mean_absolute_error: 21287.0098
# 64/64 [==============================] - 0s 649us/step - loss: 729734272.0000 - mean_absolute_error: 21141.7441
# duration ~  86.07
# applying regularization parameter 10000.0
# 508/508 [==============================] - 0s 649us/step - loss: 692299200.0000 - mean_absolute_error: 20774.5527
# 64/64 [==============================] - 0s 665us/step - loss: 699529600.0000 - mean_absolute_error: 21040.6562
# 64/64 [==============================] - 0s 665us/step - loss: 674800064.0000 - mean_absolute_error: 20605.0332
# duration ~  86.24
# applying regularization parameter 100000.0
# 508/508 [==============================] - 0s 655us/step - loss: 847059264.0000 - mean_absolute_error: 22216.6270
# 64/64 [==============================] - 0s 665us/step - loss: 826325632.0000 - mean_absolute_error: 22072.8164
# 64/64 [==============================] - 0s 681us/step - loss: 824666368.0000 - mean_absolute_error: 21926.1895
# duration ~  86.71
# applying regularization parameter 1000000.0
# 508/508 [==============================] - 0s 651us/step - loss: 1002196032.0000 - mean_absolute_error: 22560.6426
# 64/64 [==============================] - 0s 649us/step - loss: 992843136.0000 - mean_absolute_error: 22397.4277
# 64/64 [==============================] - 0s 649us/step - loss: 1002917696.0000 - mean_absolute_error: 22624.6992
# duration ~  86.70
# applying regularization parameter 10000000.0
# 508/508 [==============================] - 0s 661us/step - loss: 1581556736.0000 - mean_absolute_error: 23022.6484
# 64/64 [==============================] - 0s 665us/step - loss: 1567726720.0000 - mean_absolute_error: 23156.5215
# 64/64 [==============================] - 0s 665us/step - loss: 1565999488.0000 - mean_absolute_error: 22738.2930
# duration ~  86.20

# %%
hist = np.array(hist)
hist_loss = hist[:, :, 0]
hist_mae = hist[:, :, 1]

m, n = hist_loss.shape

plt.figure(figsize=(12, 10))
plt.plot(range(m), hist_mae[:, 0], label='Train')
plt.plot(range(m), hist_mae[:, 1], label='CV')
#plt.plot(range(m), hist_mae[:, 2], label='Test')
plt.axvline(x=6, marker="_", c='r', label='Best regularization parameter', alpha=0.5)
plt.title('MAE per Regularization parameter');
plt.xlabel('Regularization parameter index');
plt.ylabel('MAE');
ax = plt.gca()
ax.set_xticks(range(10))
ax.set_xticklabels([0, 0.1, 1, 10, 100, 1e3, 1e4, 1e5, 1e6, 1e7])
plt.legend();

# %%
reg = 10000
model = Sequential([
    tf.keras.Input(shape=(Xn_train.shape[1],)),
    Dense(units=200, activation='relu', name='layer1', kernel_regularizer=L2(reg)),
    Dense(units=100, activation='relu', name='layer2', kernel_regularizer=L2(reg)),
    Dense(units=50, activation='relu', name='layer3', kernel_regularizer=L2(reg)),
    Dense(units=1, activation='linear', name='output')
], name='My_Model')

model.compile(
    loss=MeanSquaredError(),
    optimizer=Adam(learning_rate=0.05),
    metrics=[tf.keras.metrics.MeanAbsoluteError()]
)

history = model.fit(Xn_train, y_train, validation_data=[Xn_cv, y_cv], epochs=100, verbose=True)
# Out:
# Epoch 1/100
# 508/508 [==============================] - 1s 1ms/step - loss: 13470169088.0000 - mean_absolute_error: 53038.1523 - val_loss: 2711458304.0000 - val_mean_absolute_error: 28188.5938
# Epoch 2/100
# 508/508 [==============================] - 1s 1ms/step - loss: 2603209216.0000 - mean_absolute_error: 27064.5156 - val_loss: 2757075968.0000 - val_mean_absolute_error: 28466.2891
# Epoch 3/100
# 508/508 [==============================] - 1s 1ms/step - loss: 2176933376.0000 - mean_absolute_error: 26497.5469 - val_loss: 1115074304.0000 - val_mean_absolute_error: 23880.0703
# Epoch 4/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1325520128.0000 - mean_absolute_error: 26289.3320 - val_loss: 1137829376.0000 - val_mean_absolute_error: 23982.3887
# Epoch 5/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1244157440.0000 - mean_absolute_error: 25860.6328 - val_loss: 1003843456.0000 - val_mean_absolute_error: 23441.8555
# Epoch 6/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1143710720.0000 - mean_absolute_error: 24784.5215 - val_loss: 929924096.0000 - val_mean_absolute_error: 22998.8926
# Epoch 7/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1190945152.0000 - mean_absolute_error: 25387.4590 - val_loss: 1178176128.0000 - val_mean_absolute_error: 25202.3906
# Epoch 8/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1226090752.0000 - mean_absolute_error: 25815.9844 - val_loss: 927286336.0000 - val_mean_absolute_error: 23062.0742
# Epoch 9/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1177893376.0000 - mean_absolute_error: 25402.3828 - val_loss: 1000638784.0000 - val_mean_absolute_error: 22968.9746
# Epoch 10/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1046624960.0000 - mean_absolute_error: 23910.8223 - val_loss: 826346240.0000 - val_mean_absolute_error: 21716.2188
# Epoch 11/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1184082944.0000 - mean_absolute_error: 25402.6270 - val_loss: 906560320.0000 - val_mean_absolute_error: 22719.8926
# Epoch 12/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1141334784.0000 - mean_absolute_error: 24918.0293 - val_loss: 911407296.0000 - val_mean_absolute_error: 22958.4062
# Epoch 13/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1080489728.0000 - mean_absolute_error: 24523.6367 - val_loss: 1013580544.0000 - val_mean_absolute_error: 23833.8008
# Epoch 14/100
# 508/508 [==============================] - 1s 1ms/step - loss: 997763712.0000 - mean_absolute_error: 23525.3438 - val_loss: 1168030208.0000 - val_mean_absolute_error: 25543.4570
# Epoch 15/100
# 508/508 [==============================] - 1s 1ms/step - loss: 951665152.0000 - mean_absolute_error: 23137.9004 - val_loss: 847921920.0000 - val_mean_absolute_error: 22068.1660
# Epoch 16/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1008421952.0000 - mean_absolute_error: 23776.8379 - val_loss: 941141184.0000 - val_mean_absolute_error: 23406.3379
# Epoch 17/100
# 508/508 [==============================] - 1s 1ms/step - loss: 997135872.0000 - mean_absolute_error: 23735.1113 - val_loss: 872133376.0000 - val_mean_absolute_error: 22346.7852
# Epoch 18/100
# 508/508 [==============================] - 1s 1ms/step - loss: 937025152.0000 - mean_absolute_error: 23085.9258 - val_loss: 1702577536.0000 - val_mean_absolute_error: 32032.6445
# Epoch 19/100
# 508/508 [==============================] - 1s 1ms/step - loss: 979447936.0000 - mean_absolute_error: 23507.9316 - val_loss: 852429440.0000 - val_mean_absolute_error: 22367.0488
# Epoch 20/100
# 508/508 [==============================] - 1s 1ms/step - loss: 921333952.0000 - mean_absolute_error: 23004.8770 - val_loss: 846250112.0000 - val_mean_absolute_error: 21934.3047
# Epoch 21/100
# 508/508 [==============================] - 1s 1ms/step - loss: 969587520.0000 - mean_absolute_error: 23496.7422 - val_loss: 940352000.0000 - val_mean_absolute_error: 22731.1621
# Epoch 22/100
# 508/508 [==============================] - 1s 1ms/step - loss: 880237248.0000 - mean_absolute_error: 22527.3047 - val_loss: 861888576.0000 - val_mean_absolute_error: 22623.7402
# Epoch 23/100
# 508/508 [==============================] - 1s 1ms/step - loss: 881364672.0000 - mean_absolute_error: 22601.2656 - val_loss: 964198656.0000 - val_mean_absolute_error: 24111.4395
# Epoch 24/100
# 508/508 [==============================] - 1s 1ms/step - loss: 921033344.0000 - mean_absolute_error: 23013.9824 - val_loss: 920018752.0000 - val_mean_absolute_error: 23470.9375
# Epoch 25/100
# 508/508 [==============================] - 1s 1ms/step - loss: 898897088.0000 - mean_absolute_error: 22890.0645 - val_loss: 835370560.0000 - val_mean_absolute_error: 22078.0195
# Epoch 26/100
# 508/508 [==============================] - 1s 1ms/step - loss: 892835584.0000 - mean_absolute_error: 22707.5879 - val_loss: 899800320.0000 - val_mean_absolute_error: 22775.6074
# Epoch 27/100
# 508/508 [==============================] - 1s 1ms/step - loss: 903300352.0000 - mean_absolute_error: 22872.5742 - val_loss: 771866432.0000 - val_mean_absolute_error: 21585.0156
# Epoch 28/100
# 508/508 [==============================] - 1s 1ms/step - loss: 872930944.0000 - mean_absolute_error: 22579.9961 - val_loss: 1040233472.0000 - val_mean_absolute_error: 24332.8574
# Epoch 29/100
# 508/508 [==============================] - 1s 1ms/step - loss: 879275328.0000 - mean_absolute_error: 22564.9902 - val_loss: 819501888.0000 - val_mean_absolute_error: 21823.4727
# Epoch 30/100
# 508/508 [==============================] - 1s 1ms/step - loss: 832445760.0000 - mean_absolute_error: 22146.9727 - val_loss: 823919040.0000 - val_mean_absolute_error: 22203.0664
# Epoch 31/100
# 508/508 [==============================] - 1s 1ms/step - loss: 862016384.0000 - mean_absolute_error: 22376.8711 - val_loss: 859927808.0000 - val_mean_absolute_error: 22401.2266
# Epoch 32/100
# 508/508 [==============================] - 1s 1ms/step - loss: 861802240.0000 - mean_absolute_error: 22465.4551 - val_loss: 761267776.0000 - val_mean_absolute_error: 21330.5859
# Epoch 33/100
# 508/508 [==============================] - 1s 1ms/step - loss: 876427392.0000 - mean_absolute_error: 22681.4570 - val_loss: 986466368.0000 - val_mean_absolute_error: 24120.0234
# Epoch 34/100
# 508/508 [==============================] - 1s 1ms/step - loss: 891821568.0000 - mean_absolute_error: 22822.2891 - val_loss: 791558976.0000 - val_mean_absolute_error: 21951.4824
# Epoch 35/100
# 508/508 [==============================] - 1s 1ms/step - loss: 855926272.0000 - mean_absolute_error: 22399.6445 - val_loss: 809146560.0000 - val_mean_absolute_error: 22230.7676
# Epoch 36/100
# 508/508 [==============================] - 1s 1ms/step - loss: 849754240.0000 - mean_absolute_error: 22410.4258 - val_loss: 1021510912.0000 - val_mean_absolute_error: 24183.5020
# Epoch 37/100
# 508/508 [==============================] - 1s 1ms/step - loss: 845673984.0000 - mean_absolute_error: 22424.8066 - val_loss: 748792064.0000 - val_mean_absolute_error: 21353.6250
# Epoch 38/100
# 508/508 [==============================] - 1s 1ms/step - loss: 837817856.0000 - mean_absolute_error: 22289.1953 - val_loss: 806858368.0000 - val_mean_absolute_error: 21740.8242
# Epoch 39/100
# 508/508 [==============================] - 1s 1ms/step - loss: 847086400.0000 - mean_absolute_error: 22397.5664 - val_loss: 762638144.0000 - val_mean_absolute_error: 21462.7031
# Epoch 40/100
# 508/508 [==============================] - 1s 1ms/step - loss: 836646272.0000 - mean_absolute_error: 22292.6816 - val_loss: 825279040.0000 - val_mean_absolute_error: 22436.5098
# Epoch 41/100
# 508/508 [==============================] - 1s 1ms/step - loss: 837299136.0000 - mean_absolute_error: 22243.0391 - val_loss: 762606784.0000 - val_mean_absolute_error: 21615.9551
# Epoch 42/100
# 508/508 [==============================] - 1s 1ms/step - loss: 829258304.0000 - mean_absolute_error: 22232.4785 - val_loss: 807120320.0000 - val_mean_absolute_error: 22271.8945
# Epoch 43/100
# 508/508 [==============================] - 1s 1ms/step - loss: 818650816.0000 - mean_absolute_error: 22015.2812 - val_loss: 973895552.0000 - val_mean_absolute_error: 24072.9824
# Epoch 44/100
# 508/508 [==============================] - 1s 1ms/step - loss: 822785152.0000 - mean_absolute_error: 22097.0645 - val_loss: 899937792.0000 - val_mean_absolute_error: 23351.8105
# Epoch 45/100
# 508/508 [==============================] - 1s 1ms/step - loss: 854652416.0000 - mean_absolute_error: 22434.3789 - val_loss: 749284928.0000 - val_mean_absolute_error: 21455.6328
# Epoch 46/100
# 508/508 [==============================] - 1s 1ms/step - loss: 824299072.0000 - mean_absolute_error: 22256.0293 - val_loss: 884837760.0000 - val_mean_absolute_error: 22953.5703
# Epoch 47/100
# 508/508 [==============================] - 1s 1ms/step - loss: 823624064.0000 - mean_absolute_error: 22172.4160 - val_loss: 825156608.0000 - val_mean_absolute_error: 22142.5391
# Epoch 48/100
# 508/508 [==============================] - 1s 1ms/step - loss: 827317760.0000 - mean_absolute_error: 22182.5996 - val_loss: 734685120.0000 - val_mean_absolute_error: 21304.8379
# Epoch 49/100
# 508/508 [==============================] - 1s 1ms/step - loss: 822159680.0000 - mean_absolute_error: 22128.6680 - val_loss: 889615360.0000 - val_mean_absolute_error: 22854.6758
# Epoch 50/100
# 508/508 [==============================] - 1s 1ms/step - loss: 839556032.0000 - mean_absolute_error: 22304.8652 - val_loss: 915922432.0000 - val_mean_absolute_error: 23387.8086
# Epoch 51/100
# 508/508 [==============================] - 1s 1ms/step - loss: 802083840.0000 - mean_absolute_error: 21914.7305 - val_loss: 763629568.0000 - val_mean_absolute_error: 21706.0469
# Epoch 52/100
# 508/508 [==============================] - 1s 1ms/step - loss: 828380608.0000 - mean_absolute_error: 22198.1719 - val_loss: 774168000.0000 - val_mean_absolute_error: 21672.7441
# Epoch 53/100
# 508/508 [==============================] - 1s 1ms/step - loss: 797814464.0000 - mean_absolute_error: 21829.4844 - val_loss: 946881536.0000 - val_mean_absolute_error: 23659.5488
# Epoch 54/100
# 508/508 [==============================] - 1s 1ms/step - loss: 838839296.0000 - mean_absolute_error: 22379.8242 - val_loss: 956854016.0000 - val_mean_absolute_error: 24371.6582
# Epoch 55/100
# 508/508 [==============================] - 1s 1ms/step - loss: 815138048.0000 - mean_absolute_error: 22144.0859 - val_loss: 742724416.0000 - val_mean_absolute_error: 21288.3535
# Epoch 56/100
# 508/508 [==============================] - 1s 1ms/step - loss: 808922944.0000 - mean_absolute_error: 22027.1035 - val_loss: 847678784.0000 - val_mean_absolute_error: 22380.1914
# Epoch 57/100
# 508/508 [==============================] - 1s 1ms/step - loss: 808399872.0000 - mean_absolute_error: 21996.6055 - val_loss: 732416448.0000 - val_mean_absolute_error: 21049.7539
# Epoch 58/100
# 508/508 [==============================] - 1s 1ms/step - loss: 814500224.0000 - mean_absolute_error: 22084.7402 - val_loss: 752248128.0000 - val_mean_absolute_error: 21376.8730
# Epoch 59/100
# 508/508 [==============================] - 1s 1ms/step - loss: 800505216.0000 - mean_absolute_error: 21979.1484 - val_loss: 773129536.0000 - val_mean_absolute_error: 21651.5996
# Epoch 60/100
# 508/508 [==============================] - 1s 1ms/step - loss: 809163520.0000 - mean_absolute_error: 21971.6582 - val_loss: 746585088.0000 - val_mean_absolute_error: 21457.1719
# Epoch 61/100
# 508/508 [==============================] - 1s 1ms/step - loss: 808986560.0000 - mean_absolute_error: 22038.7324 - val_loss: 842274304.0000 - val_mean_absolute_error: 22563.0137
# Epoch 62/100
# 508/508 [==============================] - 1s 1ms/step - loss: 801267904.0000 - mean_absolute_error: 21955.5020 - val_loss: 742652032.0000 - val_mean_absolute_error: 21175.7656
# Epoch 63/100
# 508/508 [==============================] - 1s 1ms/step - loss: 775519104.0000 - mean_absolute_error: 21686.3477 - val_loss: 775273856.0000 - val_mean_absolute_error: 21804.1445
# Epoch 64/100
# 508/508 [==============================] - 1s 1ms/step - loss: 793268096.0000 - mean_absolute_error: 21890.7441 - val_loss: 741322752.0000 - val_mean_absolute_error: 21597.4023
# Epoch 65/100
# 508/508 [==============================] - 1s 1ms/step - loss: 784876096.0000 - mean_absolute_error: 21763.2461 - val_loss: 776485056.0000 - val_mean_absolute_error: 21977.5938
# Epoch 66/100
# 508/508 [==============================] - 1s 1ms/step - loss: 804159808.0000 - mean_absolute_error: 22010.9922 - val_loss: 757227264.0000 - val_mean_absolute_error: 21727.9727
# Epoch 67/100
# 508/508 [==============================] - 1s 1ms/step - loss: 814949184.0000 - mean_absolute_error: 22145.6719 - val_loss: 759320128.0000 - val_mean_absolute_error: 21488.0996
# Epoch 68/100
# 508/508 [==============================] - 1s 1ms/step - loss: 775269056.0000 - mean_absolute_error: 21689.1211 - val_loss: 749375936.0000 - val_mean_absolute_error: 21711.4922
# Epoch 69/100
# 508/508 [==============================] - 1s 1ms/step - loss: 770621696.0000 - mean_absolute_error: 21656.6562 - val_loss: 866618944.0000 - val_mean_absolute_error: 22967.0410
# Epoch 70/100
# 508/508 [==============================] - 1s 1ms/step - loss: 811584128.0000 - mean_absolute_error: 22158.2539 - val_loss: 776616448.0000 - val_mean_absolute_error: 21995.1465
# Epoch 71/100
# 508/508 [==============================] - 1s 1ms/step - loss: 780612224.0000 - mean_absolute_error: 21741.7012 - val_loss: 964225152.0000 - val_mean_absolute_error: 23609.0859
# Epoch 72/100
# 508/508 [==============================] - 1s 1ms/step - loss: 795774848.0000 - mean_absolute_error: 21953.5234 - val_loss: 911404544.0000 - val_mean_absolute_error: 23473.4844
# Epoch 73/100
# 508/508 [==============================] - 1s 1ms/step - loss: 788922816.0000 - mean_absolute_error: 21779.2676 - val_loss: 872741760.0000 - val_mean_absolute_error: 23025.5840
# Epoch 74/100
# 508/508 [==============================] - 1s 1ms/step - loss: 779676480.0000 - mean_absolute_error: 21740.7715 - val_loss: 814516288.0000 - val_mean_absolute_error: 21913.0938
# Epoch 75/100
# 508/508 [==============================] - 1s 1ms/step - loss: 794889728.0000 - mean_absolute_error: 21919.9434 - val_loss: 742853568.0000 - val_mean_absolute_error: 21474.7949
# Epoch 76/100
# 508/508 [==============================] - 1s 1ms/step - loss: 765246144.0000 - mean_absolute_error: 21622.2871 - val_loss: 735574208.0000 - val_mean_absolute_error: 21347.3535
# Epoch 77/100
# 508/508 [==============================] - 1s 1ms/step - loss: 800952448.0000 - mean_absolute_error: 22000.7344 - val_loss: 793761600.0000 - val_mean_absolute_error: 21918.1660
# Epoch 78/100
# 508/508 [==============================] - 1s 1ms/step - loss: 778031104.0000 - mean_absolute_error: 21735.8652 - val_loss: 826270080.0000 - val_mean_absolute_error: 22375.9805
# Epoch 79/100
# 508/508 [==============================] - 1s 1ms/step - loss: 791058048.0000 - mean_absolute_error: 21878.1270 - val_loss: 718019712.0000 - val_mean_absolute_error: 21095.7949
# Epoch 80/100
# 508/508 [==============================] - 1s 1ms/step - loss: 769400000.0000 - mean_absolute_error: 21656.2930 - val_loss: 937325440.0000 - val_mean_absolute_error: 23396.9668
# Epoch 81/100
# 508/508 [==============================] - 1s 1ms/step - loss: 778019328.0000 - mean_absolute_error: 21791.0137 - val_loss: 729414464.0000 - val_mean_absolute_error: 21363.0898
# Epoch 82/100
# 508/508 [==============================] - 1s 1ms/step - loss: 789561600.0000 - mean_absolute_error: 21802.1680 - val_loss: 823774976.0000 - val_mean_absolute_error: 22389.1191
# Epoch 83/100
# 508/508 [==============================] - 1s 1ms/step - loss: 781526720.0000 - mean_absolute_error: 21803.9062 - val_loss: 889475520.0000 - val_mean_absolute_error: 23158.5234
# Epoch 84/100
# 508/508 [==============================] - 1s 1ms/step - loss: 794677952.0000 - mean_absolute_error: 21993.1172 - val_loss: 710844736.0000 - val_mean_absolute_error: 21141.8691
# Epoch 85/100
# 508/508 [==============================] - 1s 1ms/step - loss: 774330432.0000 - mean_absolute_error: 21727.1816 - val_loss: 779880064.0000 - val_mean_absolute_error: 21955.9355
# Epoch 86/100
# 508/508 [==============================] - 1s 1ms/step - loss: 801428544.0000 - mean_absolute_error: 22060.3984 - val_loss: 719256640.0000 - val_mean_absolute_error: 21261.5723
# Epoch 87/100
# 508/508 [==============================] - 1s 1ms/step - loss: 781676160.0000 - mean_absolute_error: 21829.0879 - val_loss: 776809664.0000 - val_mean_absolute_error: 21873.4121
# Epoch 88/100
# 508/508 [==============================] - 1s 1ms/step - loss: 763192960.0000 - mean_absolute_error: 21663.3945 - val_loss: 734270848.0000 - val_mean_absolute_error: 21458.2832
# Epoch 89/100
# 508/508 [==============================] - 1s 1ms/step - loss: 781179584.0000 - mean_absolute_error: 21786.4824 - val_loss: 764949952.0000 - val_mean_absolute_error: 21407.7051
# Epoch 90/100
# 508/508 [==============================] - 1s 1ms/step - loss: 781993664.0000 - mean_absolute_error: 21830.7109 - val_loss: 724127936.0000 - val_mean_absolute_error: 21233.7227
# Epoch 91/100
# 508/508 [==============================] - 1s 1ms/step - loss: 785453056.0000 - mean_absolute_error: 21824.1172 - val_loss: 731183040.0000 - val_mean_absolute_error: 21393.7910
# Epoch 92/100
# 508/508 [==============================] - 1s 1ms/step - loss: 769982592.0000 - mean_absolute_error: 21740.3633 - val_loss: 721653824.0000 - val_mean_absolute_error: 21252.6758
# Epoch 93/100
# 508/508 [==============================] - 1s 1ms/step - loss: 776423616.0000 - mean_absolute_error: 21754.4668 - val_loss: 777360064.0000 - val_mean_absolute_error: 21798.6191
# Epoch 94/100
# 508/508 [==============================] - 1s 1ms/step - loss: 787360320.0000 - mean_absolute_error: 21924.1328 - val_loss: 710697728.0000 - val_mean_absolute_error: 21106.3516
# Epoch 95/100
# 508/508 [==============================] - 1s 1ms/step - loss: 780463680.0000 - mean_absolute_error: 21771.2695 - val_loss: 830333760.0000 - val_mean_absolute_error: 22637.8945
# Epoch 96/100
# 508/508 [==============================] - 1s 1ms/step - loss: 784842816.0000 - mean_absolute_error: 21852.5020 - val_loss: 728323328.0000 - val_mean_absolute_error: 21291.8008
# Epoch 97/100
# 508/508 [==============================] - 1s 1ms/step - loss: 772081536.0000 - mean_absolute_error: 21695.9668 - val_loss: 758327232.0000 - val_mean_absolute_error: 21745.6934
# Epoch 98/100
# 508/508 [==============================] - 1s 1ms/step - loss: 761437952.0000 - mean_absolute_error: 21612.8301 - val_loss: 711459136.0000 - val_mean_absolute_error: 21019.7070
# Epoch 99/100
# 508/508 [==============================] - 1s 1ms/step - loss: 775153472.0000 - mean_absolute_error: 21835.7852 - val_loss: 725924160.0000 - val_mean_absolute_error: 21262.0918
# Epoch 100/100
# 508/508 [==============================] - 1s 1ms/step - loss: 766142912.0000 - mean_absolute_error: 21656.5723 - val_loss: 756220672.0000 - val_mean_absolute_error: 21765.8281

# %%
losses = np.array(history.history['loss'])
MAE = np.array(history.history['mean_absolute_error'])
val_losses = np.array(history.history['val_loss'])
val_MAE = np.array(history.history['val_mean_absolute_error'])

plt.figure(figsize=(15, 8))
plt.plot(range(MAE.size), MAE, label='MAE');
plt.plot(range(val_MAE.size), val_MAE, label='CV MAE');
plt.title('MAE value in each step')
plt.xlabel('Epoch');
plt.ylabel('MAE');
plt.legend();

# %%
J_abs_train = model.evaluate(Xn_train, y_train, verbose=False)[1]
J_abs_cv = model.evaluate(Xn_cv, y_cv, verbose=False)[1]
J_abs_test = model.evaluate(Xn_test, y_test, verbose=False)[1]

print(f'Absolute error for training set is {J_abs_train}')
print(f'Absolute error for cross validation set is {J_abs_cv}')
print(f'Absolute error for test set is {J_abs_test}')
# Out:
# Absolute error for training set is 21540.0859375
# Absolute error for cross validation set is 21765.828125
# Absolute error for test set is 21294.6015625

# %%
fig, ax = plt.subplots(6, 3, figsize=(15, 30))
m, n = Xn_train.shape
cnt = 0
for ax in ax.flatten():
    try:
        if cnt >= n:
            ax.set_visible(False)
            continue
        newy = model.predict(Xn_train, verbose=False);
        ax.scatter(X_train[:, cnt], y_train, alpha=0.2)
        ax.scatter(X_train[:, cnt], newy, alpha=0.1, c='orange')
        ax.set_title(df.drop('price', axis=1).columns[cnt])
        cnt += 1
    except:
        ax.set_visible(False)
        continue

# %%
X_all = df.drop(['price'], axis=1).values
Xn_all = norm(X_all)
p_df = df.copy(deep=True)
p_df['Predicted'] = model.predict(Xn_all).astype('int64')
p_df
# Out:
# 635/635 [==============================] - 0s 621us/step
#               bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# id
# 7.129301e+09         3       1.00         1180      5650     1.0           0
# 6.414100e+09         3       2.25         2570      7242     2.0           0
# 5.631500e+09         2       1.00          770     10000     1.0           0
# 2.487201e+09         4       3.00         1960      5000     1.0           0
# 1.954401e+09         3       2.00         1680      8080     1.0           0
# ...                ...        ...          ...       ...     ...         ...
# 2.630000e+08         3       2.50         1530      1131     3.0           0
# 6.600060e+09         4       2.50         2310      5813     2.0           0
# 1.523300e+09         2       0.75         1020      1350     2.0           0
# 2.913101e+08         3       2.50         1600      2388     2.0           0
# 1.523300e+09         2       0.75         1020      1076     2.0           0
#
#               view  condition  grade  sqft_basement  ...  cluster_1.0  \
# id                                                   ...
# 7.129301e+09     0          3      7              0  ...            0
# 6.414100e+09     0          3      7            400  ...            0
# 5.631500e+09     0          3      6              0  ...            0
# 2.487201e+09     0          5      7            910  ...            0
# 1.954401e+09     0          3      8              0  ...            0
# ...            ...        ...    ...            ...  ...          ...
# 2.630000e+08     0          3      8              0  ...            0
# 6.600060e+09     0          3      8              0  ...            1
# 1.523300e+09     0          3      7              0  ...            1
# 2.913101e+08     0          3      8              0  ...            1
# 1.523300e+09     0          3      7              0  ...            0
#
#               cluster_2.0  cluster_3.0  cluster_4.0  cluster_5.0  cluster_6.0  \
# id
# 7.129301e+09            0            0            1            0            0
# 6.414100e+09            0            0            0            0            0
# 5.631500e+09            0            0            1            0            0
# 2.487201e+09            0            0            0            0            0
# 1.954401e+09            1            0            0            0            0
# ...                   ...          ...          ...          ...          ...
# 2.630000e+08            0            0            0            0            0
# 6.600060e+09            0            0            0            0            0
# 1.523300e+09            0            0            0            0            0
# 2.913101e+08            0            0            0            0            0
# 1.523300e+09            0            0            0            0            0
#
#               cluster_7.0  cluster_8.0  cluster_9.0  Predicted
# id
# 7.129301e+09            0            0            0     196488
# 6.414100e+09            0            0            0     584180
# 5.631500e+09            0            0            0     188930
# 2.487201e+09            0            0            0     588921
# 1.954401e+09            0            0            0     500742
# ...                   ...          ...          ...        ...
# 2.630000e+08            0            1            0     356581
# 6.600060e+09            0            0            0     422187
# 1.523300e+09            0            0            0     411493
# 2.913101e+08            0            0            0     424011
# 1.523300e+09            0            1            0     337707
#
# [20297 rows x 30 columns]

# %%
p_df.to_csv('output_NN.csv', index=True)
