# %% [markdown]
# # King County - Neural Network

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Normalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.regularizers import L2
import seaborn as sns
import time
from k_mean_cluster_util import k_mean_optimization, k_mean, random_initial_centroids

# %% [markdown]
# ## Getting data ready
# First We'll have some intuition on the data and set the "id" as index value. Also remove duplicate values.

# %%
df = pd.read_csv('./kc_house_data.csv')
df.set_index('id', inplace=True)
df = df[~df.index.duplicated(keep='first')]
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 5631500400              0      1933             0    98028  47.7379 -122.233
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 1954400510              0      1987             0    98074  47.6168 -122.045
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639
# 5631500400           2720        8062
# 2487200875           1360        5000
# 1954400510           1800        7503

# %% [markdown]
# From date which is an object, "str" in this dataset, we'll have to convert to date and take year and month which is important to our model.

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df = df.drop('date', axis=1)
prices = df['price']
df = df.drop('price', axis=1)
df['price'] = prices
df.head()
# Out:
#             bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# id
# 7129300520         3       1.00         1180      5650     1.0           0
# 6414100192         3       2.25         2570      7242     2.0           0
# 5631500400         2       1.00          770     10000     1.0           0
# 2487200875         4       3.00         1960      5000     1.0           0
# 1954400510         3       2.00         1680      8080     1.0           0
#
#             view  condition  grade  sqft_above  ...  yr_built  yr_renovated  \
# id                                              ...
# 7129300520     0          3      7        1180  ...      1955             0
# 6414100192     0          3      7        2170  ...      1951          1991
# 5631500400     0          3      6         770  ...      1933             0
# 2487200875     0          5      7        1050  ...      1965             0
# 1954400510     0          3      8        1680  ...      1987             0
#
#             zipcode      lat     long  sqft_living15  sqft_lot15  year  month  \
# id
# 7129300520    98178  47.5112 -122.257           1340        5650  2014     10
# 6414100192    98125  47.7210 -122.319           1690        7639  2014     12
# 5631500400    98028  47.7379 -122.233           2720        8062  2015      2
# 2487200875    98136  47.5208 -122.393           1360        5000  2014     12
# 1954400510    98074  47.6168 -122.045           1800        7503  2015      2
#
#                price
# id
# 7129300520  221900.0
# 6414100192  538000.0
# 5631500400  180000.0
# 2487200875  604000.0
# 1954400510  510000.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Have an intuition on what columns contain null values and what their Dtypes are

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21436 entries, 7129300520 to 1523300157
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       21436 non-null  int64
#  1   bathrooms      21436 non-null  float64
#  2   sqft_living    21436 non-null  int64
#  3   sqft_lot       21436 non-null  int64
#  4   floors         21436 non-null  float64
#  5   waterfront     21436 non-null  int64
#  6   view           21436 non-null  int64
#  7   condition      21436 non-null  int64
#  8   grade          21436 non-null  int64
#  9   sqft_above     21436 non-null  int64
#  10  sqft_basement  21436 non-null  int64
#  11  yr_built       21436 non-null  int64
#  12  yr_renovated   21436 non-null  int64
#  13  zipcode        21436 non-null  int64
#  14  lat            21436 non-null  float64
#  15  long           21436 non-null  float64
#  16  sqft_living15  21436 non-null  int64
#  17  sqft_lot15     21436 non-null  int64
#  18  year           21436 non-null  int64
#  19  month          21436 non-null  int64
#  20  price          21436 non-null  float64
# dtypes: float64(5), int64(16)
# memory usage: 3.6 MB

# %%
df.describe().T
# Out:
#                  count           mean            std         min          25%  \
# bedrooms       21436.0       3.371571       0.929205      0.0000       3.0000
# bathrooms      21436.0       2.117349       0.769913      0.0000       1.7500
# sqft_living    21436.0    2082.704936     919.146469    290.0000    1430.0000
# sqft_lot       21436.0   15135.637852   41538.620606    520.0000    5040.0000
# floors         21436.0       1.496198       0.540388      1.0000       1.0000
# waterfront     21436.0       0.007604       0.086871      0.0000       0.0000
# view           21436.0       0.235118       0.767092      0.0000       0.0000
# condition      21436.0       3.410384       0.650235      1.0000       3.0000
# grade          21436.0       7.661737       1.174256      1.0000       7.0000
# sqft_above     21436.0    1790.960440     829.026491    290.0000    1200.0000
# sqft_basement  21436.0     291.744495     442.781983      0.0000       0.0000
# yr_built       21436.0    1971.098433      29.385277   1900.0000    1952.0000
# yr_renovated   21436.0      84.729800     402.431012      0.0000       0.0000
# zipcode        21436.0   98077.862288      53.469371  98001.0000   98033.0000
# lat            21436.0      47.560156       0.138601     47.1559      47.4711
# long           21436.0    -122.213697       0.140896   -122.5190    -122.3280
# sqft_living15  21436.0    1988.314378     685.699093    399.0000    1490.0000
# sqft_lot15     21436.0   12785.961280   27375.467469    651.0000    5100.0000
# year           21436.0    2014.318949       0.466080   2014.0000    2014.0000
# month          21436.0       6.590782       3.108176      1.0000       4.0000
# price          21436.0  540529.287180  367689.296471  75000.0000  322150.0000
#
#                       50%         75%           max
# bedrooms            3.000       4.000  3.300000e+01
# bathrooms           2.250       2.500  8.000000e+00
# sqft_living      1920.000    2550.000  1.354000e+04
# sqft_lot         7614.000   10696.250  1.651359e+06
# floors              1.500       2.000  3.500000e+00
# waterfront          0.000       0.000  1.000000e+00
# view                0.000       0.000  4.000000e+00
# condition           3.000       4.000  5.000000e+00
# grade               7.000       8.000  1.300000e+01
# sqft_above       1560.000    2220.000  9.410000e+03
# sqft_basement       0.000     560.000  4.820000e+03
# yr_built         1975.000    1997.000  2.015000e+03
# yr_renovated        0.000       0.000  2.015000e+03
# zipcode         98065.000   98117.000  9.819900e+04
# lat                47.572      47.678  4.777760e+01
# long             -122.230    -122.124 -1.213150e+02
# sqft_living15    1840.000    2370.000  6.210000e+03
# sqft_lot15       7620.000   10087.250  8.712000e+05
# year             2014.000    2015.000  2.015000e+03
# month               6.000       9.000  1.200000e+01
# price          450000.000  645000.000  7.700000e+06

# %%
(df == 0).sum()
# Out:
# bedrooms            13
# bathrooms           10
# sqft_living          0
# sqft_lot             0
# floors               0
# waterfront       21273
# view             19320
# condition            0
# grade                0
# sqft_above           0
# sqft_basement    13015
# yr_built             0
# yr_renovated     20526
# zipcode              0
# lat                  0
# long                 0
# sqft_living15        0
# sqft_lot15           0
# year                 0
# month                0
# price                0
# dtype: int64

# %% [markdown]
# Correlation of two values gives a great insight on what features impact the values of each other

# %%
df.corr()
# Out:
#                bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# bedrooms       1.000000   0.516772     0.577512  0.031719  0.175207
# bathrooms      0.516772   1.000000     0.754422  0.087143  0.499863
# sqft_living    0.577512   0.754422     1.000000  0.171957  0.352867
# sqft_lot       0.031719   0.087143     0.171957  1.000000 -0.005950
# floors         0.175207   0.499863     0.352867 -0.005950  1.000000
# waterfront    -0.006685   0.063734     0.103902  0.021571  0.023473
# view           0.079542   0.186684     0.283753  0.075012  0.028211
# condition      0.027896  -0.127839    -0.060973 -0.009298 -0.266543
# grade          0.358396   0.664727     0.762402  0.112541  0.457475
# sqft_above     0.478441   0.684994     0.876683  0.182581  0.522648
# sqft_basement  0.303035   0.283539     0.434419  0.015107 -0.246066
# yr_built       0.153745   0.505092     0.316544  0.052447  0.489062
# yr_renovated   0.018435   0.051101     0.055084  0.007636  0.005626
# zipcode       -0.153621  -0.202958    -0.198621 -0.129411 -0.058108
# lat           -0.010228   0.023444     0.051118 -0.085992  0.049279
# long           0.129836   0.221935     0.239214  0.229555  0.124285
# sqft_living15  0.393161   0.568194     0.756205  0.143650  0.278854
# sqft_lot15     0.029117   0.086627     0.182775  0.718097 -0.011917
# year          -0.010065  -0.023215    -0.025818  0.005981 -0.018709
# month         -0.000413   0.005427     0.010058 -0.002557  0.011864
# price          0.309007   0.525453     0.701993  0.088895  0.256278
#
#                waterfront      view  condition     grade  sqft_above  ...  \
# bedrooms        -0.006685  0.079542   0.027896  0.358396    0.478441  ...
# bathrooms        0.063734  0.186684  -0.127839  0.664727    0.684994  ...
# sqft_living      0.103902  0.283753  -0.060973  0.762402    0.876683  ...
# sqft_lot         0.021571  0.075012  -0.009298  0.112541    0.182581  ...
# floors           0.023473  0.028211  -0.266543  0.457475    0.522648  ...
# waterfront       1.000000  0.403025   0.016607  0.082841    0.072021  ...
# view             0.403025  1.000000   0.045051  0.249890    0.166930  ...
# condition        0.016607  0.045051   1.000000 -0.148248   -0.160782  ...
# grade            0.082841  0.249890  -0.148248  1.000000    0.756068  ...
# sqft_above       0.072021  0.166930  -0.160782  0.756068    1.000000  ...
# sqft_basement    0.080838  0.276482   0.174463  0.167032   -0.052456  ...
# yr_built        -0.026537 -0.055153  -0.364947  0.445329    0.422838  ...
# yr_renovated     0.093025  0.103633  -0.061136  0.014357    0.022666  ...
# zipcode          0.030558  0.087096   0.004509 -0.182675   -0.260420  ...
# lat             -0.014395  0.005671  -0.015402  0.113332   -0.001652  ...
# long            -0.042188 -0.079720  -0.107780  0.196572    0.343115  ...
# sqft_living15    0.086558  0.279077  -0.095002  0.712507    0.731992  ...
# sqft_lot15       0.030694  0.072867  -0.003731  0.118313    0.193413  ...
# year            -0.003444  0.003066  -0.044611 -0.025513   -0.020437  ...
# month            0.007724 -0.006918   0.021396  0.005161    0.007820  ...
# price            0.266961  0.396933   0.035089  0.667496    0.605495  ...
#
#                yr_built  yr_renovated   zipcode       lat      long  \
# bedrooms       0.153745      0.018435 -0.153621 -0.010228  0.129836
# bathrooms      0.505092      0.051101 -0.202958  0.023444  0.221935
# sqft_living    0.316544      0.055084 -0.198621  0.051118  0.239214
# sqft_lot       0.052447      0.007636 -0.129411 -0.085992  0.229555
# floors         0.489062      0.005626 -0.058108  0.049279  0.124285
# waterfront    -0.026537      0.093025  0.030558 -0.014395 -0.042188
# view          -0.055153      0.103633  0.087096  0.005671 -0.079720
# condition     -0.364947     -0.061136  0.004509 -0.015402 -0.107780
# grade          0.445329      0.014357 -0.182675  0.113332  0.196572
# sqft_above     0.422838      0.022666 -0.260420 -0.001652  0.343115
# sqft_basement -0.134590      0.071909  0.075283  0.109208 -0.145846
# yr_built       1.000000     -0.225697 -0.345819 -0.148606  0.408531
# yr_renovated  -0.225697      1.000000  0.064347  0.029206 -0.068736
# zipcode       -0.345819      0.064347  1.000000  0.267020 -0.564588
# lat           -0.148606      0.029206  0.267020  1.000000 -0.136369
# long           0.408531     -0.068736 -0.564588 -0.136369  1.000000
# sqft_living15  0.324568     -0.002677 -0.278160  0.047668  0.333652
# sqft_lot15     0.070307      0.007870 -0.146991 -0.086505  0.254280
# year           0.007719     -0.022968 -0.001229 -0.028499  0.002119
# month         -0.009216      0.012444  0.001956  0.014594 -0.009681
# price          0.052967      0.127002 -0.052171  0.306057  0.020571
#
#                sqft_living15  sqft_lot15      year     month     price
# bedrooms            0.393161    0.029117 -0.010065 -0.000413  0.309007
# bathrooms           0.568194    0.086627 -0.023215  0.005427  0.525453
# sqft_living         0.756205    0.182775 -0.025818  0.010058  0.701993
# sqft_lot            0.143650    0.718097  0.005981 -0.002557  0.088895
# floors              0.278854   -0.011917 -0.018709  0.011864  0.256278
# waterfront          0.086558    0.030694 -0.003444  0.007724  0.266961
# view                0.279077    0.072867  0.003066 -0.006918  0.396933
# condition          -0.095002   -0.003731 -0.044611  0.021396  0.035089
# grade               0.712507    0.118313 -0.025513  0.005161  0.667496
# sqft_above          0.731992    0.193413 -0.020437  0.007820  0.605495
# sqft_basement       0.199247    0.017283 -0.015328  0.006239  0.323552
# yr_built            0.324568    0.070307  0.007719 -0.009216  0.052967
# yr_renovated       -0.002677    0.007870 -0.022968  0.012444  0.127002
# zipcode            -0.278160   -0.146991 -0.001229  0.001956 -0.052171
# lat                 0.047668   -0.086505 -0.028499  0.014594  0.306057
# long                0.333652    0.254280  0.002119 -0.009681  0.020571
# sqft_living15       1.000000    0.182441 -0.018751  0.000374  0.584688
# sqft_lot15          0.182441    1.000000  0.000349  0.003426  0.082038
# year               -0.018751    0.000349  1.000000 -0.780760  0.004800
# month               0.000374    0.003426 -0.780760  1.000000 -0.010684
# price               0.584688    0.082038  0.004800 -0.010684  1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(df.corr(), cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='price', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
sns.boxplot(data=df, x='price', ax=ax)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='sqft_living', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='sqft_living15', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.scatterplot(data=df, x='sqft_living', y='price', ax=ax[0], alpha=0.3, color='red')
sns.scatterplot(data=df, x='sqft_living15', y='price', ax=ax[1], alpha=0.3, color='green')
# Out:
# <AxesSubplot:xlabel='sqft_living15', ylabel='price'>

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(data=df, x='long', y='lat', hue='price', palette='rocket_r',);

# %% [markdown]
# ### Should we remove outliers?
# For housing prices, a house could have been sold for a value less than what it worths. Or the house could've been sold more than what it worths. According to the red graph, some house with 13.5k sqft_living has been sold for about 2m dollars but some other house with about 12k sqft_living has been sold for about 7.5m dollars. This case could be seen as an outlier but there are other factors that have impact on the price.

# %%
df[df['sqft_living'] > 12000].T
# Out:
# id               6762700020    1225069038
# bedrooms       6.000000e+00  7.000000e+00
# bathrooms      8.000000e+00  8.000000e+00
# sqft_living    1.205000e+04  1.354000e+04
# sqft_lot       2.760000e+04  3.077520e+05
# floors         2.500000e+00  3.000000e+00
# waterfront     0.000000e+00  0.000000e+00
# view           3.000000e+00  4.000000e+00
# condition      4.000000e+00  3.000000e+00
# grade          1.300000e+01  1.200000e+01
# sqft_above     8.570000e+03  9.410000e+03
# sqft_basement  3.480000e+03  4.130000e+03
# yr_built       1.910000e+03  1.999000e+03
# yr_renovated   1.987000e+03  0.000000e+00
# zipcode        9.810200e+04  9.805300e+04
# lat            4.762980e+01  4.766750e+01
# long          -1.223230e+02 -1.219860e+02
# sqft_living15  3.940000e+03  4.850000e+03
# sqft_lot15     8.800000e+03  2.178000e+05
# year           2.014000e+03  2.014000e+03
# month          1.000000e+01  5.000000e+00
# price          7.700000e+06  2.280000e+06

# %% [markdown]
# Two houses are somewhat the same and in the same area according to their lat and long. <br>
# - More expensive one is older than the new one
# - More expensive one's grade is greater than the other by 1 values
# - sqft_lot15 is very large compared to the other one
# - In 1987, the expensive house has been renovated but the other one hasn't been renovated
# <br>
# Other than these, the other house is better in every aspect. So why it is less expensive or not at all expensive? <br>
# I'd say the first one is expensive because it is near the lake.

# %%
def remove_outliers(df, columns='all'):
    columns = df.columns if columns == 'all' else columns
    for c in columns:
        df = remove_columns_outlier(df, c)
    return df

def remove_columns_outlier(df, column):
    column = df[column]
    column_norm = (column - np.mean(column)) / np.std(column)
    column_norm = column_norm[~((column_norm >= 3) | (column_norm <= -3))]
    return df.loc[df.index[df.index.value_counts() == 1]]

def remove_outliers_per(df, column, per_column):
    fraction = column / per_column
    frac_norm = (fraction - np.mean(fraction)) / np.std(fraction)
    frac_norm = frac_norm[~((frac_norm >= 3) | (frac_norm <= -3))]
    return df.loc[list(frac_norm.index)]

def percentage_from_right(df, column, from_value):
    per = df[df[column] > from_value].size / df.size
    per = per * 100
    return per

def percentage_from_left(df, column, from_value):
    per = df[df[column] < from_value].size / df.size
    per = per * 100
    return per
    
def drop_tail_right(df, column, from_value, max_percentage=5, verbos=True):
    per = percentage_from_right(df, column, from_value)
    if per > max_percentage: raise ValueError(f'Percentage ({per:.2f}%) greater than {max_percentage:.2f}%')
    if verbos: print(f'dropping {per:.2f}% data')
    return df[df[column] < from_value]

def drop_tail_left(df, column, from_value, max_percentage=5, verbos=True):
    per = percentage_from_left(df, column, from_value)
    if per > max_percentage: raise ValueError(f'Percentage ({per:.2f}%) greater than {max_percentage:.2f}%')
    if verbos: print(f'dropping {per:.2f}% data')
    return df[df[column] > from_value]


def remove_outliers_IQR(df, column, verbos=True):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    IQR = q3 - q1
    res = drop_tail_right(df, column, q3 + 1.5 * IQR, 100, False)
    res = drop_tail_left(res, column, q1 - 1.5 * IQR, 100, False)
    per = percentage_from_right(df, column, q3 + 1.5 * IQR) + percentage_from_left(df, column, q1 - 1.5 * IQR)
    if verbos: print(f'dropping {per:.2f}% data')
    return res

# %%
#df = remove_outliers(df, ['price'])
#df = remove_outliers_per(df, df['price'], df['sqft_living'])
#df = remove_outliers_per(df, df['price'], df['sqft_above'])
#df = remove_outliers_per(df, df['price'], df['sqft_living15'])

#df = drop_tail_right(df, 'price', 969000, 8)
#df = drop_tail_right(df, 'sqft_living', 3850, 3)
#df = drop_tail_right(df, 'sqft_living15', 3500, 3)
#df = drop_tail_left(df, 'grade', 5, 5)
#df = drop_tail_right(df, 'grade', 11, 5)

df = remove_outliers_IQR(df, 'price')
#df = remove_outliers_IQR(df, 'sqft_living')
#df = df.drop('sqft_above', axis=1)
# Out:
# dropping 5.31% data

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='price', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='sqft_living', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.histplot(data=df, x='sqft_living15', ax=ax, kde=True, alpha=0.1);

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
sns.scatterplot(data=df, x='sqft_living', y='price', ax=ax[0], alpha=0.3, color='red')
sns.scatterplot(data=df, x='sqft_living15', y='price', ax=ax[1], alpha=0.3, color='green')
# Out:
# <AxesSubplot:xlabel='sqft_living15', ylabel='price'>

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(data=df, x='long', y='lat', hue='price', palette='rocket_r',);

# %% [markdown]
# As it seems some regions here, have expensive houses, So we'll try to cluster each region.<br>
# We'll use "lat" and "long" and "price" to cluster each using K_mean clustering algorithm.

# %%
selected = df[['lat', 'long', 'price']]
ids = selected.index.values
selected = selected.values
selected.shape
# Out:
# (20297, 3)

# %%
centeroids, idx = k_mean_optimization(selected, 10, 30, 25)
# Out:
# Iteration 1/25
# Distortion: 709291720.465603
# Iteration 2/25
# Distortion: 830920856.0265139
# Iteration 3/25
# Distortion: 766760072.8117801
# Iteration 4/25
# Distortion: 693641549.365174
# Iteration 5/25
# Distortion: 793864873.2262777
# Iteration 6/25
# Distortion: 720440273.7178187
# Iteration 7/25
# Distortion: 717553048.9233866
# Iteration 8/25
# Distortion: 692571800.613913
# Iteration 9/25
# Distortion: 794398432.9161649
# Iteration 10/25
# Distortion: 715721258.5721724
# Iteration 11/25
# Distortion: 812838749.8915397
# Iteration 12/25
# Distortion: 792833410.6593095
# Iteration 13/25
# Distortion: 762230242.4361318
# Iteration 14/25
# Distortion: 696396732.9562678
# Iteration 15/25
# Distortion: 879742291.5258355
# Iteration 16/25
# Distortion: 693832498.0553436
# Iteration 17/25
# Distortion: 709184963.0931798
# Iteration 18/25
# Distortion: 695894046.8293705
# Iteration 19/25
# Distortion: 815155949.1005993
# Iteration 20/25
# Distortion: 701790802.03629
# Iteration 21/25
# Distortion: 711062038.9873432
# Iteration 22/25
# Distortion: 697404072.0423129
# Iteration 23/25
# Distortion: 736474847.7277439
# Iteration 24/25
# Distortion: 741106030.469866
# Iteration 25/25
# Distortion: 892417953.900595
#
# Distortion 692571800.613913 is chosen!

# %%
selected = np.c_[ids, selected, idx]
selected = pd.DataFrame(selected, columns=['id', 'lat', 'long', 'price', 'cluster'])
selected
# Out:
#                  id      lat     long     price  cluster
# 0      7.129301e+09  47.5112 -122.257  221900.0      0.0
# 1      6.414100e+09  47.7210 -122.319  538000.0      9.0
# 2      5.631500e+09  47.7379 -122.233  180000.0      0.0
# 3      2.487201e+09  47.5208 -122.393  604000.0      9.0
# 4      1.954401e+09  47.6168 -122.045  510000.0      7.0
# ...             ...      ...      ...       ...      ...
# 20292  2.630000e+08  47.6993 -122.346  360000.0      2.0
# 20293  6.600060e+09  47.5107 -122.362  400000.0      8.0
# 20294  1.523300e+09  47.5944 -122.299  402101.0      8.0
# 20295  2.913101e+08  47.5345 -122.069  400000.0      8.0
# 20296  1.523300e+09  47.5941 -122.299  325000.0      2.0
#
# [20297 rows x 5 columns]

# %%
selected.set_index('id', inplace=True)
selected
# Out:
#                   lat     long     price  cluster
# id
# 7.129301e+09  47.5112 -122.257  221900.0      0.0
# 6.414100e+09  47.7210 -122.319  538000.0      9.0
# 5.631500e+09  47.7379 -122.233  180000.0      0.0
# 2.487201e+09  47.5208 -122.393  604000.0      9.0
# 1.954401e+09  47.6168 -122.045  510000.0      7.0
# ...               ...      ...       ...      ...
# 2.630000e+08  47.6993 -122.346  360000.0      2.0
# 6.600060e+09  47.5107 -122.362  400000.0      8.0
# 1.523300e+09  47.5944 -122.299  402101.0      8.0
# 2.913101e+08  47.5345 -122.069  400000.0      8.0
# 1.523300e+09  47.5941 -122.299  325000.0      2.0
#
# [20297 rows x 4 columns]

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(data=selected, x='long', y='lat', hue='cluster', palette='tab10', size='price');

# %%
clusters = pd.get_dummies(data=selected.cluster, drop_first=True, prefix='cluster')
df = pd.concat([df, clusters], axis=1)

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), cmap='Blues');

# %%
df.describe().T
# Out:
#                  count           mean            std         min          25%  \
# bedrooms       20297.0       3.330246       0.911846      0.0000       3.0000
# bathrooms      20297.0       2.054084       0.711399      0.0000       1.5000
# sqft_living    20297.0    1978.235158     775.491728    290.0000    1400.0000
# sqft_lot       20297.0   14646.335173   40247.208902    520.0000    5000.0000
# floors         20297.0       1.477854       0.537484      1.0000       1.0000
# waterfront     20297.0       0.003005       0.054740      0.0000       0.0000
# view           20297.0       0.173622       0.642417      0.0000       0.0000
# condition      20297.0       3.407499       0.646790      1.0000       3.0000
# grade          20297.0       7.535498       1.038258      1.0000       7.0000
# sqft_above     20297.0    1710.736562     728.055167    290.0000    1180.0000
# sqft_basement  20297.0     267.498596     409.367450      0.0000       0.0000
# yr_built       20297.0    1970.910874      29.168739   1900.0000    1952.0000
# yr_renovated   20297.0      74.916539     379.343170      0.0000       0.0000
# zipcode        20297.0   98078.456373      53.304558  98001.0000   98033.0000
# lat            20297.0      47.556983       0.141081     47.1559      47.4604
# long           20297.0    -122.213026       0.142481   -122.5190    -122.3300
# sqft_living15  20297.0    1924.116126     615.531752    399.0000    1470.0000
# sqft_lot15     20297.0   12466.256590   26609.851181    651.0000    5040.0000
# year           20297.0    2014.318520       0.465914   2014.0000    2014.0000
# month          20297.0       6.595359       3.110196      1.0000       4.0000
# price          20297.0  477262.096369  208498.449648  75000.0000  315000.0000
# cluster_1.0    20297.0       0.026457       0.160494      0.0000       0.0000
# cluster_2.0    20297.0       0.152387       0.359405      0.0000       0.0000
# cluster_3.0    20297.0       0.046805       0.211226      0.0000       0.0000
# cluster_4.0    20297.0       0.152042       0.359071      0.0000       0.0000
# cluster_5.0    20297.0       0.088289       0.283722      0.0000       0.0000
# cluster_6.0    20297.0       0.069025       0.253503      0.0000       0.0000
# cluster_7.0    20297.0       0.116126       0.320383      0.0000       0.0000
# cluster_8.0    20297.0       0.146573       0.353689      0.0000       0.0000
# cluster_9.0    20297.0       0.112972       0.316567      0.0000       0.0000
#
#                        50%          75%           max
# bedrooms            3.0000       4.0000  3.300000e+01
# bathrooms           2.0000       2.5000  7.500000e+00
# sqft_living      1860.0000    2440.0000  7.480000e+03
# sqft_lot         7500.0000   10321.0000  1.651359e+06
# floors              1.0000       2.0000  3.500000e+00
# waterfront          0.0000       0.0000  1.000000e+00
# view                0.0000       0.0000  4.000000e+00
# condition           3.0000       4.0000  5.000000e+00
# grade               7.0000       8.0000  1.200000e+01
# sqft_above       1520.0000    2110.0000  5.710000e+03
# sqft_basement       0.0000     510.0000  2.720000e+03
# yr_built         1975.0000    1996.0000  2.015000e+03
# yr_renovated        0.0000       0.0000  2.015000e+03
# zipcode         98065.0000   98118.0000  9.819900e+04
# lat                47.5671      47.6798  4.777760e+01
# long             -122.2310    -122.1220 -1.213150e+02
# sqft_living15    1800.0000    2280.0000  5.380000e+03
# sqft_lot15       7539.0000    9891.0000  8.712000e+05
# year             2014.0000    2015.0000  2.015000e+03
# month               6.0000       9.0000  1.200000e+01
# price          437850.0000  601000.0000  1.127500e+06
# cluster_1.0         0.0000       0.0000  1.000000e+00
# cluster_2.0         0.0000       0.0000  1.000000e+00
# cluster_3.0         0.0000       0.0000  1.000000e+00
# cluster_4.0         0.0000       0.0000  1.000000e+00
# cluster_5.0         0.0000       0.0000  1.000000e+00
# cluster_6.0         0.0000       0.0000  1.000000e+00
# cluster_7.0         0.0000       0.0000  1.000000e+00
# cluster_8.0         0.0000       0.0000  1.000000e+00
# cluster_9.0         0.0000       0.0000  1.000000e+00

# %% [markdown]
# ## Getting Data ready for trainning

# %%
X_train = df.drop(['price'], axis=1).values
y_train = df['price'].values

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.8, random_state=123)
X_test, X_cv, y_test, y_cv = train_test_split(X_test, y_test, test_size=0.5, random_state=10)

# %%
print(f'X_train shape is {X_train.shape} and y_train shape is {y_train.shape}')
print(f'y_cv shape is {X_cv.shape} and y_cv shape is {y_cv.shape}')
print(f'X_test shape is {X_test.shape} and y_test shape is {y_test.shape}')
# Out:
# X_train shape is (16237, 29) and y_train shape is (16237,)
# y_cv shape is (2030, 29) and y_cv shape is (2030,)
# X_test shape is (2030, 29) and y_test shape is (2030,)

# %% [markdown]
# ### Normalize the data

# %%
norm = Normalization()
norm.adapt(X_train)
Xn_train = norm(X_train)
Xn_cv = norm(X_cv)
Xn_test = norm(X_test)

# %% [markdown]
# ## Training

# %%
regs = [0, 0.1, 1, 10, 100, 1e3, 1e4, 1e5, 1e6, 1e7]
hist = []
for reg in regs:
    print(f'applying regularization parameter {reg}')
    s = time.time() # calculating duration
    model = Sequential([
        tf.keras.Input(shape=(Xn_train.shape[1],)),
        Dense(units=200, activation='relu', name='layer1', kernel_regularizer=L2(reg)),
        Dense(units=100, activation='relu', name='layer2', kernel_regularizer=L2(reg)),
        Dense(units=50, activation='relu', name='layer3', kernel_regularizer=L2(reg)),
        Dense(units=1, activation='linear', name='output')
    ], name='My_Model')

    model.compile(
        loss=MeanSquaredError(),
        optimizer=Adam(learning_rate=0.05),
        metrics=[tf.keras.metrics.MeanAbsoluteError()]
    )

    model.fit(Xn_train, y_train, validation_data=[Xn_cv, y_cv], epochs=200, verbose=False)
    hist.append([
        model.evaluate(Xn_train, y_train),
        model.evaluate(Xn_cv, y_cv), 
        model.evaluate(Xn_test, y_test)
    ])
    e = time.time() # calculating duration
    print(f'duration ~ {e - s : 0.2f}')
# Out:
# applying regularization parameter 0
# 508/508 [==============================] - 0s 663us/step - loss: 559450816.0000 - mean_absolute_error: 18460.1973
# 64/64 [==============================] - 0s 649us/step - loss: 826122880.0000 - mean_absolute_error: 22412.1875
# 64/64 [==============================] - 0s 633us/step - loss: 844353024.0000 - mean_absolute_error: 22389.0566
# duration ~  86.87
# applying regularization parameter 0.1
# 508/508 [==============================] - 0s 659us/step - loss: 492731488.0000 - mean_absolute_error: 17647.6348
# 64/64 [==============================] - 0s 665us/step - loss: 823921920.0000 - mean_absolute_error: 22218.6465
# 64/64 [==============================] - 0s 665us/step - loss: 787012352.0000 - mean_absolute_error: 21855.7031
# duration ~  85.32
# applying regularization parameter 1
# 508/508 [==============================] - 0s 651us/step - loss: 493553920.0000 - mean_absolute_error: 17402.7500
# 64/64 [==============================] - 0s 665us/step - loss: 833514752.0000 - mean_absolute_error: 22257.2461
# 64/64 [==============================] - 0s 665us/step - loss: 846867200.0000 - mean_absolute_error: 22345.1113
# duration ~  85.60
# applying regularization parameter 10
# 508/508 [==============================] - 0s 637us/step - loss: 561263808.0000 - mean_absolute_error: 18486.3984
# 64/64 [==============================] - 0s 665us/step - loss: 772143104.0000 - mean_absolute_error: 21640.1582
# 64/64 [==============================] - 0s 681us/step - loss: 800276992.0000 - mean_absolute_error: 21848.0410
# duration ~  86.47
# applying regularization parameter 100
# 508/508 [==============================] - 0s 657us/step - loss: 609358656.0000 - mean_absolute_error: 19499.5234
# 64/64 [==============================] - 0s 649us/step - loss: 785458432.0000 - mean_absolute_error: 22087.6094
# 64/64 [==============================] - 0s 649us/step - loss: 772043520.0000 - mean_absolute_error: 22071.3203
# duration ~  86.44
# applying regularization parameter 1000.0
# 508/508 [==============================] - 0s 655us/step - loss: 640515264.0000 - mean_absolute_error: 20054.8867
# 64/64 [==============================] - 0s 665us/step - loss: 709186624.0000 - mean_absolute_error: 21133.7422
# 64/64 [==============================] - 0s 649us/step - loss: 691619072.0000 - mean_absolute_error: 20713.4648
# duration ~  85.62
# applying regularization parameter 10000.0
# 508/508 [==============================] - 0s 657us/step - loss: 851113024.0000 - mean_absolute_error: 22339.5840
# 64/64 [==============================] - 0s 665us/step - loss: 842113088.0000 - mean_absolute_error: 22358.4668
# 64/64 [==============================] - 0s 665us/step - loss: 836002560.0000 - mean_absolute_error: 21979.2676
# duration ~  85.56
# applying regularization parameter 100000.0
# 508/508 [==============================] - 0s 665us/step - loss: 865150272.0000 - mean_absolute_error: 22116.9688
# 64/64 [==============================] - 0s 649us/step - loss: 887834176.0000 - mean_absolute_error: 22468.3926
# 64/64 [==============================] - 0s 665us/step - loss: 863420288.0000 - mean_absolute_error: 22007.5215
# duration ~  86.12
# applying regularization parameter 1000000.0
# 508/508 [==============================] - 0s 647us/step - loss: 1033091520.0000 - mean_absolute_error: 21824.9160
# 64/64 [==============================] - 0s 649us/step - loss: 1034642368.0000 - mean_absolute_error: 21967.2207
# 64/64 [==============================] - 0s 649us/step - loss: 1064087680.0000 - mean_absolute_error: 21943.5039
# duration ~  85.70
# applying regularization parameter 10000000.0
# 508/508 [==============================] - 0s 655us/step - loss: 1801316224.0000 - mean_absolute_error: 23778.7109
# 64/64 [==============================] - 0s 649us/step - loss: 1800654080.0000 - mean_absolute_error: 23783.1719
# 64/64 [==============================] - 0s 681us/step - loss: 1810928640.0000 - mean_absolute_error: 23657.9629
# duration ~  86.01

# %%
hist = np.array(hist)
hist_loss = hist[:, :, 0]
hist_mae = hist[:, :, 1]

m, n = hist_loss.shape

plt.figure(figsize=(12, 10))
plt.plot(range(m), hist_mae[:, 0], label='Train')
plt.plot(range(m), hist_mae[:, 1], label='CV')
#plt.plot(range(m), hist_mae[:, 2], label='Test')
plt.axvline(x=6, marker="_", c='r', label='Best regularization parameter', alpha=0.5)
plt.title('MAE per Regularization parameter');
plt.xlabel('Regularization parameter index');
plt.ylabel('MAE');
ax = plt.gca()
ax.set_xticks(range(10))
ax.set_xticklabels([0, 0.1, 1, 10, 100, 1e3, 1e4, 1e5, 1e6, 1e7])
plt.legend();

# %%
reg = 10000
model = Sequential([
    tf.keras.Input(shape=(Xn_train.shape[1],)),
    Dense(units=200, activation='relu', name='layer1', kernel_regularizer=L2(reg)),
    Dense(units=100, activation='relu', name='layer2', kernel_regularizer=L2(reg)),
    Dense(units=50, activation='relu', name='layer3', kernel_regularizer=L2(reg)),
    Dense(units=1, activation='linear', name='output')
], name='My_Model')

model.compile(
    loss=MeanSquaredError(),
    optimizer=Adam(learning_rate=0.05),
    metrics=[tf.keras.metrics.MeanAbsoluteError()]
)

history = model.fit(Xn_train, y_train, validation_data=[Xn_cv, y_cv], epochs=100, verbose=True)
# Out:
# Epoch 1/100
# 508/508 [==============================] - 1s 1ms/step - loss: 12868985856.0000 - mean_absolute_error: 52783.7539 - val_loss: 3024785920.0000 - val_mean_absolute_error: 29439.8203
# Epoch 2/100
# 508/508 [==============================] - 1s 1ms/step - loss: 2580478208.0000 - mean_absolute_error: 27429.3965 - val_loss: 2583420672.0000 - val_mean_absolute_error: 26863.7012
# Epoch 3/100
# 508/508 [==============================] - 1s 1ms/step - loss: 2191230208.0000 - mean_absolute_error: 27560.3906 - val_loss: 2196597504.0000 - val_mean_absolute_error: 34717.9688
# Epoch 4/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1290424064.0000 - mean_absolute_error: 25838.3828 - val_loss: 974546816.0000 - val_mean_absolute_error: 23316.1621
# Epoch 5/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1216496768.0000 - mean_absolute_error: 25410.7285 - val_loss: 1049978752.0000 - val_mean_absolute_error: 24264.3086
# Epoch 6/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1160783104.0000 - mean_absolute_error: 24949.5430 - val_loss: 993712640.0000 - val_mean_absolute_error: 23132.6875
# Epoch 7/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1212608640.0000 - mean_absolute_error: 25561.9160 - val_loss: 1144418432.0000 - val_mean_absolute_error: 25066.3066
# Epoch 8/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1086420096.0000 - mean_absolute_error: 24261.3613 - val_loss: 989125440.0000 - val_mean_absolute_error: 23276.3301
# Epoch 9/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1159384320.0000 - mean_absolute_error: 24960.0352 - val_loss: 1092365312.0000 - val_mean_absolute_error: 24368.3945
# Epoch 10/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1135186304.0000 - mean_absolute_error: 24756.4473 - val_loss: 1317745408.0000 - val_mean_absolute_error: 27048.1230
# Epoch 11/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1092101888.0000 - mean_absolute_error: 24215.3086 - val_loss: 936018944.0000 - val_mean_absolute_error: 22662.0039
# Epoch 12/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1126180352.0000 - mean_absolute_error: 24567.1777 - val_loss: 959394240.0000 - val_mean_absolute_error: 22948.8926
# Epoch 13/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1090792448.0000 - mean_absolute_error: 24170.4980 - val_loss: 1172044800.0000 - val_mean_absolute_error: 25293.4805
# Epoch 14/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1061263104.0000 - mean_absolute_error: 24035.2051 - val_loss: 1789347328.0000 - val_mean_absolute_error: 32111.0332
# Epoch 15/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1075706496.0000 - mean_absolute_error: 24152.7734 - val_loss: 982627648.0000 - val_mean_absolute_error: 23669.5391
# Epoch 16/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1008715008.0000 - mean_absolute_error: 23444.2266 - val_loss: 876485248.0000 - val_mean_absolute_error: 22169.3105
# Epoch 17/100
# 508/508 [==============================] - 1s 1ms/step - loss: 986899520.0000 - mean_absolute_error: 23339.4824 - val_loss: 902677760.0000 - val_mean_absolute_error: 22683.0020
# Epoch 18/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1060592384.0000 - mean_absolute_error: 24125.2598 - val_loss: 953572928.0000 - val_mean_absolute_error: 23011.7676
# Epoch 19/100
# 508/508 [==============================] - 1s 1ms/step - loss: 1033438720.0000 - mean_absolute_error: 23798.0508 - val_loss: 893651520.0000 - val_mean_absolute_error: 22308.5410
# Epoch 20/100
# 508/508 [==============================] - 1s 1ms/step - loss: 983922880.0000 - mean_absolute_error: 23317.7676 - val_loss: 873008768.0000 - val_mean_absolute_error: 22303.6465
# Epoch 21/100
# 508/508 [==============================] - 1s 1ms/step - loss: 947465216.0000 - mean_absolute_error: 23013.8281 - val_loss: 860763008.0000 - val_mean_absolute_error: 21923.9648
# Epoch 22/100
# 508/508 [==============================] - 1s 1ms/step - loss: 978358912.0000 - mean_absolute_error: 23352.8730 - val_loss: 848689152.0000 - val_mean_absolute_error: 22340.4453
# Epoch 23/100
# 508/508 [==============================] - 1s 1ms/step - loss: 922515008.0000 - mean_absolute_error: 22899.5469 - val_loss: 898954304.0000 - val_mean_absolute_error: 22301.7402
# Epoch 24/100
# 508/508 [==============================] - 1s 1ms/step - loss: 904311872.0000 - mean_absolute_error: 22564.6211 - val_loss: 868239680.0000 - val_mean_absolute_error: 22423.2051
# Epoch 25/100
# 508/508 [==============================] - 1s 1ms/step - loss: 921805184.0000 - mean_absolute_error: 22767.3867 - val_loss: 892899136.0000 - val_mean_absolute_error: 22607.6230
# Epoch 26/100
# 508/508 [==============================] - 1s 1ms/step - loss: 895624320.0000 - mean_absolute_error: 22572.9395 - val_loss: 875593344.0000 - val_mean_absolute_error: 22411.6973
# Epoch 27/100
# 508/508 [==============================] - 1s 1ms/step - loss: 891646464.0000 - mean_absolute_error: 22592.8809 - val_loss: 1012457536.0000 - val_mean_absolute_error: 23813.4004
# Epoch 28/100
# 508/508 [==============================] - 1s 1ms/step - loss: 888941056.0000 - mean_absolute_error: 22564.3750 - val_loss: 1108943488.0000 - val_mean_absolute_error: 24805.4102
# Epoch 29/100
# 508/508 [==============================] - 1s 1ms/step - loss: 924169280.0000 - mean_absolute_error: 22996.7773 - val_loss: 990306176.0000 - val_mean_absolute_error: 24252.0488
# Epoch 30/100
# 508/508 [==============================] - 1s 1ms/step - loss: 901566208.0000 - mean_absolute_error: 22667.2676 - val_loss: 960084864.0000 - val_mean_absolute_error: 23894.9902
# Epoch 31/100
# 508/508 [==============================] - 1s 1ms/step - loss: 876688576.0000 - mean_absolute_error: 22545.4551 - val_loss: 1158777728.0000 - val_mean_absolute_error: 25812.9453
# Epoch 32/100
# 508/508 [==============================] - 1s 1ms/step - loss: 868654784.0000 - mean_absolute_error: 22446.4668 - val_loss: 1086448768.0000 - val_mean_absolute_error: 24182.8184
# Epoch 33/100
# 508/508 [==============================] - 1s 1ms/step - loss: 898954944.0000 - mean_absolute_error: 22798.0254 - val_loss: 1113578240.0000 - val_mean_absolute_error: 25378.5801
# Epoch 34/100
# 508/508 [==============================] - 1s 1ms/step - loss: 892368704.0000 - mean_absolute_error: 22788.4316 - val_loss: 952561024.0000 - val_mean_absolute_error: 23849.0703
# Epoch 35/100
# 508/508 [==============================] - 1s 1ms/step - loss: 872262464.0000 - mean_absolute_error: 22549.7012 - val_loss: 814340672.0000 - val_mean_absolute_error: 22016.6230
# Epoch 36/100
# 508/508 [==============================] - 1s 1ms/step - loss: 859997632.0000 - mean_absolute_error: 22441.2969 - val_loss: 804313664.0000 - val_mean_absolute_error: 22011.3867
# Epoch 37/100
# 508/508 [==============================] - 1s 1ms/step - loss: 877940544.0000 - mean_absolute_error: 22648.9277 - val_loss: 799235968.0000 - val_mean_absolute_error: 21805.5020
# Epoch 38/100
# 508/508 [==============================] - 1s 1ms/step - loss: 853450624.0000 - mean_absolute_error: 22287.2695 - val_loss: 954660608.0000 - val_mean_absolute_error: 23655.9629
# Epoch 39/100
# 508/508 [==============================] - 1s 1ms/step - loss: 852664896.0000 - mean_absolute_error: 22246.0664 - val_loss: 1031776000.0000 - val_mean_absolute_error: 24391.4199
# Epoch 40/100
# 508/508 [==============================] - 1s 1ms/step - loss: 856092544.0000 - mean_absolute_error: 22373.7578 - val_loss: 826083904.0000 - val_mean_absolute_error: 21987.7480
# Epoch 41/100
# 508/508 [==============================] - 1s 1ms/step - loss: 855566016.0000 - mean_absolute_error: 22383.0938 - val_loss: 923022208.0000 - val_mean_absolute_error: 23466.6484
# Epoch 42/100
# 508/508 [==============================] - 1s 1ms/step - loss: 848677888.0000 - mean_absolute_error: 22303.3203 - val_loss: 907070528.0000 - val_mean_absolute_error: 22774.8906
# Epoch 43/100
# 508/508 [==============================] - 1s 1ms/step - loss: 850580224.0000 - mean_absolute_error: 22243.7480 - val_loss: 842022208.0000 - val_mean_absolute_error: 22266.7812
# Epoch 44/100
# 508/508 [==============================] - 1s 1ms/step - loss: 856613952.0000 - mean_absolute_error: 22444.1816 - val_loss: 779467776.0000 - val_mean_absolute_error: 21784.6660
# Epoch 45/100
# 508/508 [==============================] - 1s 1ms/step - loss: 870938112.0000 - mean_absolute_error: 22550.2617 - val_loss: 893670272.0000 - val_mean_absolute_error: 23307.3379
# Epoch 46/100
# 508/508 [==============================] - 1s 1ms/step - loss: 826807872.0000 - mean_absolute_error: 22140.7051 - val_loss: 872671040.0000 - val_mean_absolute_error: 22401.2090
# Epoch 47/100
# 508/508 [==============================] - 1s 1ms/step - loss: 829214848.0000 - mean_absolute_error: 22114.1523 - val_loss: 793501376.0000 - val_mean_absolute_error: 21721.2832
# Epoch 48/100
# 508/508 [==============================] - 1s 1ms/step - loss: 853319744.0000 - mean_absolute_error: 22460.1777 - val_loss: 830166336.0000 - val_mean_absolute_error: 22150.4316
# Epoch 49/100
# 508/508 [==============================] - 1s 1ms/step - loss: 838859136.0000 - mean_absolute_error: 22237.6562 - val_loss: 757988928.0000 - val_mean_absolute_error: 21527.4355
# Epoch 50/100
# 508/508 [==============================] - 1s 1ms/step - loss: 831857728.0000 - mean_absolute_error: 22101.9375 - val_loss: 808502528.0000 - val_mean_absolute_error: 22007.0176
# Epoch 51/100
# 508/508 [==============================] - 1s 1ms/step - loss: 838360576.0000 - mean_absolute_error: 22301.3516 - val_loss: 937926464.0000 - val_mean_absolute_error: 23701.3516
# Epoch 52/100
# 508/508 [==============================] - 1s 1ms/step - loss: 825982272.0000 - mean_absolute_error: 22139.0039 - val_loss: 853089792.0000 - val_mean_absolute_error: 22474.1641
# Epoch 53/100
# 508/508 [==============================] - 1s 1ms/step - loss: 846441792.0000 - mean_absolute_error: 22355.7324 - val_loss: 942890752.0000 - val_mean_absolute_error: 23539.8652
# Epoch 54/100
# 508/508 [==============================] - 1s 1ms/step - loss: 816982720.0000 - mean_absolute_error: 22087.4082 - val_loss: 812505536.0000 - val_mean_absolute_error: 22070.1367
# Epoch 55/100
# 508/508 [==============================] - 1s 1ms/step - loss: 842063552.0000 - mean_absolute_error: 22339.2988 - val_loss: 909526400.0000 - val_mean_absolute_error: 23100.5898
# Epoch 56/100
# 508/508 [==============================] - 1s 1ms/step - loss: 824555072.0000 - mean_absolute_error: 22164.9277 - val_loss: 802536576.0000 - val_mean_absolute_error: 21882.9590
# Epoch 57/100
# 508/508 [==============================] - 1s 1ms/step - loss: 814137024.0000 - mean_absolute_error: 21961.7871 - val_loss: 773886400.0000 - val_mean_absolute_error: 21615.1816
# Epoch 58/100
# 508/508 [==============================] - 1s 1ms/step - loss: 819856704.0000 - mean_absolute_error: 22084.8457 - val_loss: 798127232.0000 - val_mean_absolute_error: 22067.2520
# Epoch 59/100
# 508/508 [==============================] - 1s 1ms/step - loss: 812217344.0000 - mean_absolute_error: 21983.3906 - val_loss: 791409152.0000 - val_mean_absolute_error: 21837.1523
# Epoch 60/100
# 508/508 [==============================] - 1s 1ms/step - loss: 809311488.0000 - mean_absolute_error: 21963.9414 - val_loss: 780202560.0000 - val_mean_absolute_error: 21822.8594
# Epoch 61/100
# 508/508 [==============================] - 1s 1ms/step - loss: 828946304.0000 - mean_absolute_error: 22234.6758 - val_loss: 1048196544.0000 - val_mean_absolute_error: 24978.8105
# Epoch 62/100
# 508/508 [==============================] - 1s 1ms/step - loss: 810750016.0000 - mean_absolute_error: 22023.2578 - val_loss: 784896640.0000 - val_mean_absolute_error: 21986.2402
# Epoch 63/100
# 508/508 [==============================] - 1s 1ms/step - loss: 824964032.0000 - mean_absolute_error: 22211.4902 - val_loss: 780446464.0000 - val_mean_absolute_error: 21767.7441
# Epoch 64/100
# 508/508 [==============================] - 1s 1ms/step - loss: 832783936.0000 - mean_absolute_error: 22327.2168 - val_loss: 889744320.0000 - val_mean_absolute_error: 22478.6016
# Epoch 65/100
# 508/508 [==============================] - 1s 1ms/step - loss: 827257472.0000 - mean_absolute_error: 22253.3047 - val_loss: 802089920.0000 - val_mean_absolute_error: 21898.3945
# Epoch 66/100
# 508/508 [==============================] - 1s 1ms/step - loss: 820306048.0000 - mean_absolute_error: 22214.7539 - val_loss: 862258176.0000 - val_mean_absolute_error: 22387.1250
# Epoch 67/100
# 508/508 [==============================] - 1s 1ms/step - loss: 821527616.0000 - mean_absolute_error: 22155.5137 - val_loss: 773240704.0000 - val_mean_absolute_error: 21706.4141
# Epoch 68/100
# 508/508 [==============================] - 1s 1ms/step - loss: 816981248.0000 - mean_absolute_error: 22147.0996 - val_loss: 776189696.0000 - val_mean_absolute_error: 21781.5137
# Epoch 69/100
# 508/508 [==============================] - 1s 1ms/step - loss: 806396224.0000 - mean_absolute_error: 21976.3242 - val_loss: 807402496.0000 - val_mean_absolute_error: 22177.9023
# Epoch 70/100
# 508/508 [==============================] - 1s 1ms/step - loss: 831377984.0000 - mean_absolute_error: 22362.2734 - val_loss: 793086848.0000 - val_mean_absolute_error: 22074.3301
# Epoch 71/100
# 508/508 [==============================] - 1s 1ms/step - loss: 808613632.0000 - mean_absolute_error: 22010.1230 - val_loss: 794171328.0000 - val_mean_absolute_error: 21890.3145
# Epoch 72/100
# 508/508 [==============================] - 1s 1ms/step - loss: 821744192.0000 - mean_absolute_error: 22223.0488 - val_loss: 759766848.0000 - val_mean_absolute_error: 21586.6035
# Epoch 73/100
# 508/508 [==============================] - 1s 1ms/step - loss: 797282432.0000 - mean_absolute_error: 22001.8340 - val_loss: 994684416.0000 - val_mean_absolute_error: 24618.6367
# Epoch 74/100
# 508/508 [==============================] - 1s 1ms/step - loss: 822700800.0000 - mean_absolute_error: 22264.1621 - val_loss: 763054848.0000 - val_mean_absolute_error: 21844.6074
# Epoch 75/100
# 508/508 [==============================] - 1s 1ms/step - loss: 794846144.0000 - mean_absolute_error: 21939.5918 - val_loss: 771086784.0000 - val_mean_absolute_error: 21703.3496
# Epoch 76/100
# 508/508 [==============================] - 1s 1ms/step - loss: 816552448.0000 - mean_absolute_error: 22231.0156 - val_loss: 812721344.0000 - val_mean_absolute_error: 22109.4219
# Epoch 77/100
# 508/508 [==============================] - 1s 1ms/step - loss: 795119296.0000 - mean_absolute_error: 21934.2305 - val_loss: 789957632.0000 - val_mean_absolute_error: 21777.1113
# Epoch 78/100
# 508/508 [==============================] - 1s 1ms/step - loss: 798816000.0000 - mean_absolute_error: 21938.6738 - val_loss: 760575296.0000 - val_mean_absolute_error: 21656.8086
# Epoch 79/100
# 508/508 [==============================] - 1s 1ms/step - loss: 817033920.0000 - mean_absolute_error: 22243.8770 - val_loss: 755632128.0000 - val_mean_absolute_error: 21562.1816
# Epoch 80/100
# 508/508 [==============================] - 1s 1ms/step - loss: 797756480.0000 - mean_absolute_error: 22006.6055 - val_loss: 768345664.0000 - val_mean_absolute_error: 21586.6367
# Epoch 81/100
# 508/508 [==============================] - 1s 1ms/step - loss: 795052160.0000 - mean_absolute_error: 22042.7559 - val_loss: 827269696.0000 - val_mean_absolute_error: 22688.6445
# Epoch 82/100
# 508/508 [==============================] - 1s 1ms/step - loss: 817811072.0000 - mean_absolute_error: 22246.2129 - val_loss: 969052288.0000 - val_mean_absolute_error: 24151.1211
# Epoch 83/100
# 508/508 [==============================] - 1s 1ms/step - loss: 795725696.0000 - mean_absolute_error: 21973.3320 - val_loss: 809151104.0000 - val_mean_absolute_error: 22033.2520
# Epoch 84/100
# 508/508 [==============================] - 1s 1ms/step - loss: 785724928.0000 - mean_absolute_error: 21944.5117 - val_loss: 868471488.0000 - val_mean_absolute_error: 23075.7422
# Epoch 85/100
# 508/508 [==============================] - 1s 1ms/step - loss: 808501504.0000 - mean_absolute_error: 22116.5938 - val_loss: 764961600.0000 - val_mean_absolute_error: 21802.7402
# Epoch 86/100
# 508/508 [==============================] - 1s 1ms/step - loss: 792331648.0000 - mean_absolute_error: 21986.4277 - val_loss: 771070080.0000 - val_mean_absolute_error: 21860.2520
# Epoch 87/100
# 508/508 [==============================] - 1s 1ms/step - loss: 785202688.0000 - mean_absolute_error: 21922.8672 - val_loss: 966519680.0000 - val_mean_absolute_error: 24062.8848
# Epoch 88/100
# 508/508 [==============================] - 1s 1ms/step - loss: 819620032.0000 - mean_absolute_error: 22267.7383 - val_loss: 764361920.0000 - val_mean_absolute_error: 21611.5332
# Epoch 89/100
# 508/508 [==============================] - 1s 1ms/step - loss: 793301952.0000 - mean_absolute_error: 22018.4414 - val_loss: 821725696.0000 - val_mean_absolute_error: 22381.7188
# Epoch 90/100
# 508/508 [==============================] - 1s 1ms/step - loss: 787493120.0000 - mean_absolute_error: 21948.4297 - val_loss: 784276224.0000 - val_mean_absolute_error: 21835.1777
# Epoch 91/100
# 508/508 [==============================] - 1s 1ms/step - loss: 778752256.0000 - mean_absolute_error: 21892.2109 - val_loss: 750553088.0000 - val_mean_absolute_error: 21456.9531
# Epoch 92/100
# 508/508 [==============================] - 1s 1ms/step - loss: 785359872.0000 - mean_absolute_error: 21966.0957 - val_loss: 825090880.0000 - val_mean_absolute_error: 22235.4082
# Epoch 93/100
# 508/508 [==============================] - 1s 1ms/step - loss: 791633664.0000 - mean_absolute_error: 22004.8418 - val_loss: 761180992.0000 - val_mean_absolute_error: 21886.4766
# Epoch 94/100
# 508/508 [==============================] - 1s 1ms/step - loss: 795617664.0000 - mean_absolute_error: 22043.4277 - val_loss: 747772992.0000 - val_mean_absolute_error: 21648.3105
# Epoch 95/100
# 508/508 [==============================] - 1s 1ms/step - loss: 796321216.0000 - mean_absolute_error: 22088.5547 - val_loss: 751162048.0000 - val_mean_absolute_error: 21624.8359
# Epoch 96/100
# 508/508 [==============================] - 1s 1ms/step - loss: 785008384.0000 - mean_absolute_error: 21991.1562 - val_loss: 792250560.0000 - val_mean_absolute_error: 22168.6387
# Epoch 97/100
# 508/508 [==============================] - 1s 1ms/step - loss: 804489472.0000 - mean_absolute_error: 22159.2207 - val_loss: 854758848.0000 - val_mean_absolute_error: 22777.0332
# Epoch 98/100
# 508/508 [==============================] - 1s 1ms/step - loss: 779734720.0000 - mean_absolute_error: 21972.7793 - val_loss: 731184832.0000 - val_mean_absolute_error: 21475.5996
# Epoch 99/100
# 508/508 [==============================] - 1s 1ms/step - loss: 807904704.0000 - mean_absolute_error: 22175.1211 - val_loss: 753743936.0000 - val_mean_absolute_error: 21602.9375
# Epoch 100/100
# 508/508 [==============================] - 1s 1ms/step - loss: 782229952.0000 - mean_absolute_error: 21898.4453 - val_loss: 752844352.0000 - val_mean_absolute_error: 21858.6211

# %%
losses = np.array(history.history['loss'])
MAE = np.array(history.history['mean_absolute_error'])
val_losses = np.array(history.history['val_loss'])
val_MAE = np.array(history.history['val_mean_absolute_error'])

plt.figure(figsize=(15, 8))
plt.plot(range(MAE.size), MAE, label='MAE');
plt.plot(range(val_MAE.size), val_MAE, label='CV MAE');
plt.title('MAE value in each step')
plt.xlabel('Epoch');
plt.ylabel('MAE');
plt.legend();

# %%
J_abs_train = model.evaluate(Xn_train, y_train, verbose=False)[1]
J_abs_cv = model.evaluate(Xn_cv, y_cv, verbose=False)[1]
J_abs_test = model.evaluate(Xn_test, y_test, verbose=False)[1]

print(f'Absolute error for training set is {J_abs_train}')
print(f'Absolute error for cross validation set is {J_abs_cv}')
print(f'Absolute error for test set is {J_abs_test}')
# Out:
# Absolute error for training set is 21516.052734375
# Absolute error for cross validation set is 21858.62109375
# Absolute error for test set is 21401.8046875

# %%
fig, ax = plt.subplots(6, 3, figsize=(15, 30))
m, n = Xn_train.shape
cnt = 0
for ax in ax.flatten():
    try:
        if cnt >= n:
            ax.set_visible(False)
            continue
        newy = model.predict(Xn_train, verbose=False);
        ax.scatter(X_train[:, cnt], y_train, alpha=0.2)
        ax.scatter(X_train[:, cnt], newy, alpha=0.1, c='orange')
        ax.set_title(df.drop('price', axis=1).columns[cnt])
        cnt += 1
    except:
        ax.set_visible(False)
        continue

# %%
X_all = df.drop(['price'], axis=1).values
Xn_all = norm(X_all)
p_df = df.copy(deep=True)
p_df['Predicted'] = model.predict(Xn_all).astype('int64')
p_df
# Out:
# 635/635 [==============================] - 0s 613us/step
#               bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# id
# 7.129301e+09         3       1.00         1180      5650     1.0           0
# 6.414100e+09         3       2.25         2570      7242     2.0           0
# 5.631500e+09         2       1.00          770     10000     1.0           0
# 2.487201e+09         4       3.00         1960      5000     1.0           0
# 1.954401e+09         3       2.00         1680      8080     1.0           0
# ...                ...        ...          ...       ...     ...         ...
# 2.630000e+08         3       2.50         1530      1131     3.0           0
# 6.600060e+09         4       2.50         2310      5813     2.0           0
# 1.523300e+09         2       0.75         1020      1350     2.0           0
# 2.913101e+08         3       2.50         1600      2388     2.0           0
# 1.523300e+09         2       0.75         1020      1076     2.0           0
#
#               view  condition  grade  sqft_above  ...  cluster_1.0  \
# id                                                ...
# 7.129301e+09     0          3      7        1180  ...            0
# 6.414100e+09     0          3      7        2170  ...            0
# 5.631500e+09     0          3      6         770  ...            0
# 2.487201e+09     0          5      7        1050  ...            0
# 1.954401e+09     0          3      8        1680  ...            0
# ...            ...        ...    ...         ...  ...          ...
# 2.630000e+08     0          3      8        1530  ...            0
# 6.600060e+09     0          3      8        2310  ...            0
# 1.523300e+09     0          3      7        1020  ...            0
# 2.913101e+08     0          3      8        1600  ...            0
# 1.523300e+09     0          3      7        1020  ...            0
#
#               cluster_2.0  cluster_3.0  cluster_4.0  cluster_5.0  cluster_6.0  \
# id
# 7.129301e+09            0            0            0            0            0
# 6.414100e+09            0            0            0            0            0
# 5.631500e+09            0            0            0            0            0
# 2.487201e+09            0            0            0            0            0
# 1.954401e+09            0            0            0            0            0
# ...                   ...          ...          ...          ...          ...
# 2.630000e+08            1            0            0            0            0
# 6.600060e+09            0            0            0            0            0
# 1.523300e+09            0            0            0            0            0
# 2.913101e+08            0            0            0            0            0
# 1.523300e+09            1            0            0            0            0
#
#               cluster_7.0  cluster_8.0  cluster_9.0  Predicted
# id
# 7.129301e+09            0            0            0     199827
# 6.414100e+09            0            0            1     578993
# 5.631500e+09            0            0            0     206579
# 2.487201e+09            0            0            1     576936
# 1.954401e+09            1            0            0     492457
# ...                   ...          ...          ...        ...
# 2.630000e+08            0            0            0     354220
# 6.600060e+09            0            1            0     426543
# 1.523300e+09            0            1            0     416386
# 2.913101e+08            0            1            0     428772
# 1.523300e+09            0            0            0     340619
#
# [20297 rows x 31 columns]

# %%
p_df.to_csv('output_NN.csv', index=True)
