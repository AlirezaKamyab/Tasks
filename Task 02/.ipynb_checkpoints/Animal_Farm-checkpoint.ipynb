# %%
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')
# Out:
# 2022-10-04 15:54:52.571392: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-04 15:54:52.571415: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-04 15:54:54.005324: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-04 15:54:54.005834: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-04 15:54:54.005915: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-10-04 15:54:54.005962: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-10-04 15:54:54.006007: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-10-04 15:54:54.006052: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-10-04 15:54:54.006097: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-10-04 15:54:54.006141: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-10-04 15:54:54.006186: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-10-04 15:54:54.006194: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# %pip install PyPDF2
import PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyPDF2 in /home/alireza/.local/lib/python3.10/site-packages (2.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
f = open(r'animal-farm.pdf', 'rb')

# %%
animal_farm = PyPDF2.PdfFileReader(f)

# %%
animal_farm.getNumPages()
# Out:
# 56

# %%
chapters = []

start = 4
end_chapters = [9, 14, 18, 21, 26, 31, 37, 44, 50, 56]
text = ""
for cn in range(0, 10):
  print(f'chapter {cn + 1}')
  text = ""
  for p in range(start, animal_farm.getNumPages()):
    print(f'\rPage:{p}')
    text += animal_farm.getPage(p).extract_text()
    if end_chapters[cn] - 1 == p:
      chapters.append(text)
      start = end_chapters[cn]
      break
# Out:
# chapter 1
# Page:4
# Page:5
# Page:6
# Page:7
# Page:8
# chapter 2
# Page:9
# Page:10
# Page:11
# Page:12
# Page:13
# chapter 3
# Page:14
# Page:15
# Page:16
# Page:17
# chapter 4
# Page:18
# Page:19
# Page:20
# chapter 5
# Page:21
# Page:22
# Page:23
# Page:24
# Page:25
# chapter 6
# Page:26
# Page:27
# Page:28
# Page:29
# Page:30
# chapter 7
# Page:31
# Page:32
# Page:33
# Page:34
# Page:35
# Page:36
# chapter 8
# Page:37
# Page:38
# Page:39
# Page:40
# Page:41
# Page:42
# Page:43
# chapter 9
# Page:44
# Page:45
# Page:46
# Page:47
# Page:48
# Page:49
# chapter 10
# Page:50
# Page:51
# Page:52
# Page:53
# Page:54
# Page:55

# %%
print(chapters[1])
# Out:
# Chapter Two
#   Three nights later old Major died peacefully in his sleep. His body was buried at the foot of the orchard. This was early in March. During the next three months there was much secret activity. Major's speech had given to the more intelligent animals on the farm a completely new outlook on life. They did not know when the Rebellion predicted by Major would take place, they had no reason for thinking that it would be within their own lifetime, but they saw clearly that it was their duty to prepare for it. The work of teaching and organising the others fell naturally upon the pigs, who were generally recognised as being the cleverest of the animals. Pre-eminent among the pigs were two young boars named Snowball and Napoleon, whom Mr. Jones was breeding up for sale. Napoleon was a large, rather fierce-looking Berkshire boar, the only Berkshire on the farm, not much of a talker, but with a reputation for getting his own way. Snowball was a more vivacious pig than Napoleon, quicker in speech and more inventive, but was not considered to have the same depth of character. All the other male pigs on the farm were porkers. The best known among them was a small fat pig named Squealer, with very round cheeks, twinkling eyes, nimble movements, and a shrill voice. He was a brilliant talker, and when he was arguing some difficult point he had a way of skipping from side to side and whisking his tail which was somehow very persuasive. The others said of Squealer that he could turn black into white.  These three had elaborated old Major's teachings into a complete system of thought, to which they gave the name of Animalism. Several nights a week, after Mr. Jones was asleep, they held secret meetings in the barn and expounded the principles of Animalism to the others. At the beginning they met with much stupidity and apathy. Some of the animals talked of the of loyalty to Mr. Jones, whom they referred to as "Master," or made elementary remarks such as "Mr. Jones feeds us. If he were gone, we should starve to death." Others asked such questions as "Why should we care what happens after we are dead?" or "If this Rebellion is to happen anyway, what difference does it make whether we work for it or not?", and the pigs had great difficulty in making them see that this was contrary to the spirit of Animalism. The stupidest questions of all were asked by Mollie, the white mare. The very first question she asked Snowball was: "Will there still be sugar after the Rebellion?" "No," said Snowball firmly. "We have no means of making sugar on this farm. Besides,  you do not need sugar. You will have all the oats and hay you want."  "And shall I still be allowed to wear ribbons in my mane?" asked Mollie.  "Comrade," said Snowball, "those ribbons that you are so devoted to are the badge of slavery. Can you not understand that liberty is worth more than ribbons?"  Mollie agreed, but she did not sound very convinced.  The pigs had an even harder struggle to counteract the lies put about by Moses, the tame raven. Moses, who was Mr. Jones's especial pet, was a spy and a tale- bearer, but he was also a clever talker. He claimed to know of the existence of a mysterious country
# 6called Sugarcandy Mountain, to which all animals went when they died. It was situated somewhere up in the sky, a little distance beyond the clouds, Moses said. In Sugarcandy Mountain it was Sunday seven days a week, clover was in season all the year round, and lump sugar and linseed cake grew on the hedges. The animals hated Moses because he told tales and did no work, but some of them believed in Sugarcandy Mountain, and the pigs had to argue very hard to persuade them that there was no such place.  Their most faithful disciples were the two cart- horses, Boxer and Clover. These two had great difficulty in thinking anything out for themselves, but having once accepted the pigs as their teachers, they absorbed everything that they were told, and passed it on to the other animals by simple arguments. They were unfailing in their attendance at the secret meetings in the barn, and led the singing of  Beasts of England, with which the meetings always ended. Now, as it turned out, the Rebellion was achieved much earlier and more easily than anyone had expected. In past years Mr. Jones, although a hard master, had been a capable farmer, but of late he had fallen on evil days. He had become much disheartened after losing money in a lawsuit, and had taken to drinking more than was good for him. For whole days at a time he would lounge in his Windsor chair in the kitchen, reading the newspapers, drinking, and occasionally feeding Moses on crusts of bread soaked in beer. His men were idle and dishonest, the fields were full of weeds, the buildings wanted roofing, the hedges were neglected, and the animals were underfed.  June came and the hay was almost ready for cutting. On Midsummer's Eve, which was a Saturday, Mr. Jones went into Willingdon and got so drunk at the Red Lion that he did not come back till midday on Sunday. The men had milked the cows in the early morning and then had gone out rabbiting, without bothering to feed the animals. When Mr. Jones got back he immediately went to sleep on the drawing -room sofa with the News of the World over his face, so that when evening came, the animals were still unfed. At last they could stand it no longer. One of the cows broke in the door of the store-shed with her horn and all the animals began to help themselves from the bins. It was just then that Mr. Jones woke up. The next moment he and his four men were in the store-shed with whips in their hands, lashing out in all directions. This was more than the hungry animals could bear. With one accord, though nothing of the kind had been planned beforehand, they flung themselves upon their tormentors. Jones and his men suddenly found themselves being butted and kicked from all sides.  The situation was quite out of their control. They had never seen animals behave like this before, and this sudden uprising of creatures whom they were used to thrashing and maltreating just as they chose, frightened them almost out of their wits. After only a moment or two they gave up trying to defend themselves and took to their heels. A minute later all five of them were in full flight down the cart-track that led to the main road, with the animals pursuing them in triumph. Mrs. Jones looked out of the bedroom window, saw what was happening, hurriedly flung a few possessions into a carpet bag, and slipped out of the farm by another way. Moses sprang off his perch and flapped after her, croaking loudly. Meanwhile the animals had chased Jones and his men out on to the road and slammed the five- barred gate behind them. And so, almost before they knew what was happening, the Rebellion had been successfully carried through: Jones was expelled, and the Manor Farm was theirs.
# 7For the first few minutes the animals could hardly believe in their good fortune. Their first act was to gallop in a body right round the boundaries of the farm, as though to make quite sure that no human being was hiding anywhere upon it; then they raced back to the farm buildings to wipe out the last traces of Jones's hated reign. The harness-room at the end of the stables was broken open; the bits, the nose- rings, the dog-chains, the cruel knives with which Mr. Jones had been used to castrate the pigs and lambs, were all flung down the well. The reins, the halters, the blinkers, the degrading nosebags, were thrown on to the rubbish fire which was burning in the yard. So were the whips. All the animals capered with joy when they saw the whips going up in flames. Snowball also threw on to the fire the ribbons with which the horses' manes and tails had usually been decorated on market days. "Ribbons," he said, "should be considered as clothes, which are the mark of a human being. All animals should go naked."  When Boxer heard this he fetched the small straw hat which he wore in summer to keep the flies out of his ears, and flung it on to the fire with the rest.  In a very little while the animals had destroyed everything that reminded them of Mr. Jones. Napoleon then led them back to the store- shed and served out a double ration of corn to everybody, with two biscuits for each dog. Then they sang  Beasts of England from end to end seven times running, and after that they settled down for the night and slept as they had never slept before. But they woke at dawn as usual, and suddenly remembering the glorious thing that had happened, they all raced out into the pasture together. A little way down the pasture there was a knoll that commanded a view of most of the farm. The animals rushed to the top of it and gazed round them in the clear morning light. Yes, it was theirs —everything that they could see was theirs! In the ecstasy of that thought they gambolled round and round, they hurled themselves into the air in great leaps of excitement. They rolled in the dew, they cropped mouthfuls of the sweet summer grass, they kicked up clods of the black earth and snuffed its rich scent. Then they made a tour of inspection of the whole farm and surveyed with speechless admiration the ploughland, the hayfield, the orchard, the pool, the spinney. It was as though they had never seen these things before, and even now they could hardly believe that it was all their own.  Then they filed back to the farm buildings and halted in silence outside the door of the farmhouse. That was theirs too, but they were frightened to go inside. After a moment, however, Snowball and Napoleon butted the door open with their shoulders and the animals entered in single file, walking with the utmost care for fear of disturbing anything. They tip-toed from room to room, afraid to speak above a whisper and gazing with a kind of awe at the unbelievable luxury, at the beds with their feather mattresses, the looking-glasses, the horsehair sofa, the Brussels carpet, the lithograph of Queen Victoria over the drawing-room mantelpiece. They were just coming down the stairs when Mollie was discovered to be missing. Going back, the others found that she had remained behind in the best bedroom. She had taken a piece of blue ribbon from Mrs. Jones's dressing-table, and was holding it against her shoulder and admiring herself in the glass in a very foolish manner. The others reproached her sharply, and they went outside. Some hams hanging in the kitchen were taken out for burial, and the barrel of beer in the scullery was stove in with a kick from Boxer's hoof, otherwise nothing in the house was touched. A unanimous resolution was passed on the spot that the farmhouse should be preserved as a museum. All were agreed that no animal must ever live there.
# 8The animals had their breakfast, and then Snowball and Napoleon called them together again. "Comrades," said Snowball, "it is half-past six and we have a long day before us. Today we begin the hay harvest. But there is another matter that must be attended to first."  The pigs now revealed that during the past three months they had taught themselves to read and write from an old spelling book which had belonged to Mr. Jones's children and which had been thrown on the rubbish heap. Napoleon sent for pots of black and white paint and led the way down to the five-barred gate that gave on to the main road. Then Snowball (for it was Snowball who was best at writing) took a brush between the two knuckles of his trotter, painted out MANOR FARM from the top bar of the gate and in its place painted ANIMAL FARM. This was to be the name of the farm from now onwards. After this they went back to the farm buildings, where Snowball and Napoleon sent for a ladder which they caused to be set against the end wall of the big barn. They explained that by their studies of the past three months the pigs had succeeded in reducing the principles of Animalism to Seven Commandments. These Seven Commandments would now be inscribed on the wall; they would form an unalterable law by which all the animals on Animal Farm must live for ever after. With some difficulty (for it is not easy for a pig to balance himself  on a ladder) Snowball climbed up and set to work, with Squealer a few rungs below him holding the paint- pot. The Commandments were written on the tarred wall in great white letters that could be read thirty yards away. They ran thus: THE SEVEN COMMANDMENTS 1. Whatever goes upon two legs is an enemy. 2. Whatever goes upon four legs, or has wings, is a friend.  3. No animal shall wear clothes. 4. No animal shall sleep in a bed. 5. No animal shall drink alcohol. 6. No animal shall kill any other animal. 7. All animals are equal. It was very neatly written, and except that "friend" was written "freind" and one of the "S's" was the wrong way round, the spelling was correct all the way through. Snowball read it aloud for the benefit of the others. All the animals nodded in complete agreement, and the cleverer ones at once began to learn the Commandments by heart.  "Now, comrades," cried Snowball, throwing down the paint- brush, "to the hayfield! Let us make it a point of honour to get in the harvest more quickly  than Jones and his men could do." But at this moment the three cows, who had seemed uneasy for some time past, set up a loud lowing. They had not been milked for twenty -four hours, and their udders were almost bursting. After a little thought, the pigs sent for buckets and milked the cows fairly successfully, their trotters being well adapted to this task. Soon there were five buckets of frothing creamy milk at which many of the animals looked with considerable interest. "What is going to happen to all that milk?" said someone.  "Jones used sometimes to mix some of it in our mash," said one of the hens.
# 9"Never mind the milk, comrades!" cried Napoleon, placing himself in front of the buckets. "That will be attended to. The harvest is more important. Comrade S nowball will lead the way. I shall follow in a few minutes. Forward, comrades! The hay is waiting." So the animals trooped down to the hayfield to begin the harvest, and when they came back in the evening it was noticed that the milk had disappeared.
#
# 10

# %% [markdown]
# <h2>Functions</h2>
# Define functions to process the text

# %%
def token_frequency(txt, not_include=[], only_include=[], verbos=False):
    if len(not_include) != 0 and len(only_include) != 0: 
        raise Exception('Cannot specify both "not_include" and "only_include"')
    words = dict()
    doc = nlp(txt)
    for token in doc:
        if token.pos_ in not_include: continue
        if len(only_include) != 0 and token.pos_ not in only_include: continue
        if nlp.vocab[token.lemma_].is_stop: continue
        if token.lemma_ not in words.keys():
            words[token.lemma_] = 1
        else: words[token.lemma_] += 1
        if verbos: print(f"{token.text:{16}} {token.pos_:{12}} {token.dep_:{12}} {token.lemma_:{16}} {spacy.explain(token.tag_)}")
    
    words = dict(sorted(words.items(), key=lambda item: item[1], reverse=True))
    return words

# %% [markdown]
# <h1>Chapter One</h1>
# Let's try to process chapter one

# %%
chapter1_doc = nlp(chapters[0])

# %%
chapter1_doc.text
# Out:
# 'Chapter One  \nMr. Jones, of the Manor Farm, had locked the hen-houses for the night, but was too drunk to remember to shut the popholes. With the ring of light from his lantern dancing from side to side, he lurched across the yard, kicked off his boots at the back door, drew himself a last glass of beer from the barrel in the scullery, and made his way up to bed, where Mrs. Jones was already snoring. As soon as the light in the bedroom went out there was a stirring and a fluttering all through the farm buildings. Word had gone round during the day that old Major, the prize Middle White boar, had had a strange dream on the previous night and wished to communicate it to the other animals. It had been agreed that they should all meet in the big barn as soon as Mr. Jones was safely out of the way. Old Major (so he was always called, though the name under which he had been exhibited was Willingdon Beauty) was so highly regarded on the farm that everyone was quite ready to lose an hour\'s sleep in order to hear what he had to say. At one end of the big barn, on a sort of raised platform, Major was already ensconced on his bed of straw, under a lantern which hung from a beam. He was twelve years old and had lately grown rather stout, but he was still a majestic -looking pig, with a wise and benevolent appearance in spite of the fact that his tushes had never been cut. Before long the other animals began to arrive and make themselves comfortable after their different fashions. First came the three dogs, Bluebell, Jessie, and Pincher, and then the pigs, who settled down in the straw immediately in front of the platform. The hens perched themselves on the window-sills, the pigeons fluttered up to the rafters, the sheep and cows lay down behind the pigs and began to chew the cud. The two cart-horses, Boxer and Clover, came in together, walking very slowly and setting down their vast hairy hoofs with great care lest there should be some small animal concealed in the straw. Clover was a stout motherly mare approaching middle life, who had never quite got her figure back after her fourth foal. Boxer was an enormous beast, nearly eighteen hands high, and as strong as any two ordinary horses put together. A white stripe down his nose gave him a somewhat stupid appearance, and in fact he was not of first- rate intelligence, but he was universally respected for his steadiness of character and tremendous powers of work. After the horses came Muriel, the white goat, and Benjamin, the donkey. Benjamin was the oldest animal on the farm, and the worst tempered. He seldom talked, and when he did, it was usually to make some cynical remark—for instance, he would say that God had given him a tail to keep the flies off, but that he would sooner have had no tail and no flies. Alone among the animals on the farm he never laughed. If asked why, he would say that he saw nothing to laugh at. Nevertheless, without openly admitting it, he was devoted to Boxer; the two of them usually spent their Sundays together in the small paddock beyond the orchard, grazing side by side and never speaking. The two horses had just lain down when a brood of ducklings, which had lost their mother, filed into the barn, cheeping feebly and wandering from side to side to find some place where they would not be trodden on. Clover made a sort of wall round them with her great foreleg, and the ducklings nestled down inside it and promptly fell asleep. At the last moment Mollie, the foolish, pretty white mare who drew Mr. Jones\'s trap, \n1came mincing daintily in, chewing at a lump of sugar. She took a place near the front and began flirting her white mane, hoping to draw attention to the red ribbons it was plaited with. Last of all came the cat, who looked round, as usual, for the warmest place, and finally squeezed herself in between Boxer and Clover; there she purred contentedly throughout Major\'s speech without listening to a word of what he was saying.  All the animals were  ...

# %%
words = token_frequency(chapters[0], not_include=['SPACE', 'PUNCT', 'NUM'], verbos=True)
# Out:
# Chapter          NOUN         compound     chapter          noun, singular or mass
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Manor            PROPN        compound     Manor            noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# locked           VERB         ROOT         lock             verb, past participle
# hen              NOUN         compound     hen              noun, singular or mass
# houses           NOUN         dobj         house            noun, plural
# night            NOUN         pobj         night            noun, singular or mass
# drunk            ADJ          acomp        drunk            adjective (English), other noun-modifier (Chinese)
# remember         VERB         xcomp        remember         verb, base form
# shut             VERB         xcomp        shut             verb, base form
# popholes         NOUN         dobj         pophole          noun, plural
# ring             NOUN         pobj         ring             noun, singular or mass
# light            NOUN         pobj         light            noun, singular or mass
# lantern          ADJ          amod         lantern          adjective (English), other noun-modifier (Chinese)
# dancing          NOUN         pobj         dancing          noun, singular or mass
# lurched          VERB         ROOT         lurch            verb, past tense
# yard             NOUN         pobj         yard             noun, singular or mass
# kicked           VERB         conj         kick             verb, past tense
# boots            NOUN         dobj         boot             noun, plural
# door             NOUN         pobj         door             noun, singular or mass
# drew             VERB         conj         draw             verb, past tense
# glass            NOUN         dobj         glass            noun, singular or mass
# beer             NOUN         pobj         beer             noun, singular or mass
# barrel           NOUN         pobj         barrel           noun, singular or mass
# scullery         NOUN         pobj         scullery         noun, singular or mass
# way              NOUN         dobj         way              noun, singular or mass
# bed              NOUN         pobj         bed              noun, singular or mass
# Mrs.             PROPN        compound     Mrs.             noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# snoring          VERB         relcl        snore            verb, gerund or present participle
# soon             ADV          advmod       soon             adverb
# light            NOUN         nsubj        light            noun, singular or mass
# bedroom          NOUN         pobj         bedroom          noun, singular or mass
# stirring         NOUN         attr         stirring         noun, singular or mass
# fluttering       NOUN         conj         fluttering       noun, singular or mass
# farm             NOUN         compound     farm             noun, singular or mass
# buildings        NOUN         pobj         building         noun, plural
# Word             PROPN        nsubj        Word             noun, proper singular
# round            ADJ          advmod       round            adjective (English), other noun-modifier (Chinese)
# day              NOUN         pobj         day              noun, singular or mass
# old              ADJ          amod         old              adjective (English), other noun-modifier (Chinese)
# Major            PROPN        nsubj        Major            noun, proper singular
# prize            NOUN         appos        prize            noun, singular or mass
# Middle           PROPN        compound     Middle           noun, proper singular
# White            PROPN        compound     White            noun, proper singular
# boar             NOUN         appos        boar             noun, singular or mass
# strange          ADJ          amod         strange          adjective (English), other noun-modifier (Chinese)
# dream            NOUN         dobj         dream            noun, singular or mass
# previous         ADJ          amod         previous         adjective (English), other noun-modifier (Chinese)
# night            NOUN         pobj         night            noun, singular or mass
# wished           VERB         conj         wish             verb, past tense
# communicate      VERB         xcomp        communicate      verb, base form
# animals          NOUN         pobj         animal           noun, plural
# agreed           VERB         ROOT         agree            verb, past participle
# meet             VERB         ccomp        meet             verb, base form
# big              ADJ          amod         big              adjective (English), other noun-modifier (Chinese)
# barn             NOUN         pobj         barn             noun, singular or mass
# soon             ADV          advmod       soon             adverb
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# safely           ADV          advmod       safely           adverb
# way              NOUN         pobj         way              noun, singular or mass
# Old              ADJ          amod         old              adjective (English), other noun-modifier (Chinese)
# Major            PROPN        nsubjpass    Major            noun, proper singular
# exhibited        VERB         relcl        exhibit          verb, past participle
# Willingdon       PROPN        compound     Willingdon       noun, proper singular
# Beauty           PROPN        attr         Beauty           noun, proper singular
# highly           ADV          advmod       highly           adverb
# regarded         VERB         acomp        regard           verb, past participle
# farm             NOUN         pobj         farm             noun, singular or mass
# ready            ADJ          acomp        ready            adjective (English), other noun-modifier (Chinese)
# lose             VERB         xcomp        lose             verb, base form
# hour             NOUN         poss         hour             noun, singular or mass
# sleep            NOUN         dobj         sleep            noun, singular or mass
# order            NOUN         pobj         order            noun, singular or mass
# hear             VERB         acl          hear             verb, base form
# end              NOUN         pobj         end              noun, singular or mass
# big              ADJ          amod         big              adjective (English), other noun-modifier (Chinese)
# barn             NOUN         pobj         barn             noun, singular or mass
# sort             NOUN         pobj         sort             noun, singular or mass
# raised           VERB         amod         raise            verb, past participle
# platform         NOUN         pobj         platform         noun, singular or mass
# Major            PROPN        nsubjpass    Major            noun, proper singular
# ensconced        VERB         ROOT         ensconce         verb, past participle
# bed              NOUN         pobj         bed              noun, singular or mass
# straw            NOUN         pobj         straw            noun, singular or mass
# lantern          NOUN         pobj         lantern          noun, singular or mass
# hung             VERB         relcl        hang             verb, past tense
# beam             NOUN         pobj         beam             noun, singular or mass
# years            NOUN         npadvmod     year             noun, plural
# old              ADJ          acomp        old              adjective (English), other noun-modifier (Chinese)
# lately           ADV          advmod       lately           adverb
# grown            VERB         conj         grow             verb, past participle
# stout            ADJ          advmod       stout            adjective (English), other noun-modifier (Chinese)
# majestic         ADJ          amod         majestic         adjective (English), other noun-modifier (Chinese)
# -looking         NOUN         amod         -looking         noun, singular or mass
# pig              NOUN         attr         pig              noun, singular or mass
# wise             ADJ          amod         wise             adjective (English), other noun-modifier (Chinese)
# benevolent       ADJ          conj         benevolent       adjective (English), other noun-modifier (Chinese)
# appearance       NOUN         pobj         appearance       noun, singular or mass
# spite            NOUN         pobj         spite            noun, singular or mass
# fact             NOUN         pobj         fact             noun, singular or mass
# tushes           NOUN         nsubjpass    tush             noun, plural
# cut              VERB         acl          cut              verb, past participle
# long             ADV          pcomp        long             adverb
# animals          NOUN         nsubj        animal           noun, plural
# began            VERB         ROOT         begin            verb, past tense
# arrive           VERB         xcomp        arrive           verb, base form
# comfortable      ADJ          ccomp        comfortable      adjective (English), other noun-modifier (Chinese)
# different        ADJ          amod         different        adjective (English), other noun-modifier (Chinese)
# fashions         NOUN         pobj         fashion          noun, plural
# came             VERB         ROOT         come             verb, past tense
# dogs             NOUN         nsubj        dog              noun, plural
# Bluebell         PROPN        appos        Bluebell         noun, proper singular
# Jessie           PROPN        conj         Jessie           noun, proper singular
# Pincher          PROPN        conj         Pincher          noun, proper singular
# pigs             NOUN         conj         pig              noun, plural
# settled          VERB         relcl        settle           verb, past tense
# straw            NOUN         pobj         straw            noun, singular or mass
# immediately      ADV          advmod       immediately      adverb
# platform         NOUN         pobj         platform         noun, singular or mass
# hens             NOUN         nsubj        hen              noun, plural
# perched          VERB         ccomp        perch            verb, past tense
# window           NOUN         compound     window           noun, singular or mass
# sills            NOUN         pobj         sill             noun, plural
# pigeons          NOUN         nsubj        pigeon           noun, plural
# fluttered        VERB         ccomp        flutter          verb, past tense
# rafters          NOUN         pobj         rafter           noun, plural
# sheep            NOUN         nsubj        sheep            noun, plural
# cows             NOUN         conj         cow              noun, plural
# lay              VERB         ROOT         lie              verb, past tense
# pigs             NOUN         pobj         pig              noun, plural
# began            VERB         conj         begin            verb, past tense
# chew             VERB         xcomp        chew             verb, base form
# cud              NOUN         dobj         cud              noun, singular or mass
# cart             NOUN         compound     cart             noun, singular or mass
# horses           NOUN         nsubj        horse            noun, plural
# Boxer            PROPN        conj         Boxer            noun, proper singular
# Clover           PROPN        conj         Clover           noun, proper singular
# came             VERB         ROOT         come             verb, past tense
# walking          VERB         advcl        walk             verb, gerund or present participle
# slowly           ADV          advmod       slowly           adverb
# setting          VERB         conj         set              verb, gerund or present participle
# vast             ADJ          amod         vast             adjective (English), other noun-modifier (Chinese)
# hairy            ADJ          amod         hairy            adjective (English), other noun-modifier (Chinese)
# hoofs            NOUN         dobj         hoof             noun, plural
# great            ADJ          amod         great            adjective (English), other noun-modifier (Chinese)
# care             NOUN         pobj         care             noun, singular or mass
# lest             SCONJ        mark         lest             conjunction, subordinating or preposition
# small            ADJ          amod         small            adjective (English), other noun-modifier (Chinese)
# animal           NOUN         attr         animal           noun, singular or mass
# concealed        VERB         acl          conceal          verb, past participle
# straw            NOUN         pobj         straw            noun, singular or mass
# Clover           NOUN         nsubj        clover           noun, singular or mass
# stout            ADJ          amod         stout            adjective (English), other noun-modifier (Chinese)
# motherly         ADJ          amod         motherly         adjective (English), other noun-modifier (Chinese)
# mare             NOUN         attr         mare             noun, singular or mass
# approaching      VERB         acl          approach         verb, gerund or present participle
# middle           ADJ          amod         middle           adjective (English), other noun-modifier (Chinese)
# life             NOUN         dobj         life             noun, singular or mass
# figure           NOUN         dobj         figure           noun, singular or mass
# fourth           ADJ          amod         fourth           adjective (English), other noun-modifier (Chinese)
# foal             NOUN         pobj         foal             noun, singular or mass
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# enormous         ADJ          amod         enormous         adjective (English), other noun-modifier (Chinese)
# beast            NOUN         attr         beast            noun, singular or mass
# nearly           ADV          advmod       nearly           adverb
# hands            NOUN         nsubj        hand             noun, plural
# high             ADJ          amod         high             adjective (English), other noun-modifier (Chinese)
# strong           ADJ          conj         strong           adjective (English), other noun-modifier (Chinese)
# ordinary         ADJ          amod         ordinary         adjective (English), other noun-modifier (Chinese)
# horses           NOUN         nsubj        horse            noun, plural
# white            ADJ          amod         white            adjective (English), other noun-modifier (Chinese)
# stripe           NOUN         nsubj        stripe           noun, singular or mass
# nose             NOUN         pobj         nose             noun, singular or mass
# somewhat         ADV          advmod       somewhat         adverb
# stupid           ADJ          amod         stupid           adjective (English), other noun-modifier (Chinese)
# appearance       NOUN         dobj         appearance       noun, singular or mass
# fact             NOUN         pobj         fact             noun, singular or mass
# rate             NOUN         compound     rate             noun, singular or mass
# intelligence     NOUN         pobj         intelligence     noun, singular or mass
# universally      ADV          advmod       universally      adverb
# respected        VERB         conj         respect          verb, past participle
# steadiness       NOUN         pobj         steadiness       noun, singular or mass
# character        NOUN         pobj         character        noun, singular or mass
# tremendous       ADJ          amod         tremendous       adjective (English), other noun-modifier (Chinese)
# powers           NOUN         conj         power            noun, plural
# work             NOUN         pobj         work             noun, singular or mass
# horses           NOUN         nsubj        horse            noun, plural
# came             VERB         ROOT         come             verb, past tense
# Muriel           PROPN        nsubj        Muriel           noun, proper singular
# white            PROPN        compound     white            noun, proper singular
# goat             PROPN        conj         goat             noun, proper singular
# Benjamin         PROPN        conj         Benjamin         noun, proper singular
# donkey           NOUN         appos        donkey           noun, singular or mass
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# oldest           ADJ          amod         old              adjective, superlative
# animal           NOUN         attr         animal           noun, singular or mass
# farm             NOUN         pobj         farm             noun, singular or mass
# worst            ADJ          nsubj        bad              adjective, superlative
# tempered         VERB         conj         temper           verb, past participle
# seldom           ADV          advmod       seldom           adverb
# talked           VERB         ccomp        talk             verb, past tense
# usually          ADV          advmod       usually          adverb
# cynical          ADJ          amod         cynical          adjective (English), other noun-modifier (Chinese)
# remark           NOUN         dobj         remark           noun, singular or mass
# instance         NOUN         pobj         instance         noun, singular or mass
# God              PROPN        nsubj        God              noun, proper singular
# tail             NOUN         dobj         tail             noun, singular or mass
# flies            NOUN         dobj         fly              noun, plural
# sooner           ADV          advmod       soon             adverb
# tail             NOUN         dobj         tail             noun, singular or mass
# flies            NOUN         conj         fly              noun, plural
# animals          NOUN         pobj         animal           noun, plural
# farm             NOUN         pobj         farm             noun, singular or mass
# laughed          VERB         relcl        laugh            verb, past tense
# asked            VERB         advcl        ask              verb, past participle
# laugh            VERB         relcl        laugh            verb, base form
# openly           ADV          advmod       openly           adverb
# admitting        VERB         pcomp        admit            verb, gerund or present participle
# devoted          ADJ          acomp        devoted          adjective (English), other noun-modifier (Chinese)
# Boxer            PROPN        pobj         Boxer            noun, proper singular
# usually          ADV          advmod       usually          adverb
# spent            VERB         ROOT         spend            verb, past tense
# Sundays          NOUN         dobj         sunday           noun, plural
# small            ADJ          amod         small            adjective (English), other noun-modifier (Chinese)
# paddock          NOUN         pobj         paddock          noun, singular or mass
# orchard          NOUN         pobj         orchard          noun, singular or mass
# grazing          VERB         compound     graze            verb, gerund or present participle
# speaking         VERB         conj         speak            verb, gerund or present participle
# horses           NOUN         nsubj        horse            noun, plural
# lain             VERB         ROOT         lain             verb, base form
# brood            NOUN         nsubj        brood            noun, singular or mass
# ducklings        NOUN         pobj         duckling         noun, plural
# lost             VERB         relcl        lose             verb, past participle
# mother           NOUN         dobj         mother           noun, singular or mass
# filed            VERB         advcl        file             verb, past participle
# barn             NOUN         pobj         barn             noun, singular or mass
# cheeping         VERB         advcl        cheep            verb, gerund or present participle
# feebly           ADV          advmod       feebly           adverb
# wandering        VERB         conj         wander           verb, gerund or present participle
# find             VERB         advcl        find             verb, base form
# place            NOUN         dobj         place            noun, singular or mass
# trodden          VERB         relcl        tread            verb, past participle
# Clover           NOUN         nsubj        clover           noun, singular or mass
# sort             NOUN         dobj         sort             noun, singular or mass
# wall             NOUN         pobj         wall             noun, singular or mass
# round            VERB         advcl        round            verb, base form
# great            ADJ          amod         great            adjective (English), other noun-modifier (Chinese)
# foreleg          NOUN         pobj         foreleg          noun, singular or mass
# ducklings        NOUN         nsubj        duckling         noun, plural
# nestled          VERB         conj         nestle           verb, past tense
# inside           ADP          prep         inside           conjunction, subordinating or preposition
# promptly         ADV          advmod       promptly         adverb
# fell             VERB         conj         fall             verb, past tense
# asleep           ADJ          acomp        asleep           adjective (English), other noun-modifier (Chinese)
# moment           NOUN         pobj         moment           noun, singular or mass
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# foolish          ADJ          amod         foolish          adjective (English), other noun-modifier (Chinese)
# pretty           ADV          advmod       pretty           adverb
# white            ADJ          amod         white            adjective (English), other noun-modifier (Chinese)
# mare             NOUN         appos        mare             noun, singular or mass
# drew             VERB         relcl        draw             verb, past tense
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# trap             NOUN         dobj         trap             noun, singular or mass
# mincing          NOUN         appos        mincing          noun, singular or mass
# daintily         ADV          advmod       daintily         adverb
# chewing          VERB         ROOT         chew             verb, gerund or present participle
# lump             NOUN         pobj         lump             noun, singular or mass
# sugar            NOUN         pobj         sugar            noun, singular or mass
# place            NOUN         dobj         place            noun, singular or mass
# near             ADP          prep         near             conjunction, subordinating or preposition
# began            VERB         conj         begin            verb, past tense
# flirting         VERB         xcomp        flirt            verb, gerund or present participle
# white            ADJ          amod         white            adjective (English), other noun-modifier (Chinese)
# mane             NOUN         dobj         mane             noun, singular or mass
# hoping           VERB         advcl        hope             verb, gerund or present participle
# draw             VERB         xcomp        draw             verb, base form
# attention        NOUN         dobj         attention        noun, singular or mass
# red              ADJ          amod         red              adjective (English), other noun-modifier (Chinese)
# ribbons          NOUN         pobj         ribbon           noun, plural
# plaited          VERB         relcl        plait            verb, past participle
# came             VERB         ccomp        come             verb, past tense
# cat              NOUN         nsubj        cat              noun, singular or mass
# looked           VERB         relcl        look             verb, past tense
# round            ADV          advmod       round            adverb
# usual            ADJ          amod         usual            adjective (English), other noun-modifier (Chinese)
# warmest          ADJ          amod         warm             adjective, superlative
# place            NOUN         pobj         place            noun, singular or mass
# finally          ADV          advmod       finally          adverb
# squeezed         VERB         conj         squeeze          verb, past tense
# Boxer            PROPN        pobj         Boxer            noun, proper singular
# Clover           PROPN        conj         Clover           noun, proper singular
# purred           VERB         ROOT         purr             verb, past tense
# contentedly      ADV          advmod       contentedly      adverb
# Major            PROPN        poss         Major            noun, proper singular
# speech           NOUN         pobj         speech           noun, singular or mass
# listening        VERB         pcomp        listen           verb, gerund or present participle
# word             NOUN         pobj         word             noun, singular or mass
# animals          NOUN         nsubj        animal           noun, plural
# present          ADJ          acomp        present          adjective (English), other noun-modifier (Chinese)
# Moses            PROPN        pobj         Moses            noun, proper singular
# tame             NOUN         compound     tame             noun, singular or mass
# raven            NOUN         appos        raven            noun, singular or mass
# slept            VERB         relcl        sleep            verb, past tense
# perch            NOUN         pobj         perch            noun, singular or mass
# door             NOUN         pobj         door             noun, singular or mass
# Major            PROPN        nsubj        Major            noun, proper singular
# comfortable      ADJ          ccomp        comfortable      adjective (English), other noun-modifier (Chinese)
# waiting          VERB         conj         wait             verb, gerund or present participle
# attentively      ADV          advmod       attentively      adverb
# cleared          VERB         ROOT         clear            verb, past tense
# throat           NOUN         dobj         throat           noun, singular or mass
# began            VERB         conj         begin            verb, past tense
# Comrades         NOUN         dobj         comrade          noun, plural
# heard            VERB         relcl        hear             verb, past participle
# strange          ADJ          amod         strange          adjective (English), other noun-modifier (Chinese)
# dream            NOUN         pobj         dream            noun, singular or mass
# night            NOUN         npadvmod     night            noun, singular or mass
# come             VERB         ROOT         come             verb, base form
# dream            NOUN         pobj         dream            noun, singular or mass
# later            ADV          advmod       later            adverb
# think            VERB         ROOT         think            verb, base form
# comrades         NOUN         npadvmod     comrade          noun, plural
# shall            AUX          aux          shall            verb, modal auxiliary
# months           NOUN         npadvmod     month            noun, plural
# longer           ADV          advmod       long             adverb, comparative
# die              VERB         advcl        die              verb, non-3rd person singular present
# feel             VERB         conj         feel             verb, non-3rd person singular present
# duty             NOUN         ROOT         duty             noun, singular or mass
# pass             VERB         relcl        pass             verb, base form
# wisdom           NOUN         dobj         wisdom           noun, singular or mass
# acquired         VERB         advcl        acquire          verb, past participle
# long             ADJ          amod         long             adjective (English), other noun-modifier (Chinese)
# life             NOUN         dobj         life             noun, singular or mass
# time             NOUN         dobj         time             noun, singular or mass
# thought          NOUN         pobj         thought          noun, singular or mass
# lay              VERB         advcl        lay              verb, non-3rd person singular present
# stall            NOUN         pobj         stall            noun, singular or mass
# think            VERB         conj         think            verb, non-3rd person singular present
# understand       VERB         ccomp        understand       verb, non-3rd person singular present
# nature           NOUN         dobj         nature           noun, singular or mass
# life             NOUN         pobj         life             noun, singular or mass
# earth            NOUN         pobj         earth            noun, singular or mass
# animal           NOUN         nsubj        animal           noun, singular or mass
# living           VERB         relcl        live             verb, gerund or present participle
# wish             VERB         ccomp        wish             verb, non-3rd person singular present
# speak            VERB         xcomp        speak            verb, base form
# comrades         NOUN         nmod         comrade          noun, plural
# nature           NOUN         nsubj        nature           noun, singular or mass
# life             NOUN         pobj         life             noun, singular or mass
# Let              VERB         advcl        let              verb, base form
# face             VERB         ccomp        face             verb, base form
# lives            NOUN         nsubj        life             noun, plural
# miserable        ADJ          acomp        miserable        adjective (English), other noun-modifier (Chinese)
# laborious        ADJ          conj         laborious        adjective (English), other noun-modifier (Chinese)
# short            ADJ          conj         short            adjective (English), other noun-modifier (Chinese)
# born             VERB         ccomp        bear             verb, past participle
# food             NOUN         dobj         food             noun, singular or mass
# w                PROPN        pobj         w                noun, proper singular
# ill              ADJ          amod         ill              adjective (English), other noun-modifier (Chinese)
# breath           NOUN         dobj         breath           noun, singular or mass
# bodies           NOUN         pobj         body             noun, plural
# capable          ADJ          acomp        capable          adjective (English), other noun-modifier (Chinese)
# forced           VERB         conj         force            verb, past participle
# work             VERB         xcomp        work             verb, base form
# atom             NOUN         pobj         atom             noun, singular or mass
# strength         NOUN         pobj         strength         noun, singular or mass
# instant          NOUN         conj         instant          noun, singular or mass
# usefulness       NOUN         nsubj        usefulness       noun, singular or mass
# come             VERB         acl          come             verb, past participle
# end              NOUN         pobj         end              noun, singular or mass
# slaughtered      VERB         relcl        slaughter        verb, past participle
# hideous          ADJ          amod         hideous          adjective (English), other noun-modifier (Chinese)
# cruelty          NOUN         pobj         cruelty          noun, singular or mass
# animal           NOUN         nsubj        animal           noun, singular or mass
# England          PROPN        pobj         England          noun, proper singular
# knows            VERB         ROOT         know             verb, 3rd person singular present
# meaning          NOUN         dobj         meaning          noun, singular or mass
# happiness        NOUN         pobj         happiness        noun, singular or mass
# leisure          NOUN         conj         leisure          noun, singular or mass
# year             NOUN         npadvmod     year             noun, singular or mass
# old              ADJ          acomp        old              adjective (English), other noun-modifier (Chinese)
# animal           NOUN         nsubj        animal           noun, singular or mass
# England          PROPN        pobj         England          noun, proper singular
# free             ADJ          acomp        free             adjective (English), other noun-modifier (Chinese)
# life             NOUN         nsubj        life             noun, singular or mass
# animal           NOUN         pobj         animal           noun, singular or mass
# misery           NOUN         attr         misery           noun, singular or mass
# slavery          NOUN         conj         slavery          noun, singular or mass
# plain            ADJ          amod         plain            adjective (English), other noun-modifier (Chinese)
# truth            NOUN         attr         truth            noun, singular or mass
# simply           ADV          advmod       simply           adverb
# order            NOUN         pobj         order            noun, singular or mass
# nature           NOUN         pobj         nature           noun, singular or mass
# land             NOUN         nsubj        land             noun, singular or mass
# poor             ADJ          acomp        poor             adjective (English), other noun-modifier (Chinese)
# afford           VERB         ccomp        afford           verb, base form
# decent           ADJ          amod         decent           adjective (English), other noun-modifier (Chinese)
# life             NOUN         dobj         life             noun, singular or mass
# dwell            VERB         relcl        dwell            verb, non-3rd person singular present
# comrades         NOUN         ROOT         comrade          noun, plural
# times            NOUN         quantmod     time             noun, plural
# soil             NOUN         nsubj        soil             noun, singular or mass
# England          PROPN        pobj         England          noun, proper singular
# fertile          ADJ          acomp        fertile          adjective (English), other noun-modifier (Chinese)
# climate          NOUN         nsubj        climate          noun, singular or mass
# good             ADJ          acomp        good             adjective (English), other noun-modifier (Chinese)
# capable          ADJ          acomp        capable          adjective (English), other noun-modifier (Chinese)
# affording        VERB         pcomp        afford           verb, gerund or present participle
# food             NOUN         dobj         food             noun, singular or mass
# abundance        NOUN         pobj         abundance        noun, singular or mass
# enormously       ADV          advmod       enormously       adverb
# greater          ADJ          amod         great            adjective, comparative
# number           NOUN         pobj         number           noun, singular or mass
# animals          NOUN         pobj         animal           noun, plural
# inhabit          VERB         advcl        inhabit          verb, base form
# T                NOUN         nsubj        t                noun, singular or mass
# single           ADJ          amod         single           adjective (English), other noun-modifier (Chinese)
# farm             NOUN         appos        farm             noun, singular or mass
# support          VERB         ROOT         support          verb, base form
# dozen            NOUN         nummod       dozen            noun, singular or mass
# horses           NOUN         dobj         horse            noun, plural
# cows             NOUN         appos        cow              noun, plural
# sheep            NOUN         pobj         sheep            noun, singular or mass
# living           VERB         acl          live             verb, gerund or present participle
# comfort          NOUN         pobj         comfort          noun, singular or mass
# dignity          NOUN         conj         dignity          noun, singular or mass
# imagining        NOUN         pobj         imagining        noun, singular or mass
# continue         VERB         ROOT         continue         verb, base form
# miserable        ADJ          amod         miserable        adjective (English), other noun-modifier (Chinese)
# condition        NOUN         pobj         condition        noun, singular or mass
# nearly           ADV          advmod       nearly           adverb
# produce          NOUN         pobj         produce          noun, singular or mass
# labour           NOUN         pobj         labour           noun, singular or mass
# stolen           VERB         ROOT         steal            verb, past participle
# human            ADJ          amod         human            adjective (English), other noun-modifier (Chinese)
# comrades         NOUN         nsubj        comrade          noun, plural
# answer           NOUN         attr         answer           noun, singular or mass
# problems         NOUN         pobj         problem          noun, plural
# summed           VERB         ROOT         sum              verb, past participle
# single           ADJ          amod         single           adjective (English), other noun-modifier (Chinese)
# word             NOUN         pobj         word             noun, singular or mass
# Man              PROPN        compound     Man              noun, proper singular
# .                PROPN        compound     .                noun, proper singular
# Man              PROPN        nsubj        Man              noun, proper singular
# real             ADJ          amod         real             adjective (English), other noun-modifier (Chinese)
# enemy            NOUN         attr         enemy            noun, singular or mass
# Remove           VERB         ROOT         remove           verb, base form
# Man              PROPN        dobj         Man              noun, proper singular
# scene            NOUN         pobj         scene            noun, singular or mass
# root             NOUN         compound     root             noun, singular or mass
# cause            NOUN         nsubjpass    cause            noun, singular or mass
# hunger           NOUN         pobj         hunger           noun, singular or mass
# overwork         NOUN         conj         overwork         noun, singular or mass
# abolished        VERB         conj         abolish          verb, past participle
# Man              NOUN         nsubj        man              noun, singular or mass
# creature         NOUN         attr         creature         noun, singular or mass
# consumes         VERB         relcl        consume          verb, 3rd person singular present
# producing        VERB         pcomp        produce          verb, gerund or present participle
# milk             NOUN         dobj         milk             noun, singular or mass
# lay              VERB         ccomp        lay              verb, base form
# eggs             NOUN         dobj         egg              noun, plural
# weak             ADJ          acomp        weak             adjective (English), other noun-modifier (Chinese)
# pull             VERB         xcomp        pull             verb, base form
# plough           NOUN         dobj         plough           noun, singular or mass
# run              VERB         ROOT         run              verb, base form
# fast             ADV          advmod       fast             adverb
# catch            VERB         xcomp        catch            verb, base form
# rabbits          NOUN         dobj         rabbit           noun, plural
# lord             PROPN        attr         lord             noun, proper singular
# animals          NOUN         pobj         animal           noun, plural
# sets             VERB         ccomp        set              verb, 3rd person singular present
# work             VERB         xcomp        work             verb, base form
# bare             ADJ          amod         bare             adjective (English), other noun-modifier (Chinese)
# minimum          NOUN         dobj         minimum          noun, singular or mass
# prevent          VERB         relcl        prevent          verb, base form
# starving         VERB         pcomp        starve           verb, gerund or present participle
# rest             NOUN         conj         rest             noun, singular or mass
# labour           NOUN         nsubj        labour           noun, singular or mass
# tills            VERB         ccomp        till             verb, 3rd person singular present
# soil             NOUN         dobj         soil             noun, singular or mass
# dung             NOUN         nsubj        dung             noun, singular or mass
# fertilises       VERB         ROOT         fertilise        verb, 3rd person singular present
# bare             ADJ          amod         bare             adjective (English), other noun-modifier (Chinese)
# skin             NOUN         pobj         skin             noun, singular or mass
# cows             VERB         ccomp        cow              verb, 3rd person singular present
# thousands        NOUN         dobj         thousand         noun, plural
# gallons          NOUN         pobj         gallon           noun, plural
# milk             NOUN         pobj         milk             noun, singular or mass
# year             NOUN         pobj         year             noun, singular or mass
# happened         VERB         ROOT         happen           verb, past participle
# milk             NOUN         pobj         milk             noun, singular or mass
# breeding         VERB         relcl        breed            verb, gerund or present participle
# sturdy           ADJ          amod         sturdy           adjective (English), other noun-modifier (Chinese)
# calves           NOUN         dobj         calf             noun, plural
# drop             NOUN         nsubj        drop             noun, singular or mass
# throats          NOUN         dobj         throat           noun, plural
# enemies          NOUN         pobj         enemy            noun, plural
# hens             VERB         ROOT         hen              verb, 3rd person singular present
# eggs             NOUN         dobj         egg              noun, plural
# laid             VERB         ccomp        lay              verb, past participle
# year             NOUN         npadvmod     year             noun, singular or mass
# eggs             NOUN         pobj         egg              noun, plural
# hatched          VERB         conj         hatch            verb, past participle
# chickens         NOUN         pobj         chicken          noun, plural
# rest             NOUN         nsubj        rest             noun, singular or mass
# market           NOUN         pobj         market           noun, singular or mass
# bring            VERB         advcl        bring            verb, base form
# money            NOUN         dobj         money            noun, singular or mass
# Jones            PROPN        pobj         Jones            noun, proper singular
# men              NOUN         conj         man              noun, plural
# Clover           PROPN        appos        Clover           noun, proper singular
# foals            NOUN         attr         foal             noun, plural
# bore             VERB         relcl        bore             verb, non-3rd person singular present
# support          NOUN         attr         support          noun, singular or mass
# pleasure         NOUN         conj         pleasure         noun, singular or mass
# old              ADJ          amod         old              adjective (English), other noun-modifier (Chinese)
# age              NOUN         pobj         age              noun, singular or mass
# sold             VERB         ccomp        sell             verb, past participle
# year             NOUN         pobj         year             noun, singular or mass
# old              ADJ          amod         old              adjective (English), other noun-modifier (Chinese)
# return           NOUN         pobj         return           noun, singular or mass
# confinements     NOUN         pobj         confinement      noun, plural
# labour           NOUN         dobj         labour           noun, singular or mass
# fields           NOUN         pobj         field            noun, plural
# bare             ADJ          amod         bare             adjective (English), other noun-modifier (Chinese)
# rations          NOUN         pobj         ration           noun, plural
# stall            NOUN         conj         stall            noun, singular or mass
# miserable        ADJ          amod         miserable        adjective (English), other noun-modifier (Chinese)
# lives            NOUN         nsubjpass    life             noun, plural
# lead             VERB         relcl        lead             verb, non-3rd person singular present
# allowed          VERB         ROOT         allow            verb, past participle
# reach            VERB         xcomp        reach            verb, base form
# natural          ADJ          amod         natural          adjective (English), other noun-modifier (Chinese)
# span             NOUN         dobj         span             noun, singular or mass
# grumble          VERB         ROOT         grumble          verb, base form
# lucky            ADJ          amod         lucky            adjective (English), other noun-modifier (Chinese)
# years            NOUN         npadvmod     year             noun, plural
# old              ADJ          acomp        old              adjective (English), other noun-modifier (Chinese)
# children         NOUN         dobj         child            noun, plural
# natural          ADJ          amod         natural          adjective (English), other noun-modifier (Chinese)
# life             NOUN         attr         life             noun, singular or mass
# pig              NOUN         pobj         pig              noun, singular or mass
# animal           NOUN         nsubj        animal           noun, singular or mass
# escapes          VERB         ROOT         escape           verb, 3rd person singular present
# cruel            PROPN        amod         cruel            noun, proper singular
# knife            NOUN         dobj         knife            noun, singular or mass
# end              NOUN         pobj         end              noun, singular or mass
# young            ADJ          amod         young            adjective (English), other noun-modifier (Chinese)
# porkers          NOUN         npadvmod     porker           noun, plural
# sitting          VERB         relcl        sit              verb, gerund or present participle
# scream           VERB         ROOT         scream           verb, base form
# lives            NOUN         dobj         life             noun, plural
# block            NOUN         pobj         block            noun, singular or mass
# year             NOUN         pobj         year             noun, singular or mass
# horror           NOUN         pobj         horror           noun, singular or mass
# come             VERB         ROOT         come             verb, base form
# cows             NOUN         dep          cow              noun, plural
# pigs             NOUN         conj         pig              noun, plural
# hens             NOUN         conj         hen              noun, plural
# sheep            NOUN         conj         sheep            noun, singular or mass
# ...
# voice            NOUN         nsubj        voice            noun, singular or mass
# hoarse           ADJ          acomp        hoarse           adjective (English), other noun-modifier (Chinese)
# sang             VERB         conj         sing             verb, past tense
# stirring         ADJ          amod         stirring         adjective (English), other noun-modifier (Chinese)
# tune             NOUN         attr         tune             noun, singular or mass
# Clementine       PROPN        pobj         Clementine       noun, proper singular
# La               PROPN        compound     La               noun, proper singular
# Cucuracha        PROPN        conj         Cucuracha        noun, proper singular
# words            NOUN         nsubj        word             noun, plural
# ran              VERB         ccomp        run              verb, past tense
# Beasts           PROPN        nsubj        Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# beasts           NOUN         appos        beast            noun, plural
# Ireland          PROPN        pobj         Ireland          noun, proper singular
# Beasts           NOUN         conj         beast            noun, plural
# land             NOUN         pobj         land             noun, singular or mass
# clime            NOUN         conj         clime            noun, singular or mass
# Hearken          PROPN        ROOT         Hearken          noun, proper singular
# joyful           ADJ          amod         joyful           adjective (English), other noun-modifier (Chinese)
# tidings          NOUN         pobj         tiding           noun, plural
# golden           ADJ          amod         golden           adjective (English), other noun-modifier (Chinese)
# future           ADJ          amod         future           adjective (English), other noun-modifier (Chinese)
# time             NOUN         pobj         time             noun, singular or mass
# Soon             ADV          advmod       soon             adverb
# late             ADV          conj         late             adverb
# day              NOUN         nsubj        day              noun, singular or mass
# coming           VERB         ccomp        come             verb, gerund or present participle
# Tyrant           PROPN        compound     Tyrant           noun, proper singular
# Man              PROPN        nsubj        Man              noun, proper singular
# shall            AUX          aux          shall            verb, modal auxiliary
# o'erthrown       ADP          attr         o'erthrown       conjunction, subordinating or preposition
# fruitful         ADJ          amod         fruitful         adjective (English), other noun-modifier (Chinese)
# fields           NOUN         nsubj        field            noun, plural
# England          PROPN        pobj         England          noun, proper singular
# Shall            AUX          aux          shall            verb, modal auxiliary
# trod             NOUN         attr         trod             noun, singular or mass
# beasts           NOUN         pobj         beast            noun, plural
# Rings            NOUN         nsubj        ring             noun, plural
# shall            AUX          aux          shall            verb, modal auxiliary
# vanish           VERB         ccomp        vanish           verb, base form
# noses            NOUN         pobj         nose             noun, plural
# harness          NOUN         nsubj        harness          noun, singular or mass
# Bit              NOUN         appos        bit              noun, singular or mass
# spur             VERB         nsubj        spur             verb, base form
# shall            AUX          aux          shall            verb, modal auxiliary
# rust             VERB         conj         rust             verb, base form
# forever          ADV          advmod       forever          adverb
# Cruel            PROPN        nsubj        Cruel            noun, proper singular
# whips            VERB         ROOT         whip             verb, 3rd person singular present
# shall            AUX          aux          shall            verb, modal auxiliary
# crack            VERB         ccomp        crack            verb, base form
# Riches           NOUN         nsubj        rich             noun, plural
# mind             NOUN         pobj         mind             noun, singular or mass
# picture          VERB         ROOT         picture          verb, base form
# Wheat            NOUN         conj         wheat            noun, singular or mass
# barley           NOUN         conj         barley           noun, singular or mass
# oats             NOUN         conj         oat              noun, plural
# hay              PROPN        conj         hay              noun, proper singular
# Clover           PROPN        conj         Clover           noun, proper singular
# beans            NOUN         conj         bean             noun, plural
# mangel           NOUN         compound     mangel           noun, singular or mass
# wurzels          NOUN         conj         wurzel           noun, plural
# Shall            AUX          aux          shall            verb, modal auxiliary
# day              NOUN         pobj         day              noun, singular or mass
# Bright           ADJ          nsubj        bright           adjective (English), other noun-modifier (Chinese)
# shine            VERB         ccomp        shine            verb, base form
# fields           NOUN         dobj         field            noun, plural
# England          PROPN        pobj         England          noun, proper singular
# Purer            PROPN        nsubj        Purer            noun, proper singular
# shall            AUX          aux          shall            verb, modal auxiliary
# waters           NOUN         nsubj        water            noun, plural
# Sweeter          ADJ          nsubj        sweet            adjective, comparative
# shall            AUX          aux          shall            verb, modal auxiliary
# blow             VERB         conj         blow             verb, base form
# breezes          NOUN         dobj         breeze           noun, plural
# day              NOUN         pobj         day              noun, singular or mass
# sets             VERB         relcl        set              verb, 3rd person singular present
# free             ADJ          ccomp        free             adjective (English), other noun-modifier (Chinese)
# day              NOUN         pobj         day              noun, singular or mass
# labour           VERB         advcl        labour           verb, base form
# die              VERB         advcl        die              verb, non-3rd person singular present
# break            VERB         advcl        break            verb, non-3rd person singular present
# Cows             NOUN         nsubj        cow              noun, plural
# horses           NOUN         conj         horse            noun, plural
# geese            PROPN        conj         geese            noun, proper singular
# turkeys          NOUN         conj         turkey           noun, plural
# toil             VERB         ROOT         toil             verb, base form
# freedom          NOUN         poss         freedom          noun, singular or mass
# sake             NOUN         pobj         sake             noun, singular or mass
# Beasts           NOUN         nsubj        beast            noun, plural
# England          PROPN        pobj         England          noun, proper singular
# beasts           NOUN         appos        beast            noun, plural
# Ireland          PROPN        pobj         Ireland          noun, proper singular
# Beasts           NOUN         appos        beast            noun, plural
# land             NOUN         pobj         land             noun, singular or mass
# clime            NOUN         conj         clime            noun, singular or mass
# Hearken          PROPN        ROOT         Hearken          noun, proper singular
# spread           VERB         conj         spread           verb, base form
# tidings          NOUN         dobj         tiding           noun, plural
# golden           ADJ          amod         golden           adjective (English), other noun-modifier (Chinese)
# future           ADJ          amod         future           adjective (English), other noun-modifier (Chinese)
# time             NOUN         pobj         time             noun, singular or mass
# singing          NOUN         nsubj        singing          noun, singular or mass
# song             NOUN         pobj         song             noun, singular or mass
# threw            VERB         ROOT         throw            verb, past tense
# animals          NOUN         dobj         animal           noun, plural
# wildest          ADJ          amod         wildest          adjective (English), other noun-modifier (Chinese)
# excitement       NOUN         pobj         excitement       noun, singular or mass
# Major            PROPN        nsubj        Major            noun, proper singular
# reached          VERB         advcl        reach            verb, past participle
# end              NOUN         dobj         end              noun, singular or mass
# begun            VERB         ROOT         begin            verb, past participle
# singing          VERB         xcomp        singe            verb, gerund or present participle
# stupidest        ADJ          amod         stupid           adjective, superlative
# 4of              NOUN         npadvmod     4of              noun, singular or mass
# picked           VERB         ROOT         pick             verb, past participle
# tune             NOUN         dobj         tune             noun, singular or mass
# words            NOUN         pobj         word             noun, plural
# clever           ADJ          amod         clever           adjective (English), other noun-modifier (Chinese)
# pigs             NOUN         pobj         pig              noun, plural
# dogs             NOUN         conj         dog              noun, plural
# entire           ADJ          amod         entire           adjective (English), other noun-modifier (Chinese)
# song             NOUN         dobj         song             noun, singular or mass
# heart            NOUN         pobj         heart            noun, singular or mass
# minutes          NOUN         pobj         minute           noun, plural
# preliminary      ADJ          amod         preliminary      adjective (English), other noun-modifier (Chinese)
# tries            NOUN         pobj         try              noun, plural
# farm             NOUN         nsubj        farm             noun, singular or mass
# burst            VERB         ROOT         burst            verb, past tense
# Beasts           PROPN        pobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# tremendous       ADJ          amod         tremendous       adjective (English), other noun-modifier (Chinese)
# unison           NOUN         pobj         unison           noun, singular or mass
# cows             NOUN         nsubj        cow              noun, plural
# lowed            VERB         ccomp        low              verb, past tense
# dogs             NOUN         nsubj        dog              noun, plural
# whined           VERB         ccomp        whine            verb, past tense
# sheep            NOUN         nsubj        sheep            noun, singular or mass
# bleated          VERB         ccomp        bleat            verb, past tense
# horses           NOUN         nsubj        horse            noun, plural
# whinnied         VERB         ccomp        whinny           verb, past tense
# ducks            NOUN         nsubj        duck             noun, plural
# quacked          VERB         ROOT         quack            verb, past tense
# delighted        ADJ          acomp        delighted        adjective (English), other noun-modifier (Chinese)
# song             NOUN         pobj         song             noun, singular or mass
# sang             VERB         relcl        sing             verb, past tense
# right            ADV          advmod       right            adverb
# times            NOUN         pobj         time             noun, plural
# succession       NOUN         pobj         succession       noun, singular or mass
# continued        VERB         conj         continue         verb, past participle
# singing          VERB         xcomp        singe            verb, gerund or present participle
# night            NOUN         npadvmod     night            noun, singular or mass
# interrupted      VERB         advcl        interrupt        verb, past participle
# Unfortunately    ADV          advmod       unfortunately    adverb
# uproar           NOUN         nsubj        uproar           noun, singular or mass
# awoke            VERB         ROOT         awake            verb, past tense
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        dobj         Jones            noun, proper singular
# sprang           VERB         relcl        spring           verb, past tense
# bed              NOUN         pobj         bed              noun, singular or mass
# sure             ADJ          ccomp        sure             adjective (English), other noun-modifier (Chinese)
# fox              NOUN         attr         fox              noun, singular or mass
# yard             NOUN         pobj         yard             noun, singular or mass
# seized           VERB         ROOT         seize            verb, past tense
# gun              NOUN         dobj         gun              noun, singular or mass
# stood            VERB         relcl        stand            verb, past tense
# corner           NOUN         pobj         corner           noun, singular or mass
# bedroom          NOUN         pobj         bedroom          noun, singular or mass
# let              AUX          aux          let              verb, base form
# fly              VERB         conj         fly              verb, base form
# charge           NOUN         dobj         charge           noun, singular or mass
# number           NOUN         pobj         number           noun, singular or mass
# shot             NOUN         advcl        shot             noun, singular or mass
# darkness         NOUN         pobj         darkness         noun, singular or mass
# pellets          NOUN         nsubj        pellet           noun, plural
# buried           VERB         ROOT         bury             verb, past tense
# wall             NOUN         pobj         wall             noun, singular or mass
# barn             NOUN         pobj         barn             noun, singular or mass
# meeting          NOUN         nsubj        meeting          noun, singular or mass
# broke            VERB         conj         break            verb, past tense
# hurriedly        ADV          advmod       hurriedly        adverb
# fled             VERB         ROOT         flee             verb, past tense
# sleeping         NOUN         compound     sleeping         noun, singular or mass
# place            NOUN         pobj         place            noun, singular or mass
# birds            NOUN         nsubj        bird             noun, plural
# jumped           VERB         ccomp        jump             verb, past tense
# perches          NOUN         pobj         perch            noun, plural
# animals          NOUN         nsubj        animal           noun, plural
# settled          VERB         ROOT         settle           verb, past tense
# straw            NOUN         pobj         straw            noun, singular or mass
# farm             NOUN         nsubj        farm             noun, singular or mass
# asleep           ADJ          acomp        asleep           adjective (English), other noun-modifier (Chinese)
# moment           NOUN         pobj         moment           noun, singular or mass

# %%
words
# Out:
# {'animal': 24,
#  'comrade': 15,
#  'come': 13,
#  'life': 13,
#  'old': 11,
#  'Man': 11,
#  'Major': 10,
#  'shall': 10,
#  'year': 9,
#  'England': 9,
#  'Jones': 8,
#  'horse': 8,
#  'night': 7,
#  'farm': 7,
#  'day': 7,
#  'dream': 7,
#  'pig': 7,
#  'dog': 7,
#  'beast': 7,
#  'word': 7,
#  'sing': 7,
#  'long': 6,
#  'begin': 6,
#  'cow': 6,
#  'song': 6,
#  'soon': 5,
#  'straw': 5,
#  'Boxer': 5,
#  'time': 5,
#  'know': 5,
#  'labour': 5,
#  'enemy': 5,
#  'rat': 5,
#  'tune': 5,
#  'Mr.': 4,
#  'hen': 4,
#  'remember': 4,
#  'bed': 4,
#  'round': 4,
#  'barn': 4,
#  'lose': 4,
#  'end': 4,
#  'sheep': 4,
#  'Clover': 4,
#  'great': 4,
#  'white': 4,
#  'work': 4,
#  'place': 4,
#  'throat': 4,
#  'let': 4,
#  'draw': 3,
#  'way': 3,
#  'sleep': 3,
#  'settle': 3,
#  'perch': 3,
#  'set': 3,
#  'tremendous': 3,
#  'fly': 3,
#  'speak': 3,
#  'moment': 3,
#  'listen': 3,
#  'clear': 3,
#  'pass': 3,
#  'lay': 3,
#  'nature': 3,
#  'live': 3,
#  'miserable': 3,
#  'free': 3,
#  'land': 3,
#  'continue': 3,
#  'produce': 3,
#  'human': 3,
#  'man': 3,
#  'creature': 3,
#  'milk': 3,
#  'egg': 3,
#  'bare': 3,
#  'field': 3,
#  'future': 3,
#  'vote': 3,
#  'Beasts': 3,
#  'house': 2,
#  'ring': 2,
#  'light': 2,
#  'lantern': 2,
#  'yard': 2,
#  'door': 2,
#  'bedroom': 2,
#  'stirring': 2,
#  'strange': 2,
#  'wish': 2,
#  'agree': 2,
#  'big': 2,
#  'order': 2,
#  'hear': 2,
#  'sort': 2,
#  'raise': 2,
#  'platform': 2,
#  'grow': 2,
#  'stout': 2,
#  'appearance': 2,
#  'fact': 2,
#  'cut': 2,
#  'comfortable': 2,
#  'lie': 2,
#  'chew': 2,
#  'small': 2,
#  'clover': 2,
#  'mare': 2,
#  'foal': 2,
#  'nearly': 2,
#  'nose': 2,
#  'stupid': 2,
#  'power': 2,
#  'Benjamin': 2,
#  'usually': 2,
#  'tail': 2,
#  'laugh': 2,
#  'duckling': 2,
#  'mother': 2,
#  'wall': 2,
#  'asleep': 2,
#  'near': 2,
#  'cat': 2,
#  'later': 2,
#  'think': 2,
#  'die': 2,
#  'duty': 2,
#  'stall': 2,
#  'earth': 2,
#  'short': 2,
#  'food': 2,
#  'body': 2,
#  'capable': 2,
#  'afford': 2,
#  'soil': 2,
#  'number': 2,
#  'single': 2,
#  'support': 2,
#  'weak': 2,
#  'run': 2,
#  'catch': 2,
#  'rabbit': 2,
#  'rest': 2,
#  'money': 2,
#  'sell': 2,
#  'lead': 2,
#  'reach': 2,
#  'natural': 2,
#  'sit': 2,
#  'evil': 2,
#  'spring': 2,
#  'rich': 2,
#  'message': 2,
#  'generation': 2,
#  'struggle': 2,
#  'tell': 2,
#  'interest': 2,
#  'prosperity': 2,
#  'perfect': 2,
#  'uproar': 2,
#  'hole': 2,
#  'friend': 2,
#  'meeting': 2,
#  'little': 2,
#  'leg': 2,
#  'clever': 2,
#  'vanish': 2,
#  'ago': 2,
#  'mind': 2,
#  'voice': 2,
#  'hoarse': 2,
#  'Ireland': 2,
#  'clime': 2,
#  'Hearken': 2,
#  'tiding': 2,
#  'golden': 2,
#  'break': 2,
#  'singe': 2,
#  'chapter': 1,
#  'Manor': 1,
#  'Farm': 1,
#  'lock': 1,
#  'drunk': 1,
#  'shut': 1,
#  'pophole': 1,
#  'dancing': 1,
#  'lurch': 1,
#  'kick': 1,
#  'boot': 1,
#  'glass': 1,
#  'beer': 1,
#  'barrel': 1,
#  'scullery': 1,
#  'Mrs.': 1,
#  'snore': 1,
#  'fluttering': 1,
#  'building': 1,
#  'Word': 1,
#  'prize': 1,
#  'Middle': 1,
#  'White': 1,
#  'boar': 1,
#  'previous': 1,
#  'communicate': 1,
#  'meet': 1,
#  'safely': 1,
#  'exhibit': 1,
#  'Willingdon': 1,
#  'Beauty': 1,
#  'highly': 1,
#  'regard': 1,
#  'ready': 1,
#  'hour': 1,
#  'ensconce': 1,
#  'hang': 1,
#  'beam': 1,
#  'lately': 1,
#  'majestic': 1,
#  '-looking': 1,
#  'wise': 1,
#  'benevolent': 1,
#  'spite': 1,
#  'tush': 1,
#  'arrive': 1,
#  'different': 1,
#  'fashion': 1,
#  'Bluebell': 1,
#  'Jessie': 1,
#  'Pincher': 1,
#  'immediately': 1,
#  'window': 1,
#  'sill': 1,
#  'pigeon': 1,
#  'flutter': 1,
#  'rafter': 1,
#  'cud': 1,
#  'cart': 1,
#  'walk': 1,
#  'slowly': 1,
#  'vast': 1,
#  'hairy': 1,
#  'hoof': 1,
#  'care': 1,
#  'lest': 1,
#  'conceal': 1,
#  'motherly': 1,
#  'approach': 1,
#  'middle': 1,
#  'figure': 1,
#  'fourth': 1,
#  'enormous': 1,
#  'hand': 1,
#  'high': 1,
#  'strong': 1,
#  'ordinary': 1,
#  'stripe': 1,
#  'somewhat': 1,
#  'rate': 1,
#  'intelligence': 1,
#  'universally': 1,
#  'respect': 1,
#  'steadiness': 1,
#  'character': 1,
#  'Muriel': 1,
#  'goat': 1,
#  'donkey': 1,
#  'bad': 1,
#  'temper': 1,
#  'seldom': 1,
#  'talk': 1,
#  'cynical': 1,
#  'remark': 1,
#  'instance': 1,
#  'God': 1,
#  'ask': 1,
#  'openly': 1,
#  'admit': 1,
#  'devoted': 1,
#  'spend': 1,
#  'sunday': 1,
#  'paddock': 1,
#  'orchard': 1,
#  'graze': 1,
#  'lain': 1,
#  'brood': 1,
#  'file': 1,
#  'cheep': 1,
#  'feebly': 1,
#  'wander': 1,
#  'find': 1,
#  'tread': 1,
#  'foreleg': 1,
#  'nestle': 1,
#  'inside': 1,
#  'promptly': 1,
#  'fall': 1,
#  'Mollie': 1,
#  'foolish': 1,
#  'pretty': 1,
#  'trap': 1,
#  'mincing': 1,
#  'daintily': 1,
#  'lump': 1,
#  'sugar': 1,
#  'flirt': 1,
#  'mane': 1,
#  'hope': 1,
#  'attention': 1,
#  'red': 1,
#  'ribbon': 1,
#  'plait': 1,
#  'look': 1,
#  'usual': 1,
#  'warm': 1,
#  'finally': 1,
#  'squeeze': 1,
#  'purr': 1,
#  'contentedly': 1,
#  'speech': 1,
#  'present': 1,
#  'Moses': 1,
#  'tame': 1,
#  'raven': 1,
#  'wait': 1,
#  'attentively': 1,
#  'month': 1,
#  'feel': 1,
#  'wisdom': 1,
#  'acquire': 1,
#  'thought': 1,
#  'understand': 1,
#  'face': 1,
#  'laborious': 1,
#  'bear': 1,
#  'w': 1,
#  'ill': 1,
#  'breath': 1,
#  'force': 1,
#  'atom': 1,
#  'strength': 1,
#  'instant': 1,
#  'usefulness': 1,
#  'slaughter': 1,
#  'hideous': 1,
#  'cruelty': 1,
#  'meaning': 1,
#  'happiness': 1,
#  'leisure': 1,
#  'misery': 1,
#  'slavery': 1,
#  'plain': 1,
#  'truth': 1,
#  'simply': 1,
#  'poor': 1,
#  'decent': 1,
#  'dwell': 1,
#  'fertile': 1,
#  'climate': 1,
#  'good': 1,
#  'abundance': 1,
#  'enormously': 1,
#  'inhabit': 1,
#  't': 1,
#  'dozen': 1,
#  'comfort': 1,
#  'dignity': 1,
#  'imagining': 1,
#  'condition': 1,
#  'steal': 1,
#  'answer': 1,
#  'problem': 1,
#  'sum': 1,
#  '.': 1,
#  'real': 1,
#  'remove': 1,
#  'scene': 1,
#  'root': 1,
#  'cause': 1,
#  'hunger': 1,
#  'overwork': 1,
#  'abolish': 1,
#  'consume': 1,
#  'pull': 1,
#  'plough': 1,
#  'fast': 1,
#  'lord': 1,
#  'minimum': 1,
#  'prevent': 1,
#  'starve': 1,
#  'till': 1,
#  'dung': 1,
#  'fertilise': 1,
#  'skin': 1,
#  'thousand': 1,
#  'gallon': 1,
#  'happen': 1,
#  'breed': 1,
#  'sturdy': 1,
#  'calf': 1,
#  'drop': 1,
#  'hatch': 1,
#  'chicken': 1,
#  'market': 1,
#  'bring': 1,
#  'bore': 1,
#  'pleasure': 1,
#  'age': 1,
#  'return': 1,
#  'confinement': 1,
#  'ration': 1,
#  'allow': 1,
#  'span': 1,
#  'grumble': 1,
#  'lucky': 1,
#  'child': 1,
#  'escape': 1,
#  'cruel': 1,
#  'knife': 1,
#  'young': 1,
#  'porker': 1,
#  'scream': 1,
#  'block': 1,
#  'horror': 1,
#  'fate': 1,
#  'muscle': 1,
#  'knacker': 1,
#  'boil': 1,
#  'foxhound': 1,
#  'toothless': 1,
#  'tie': 1,
#  'brick': 1,
#  'neck': 1,
#  'drown': 1,
#  'pond': 1,
#  'crystal': 1,
#  'tyranny': 1,
#  'rid': 1,
#  'overnight': 1,
#  'soul': 1,
#  'overthrow': 1,
#  'race': 1,
#  'rebellion': 1,
#  'Rebellion': 1,
#  'week': 1,
#  'surely': 1,
#  'beneath': 1,
#  'foot': 1,
#  'justice': 1,
#  'fix': 1,
#  'eye': 1,
#  'remainder': 1,
#  'carry': 1,
#  'victorious': 1,
#  'resolution': 1,
#  'falter': 1,
#  'argument': 1,
#  'astray': 1,
#  'common': 1,
#  'serve': 1,
#  'unity': 1,
#  'comradeship': 1,
#  'large': 1,
#  'creep': 1,
#  'hindquarter': 1,
#  'suddenly': 1,
#  'sight': 1,
#  'swift': 1,
#  'dash': 1,
#  'save': 1,
#  'trotter': 1,
#  'silence': 1,
#  'point': 1,
#  'wild': 1,
#  'propose': 1,
#  'question': 1,
#  'overwhelming': 1,
#  'majority': 1,
#  'dissentient': 1,
#  'discover': 1,
#  'merely': 1,
#  'repeat': 1,
#  'enmity': 1,
#  'wing': 1,
#  'fight': 1,
#  'resemble': 1,
#  'conquer': 1,
#  'adopt': 1,
#  'vice': 1,
#  'wear': 1,
#  'clothe': 1,
#  'drink': 1,
#  'alcohol': 1,
#  'smoke': 1,
#  'tobacco': 1,
#  'touch': 1,
#  'engage': 1,
#  'trade': 1,
#  'habit': 1,
#  'tyrannise': 1,
#  'kind': 1,
#  'simple': 1,
#  'brother': 1,
#  'kill': 1,
#  'equal': 1,
#  'describe': 1,
#  'remind': 1,
#  'forget': 1,
#  'sow': 1,
#  'use': 1,
#  'infancy': 1,
#  'certain': 1,
#  'memory': 1,
#  'teach': 1,
#  'Old': 1,
#  'Clementine': 1,
#  'La': 1,
#  'Cucuracha': 1,
#  'joyful': 1,
#  'late': 1,
#  'Tyrant': 1,
#  "o'erthrown": 1,
#  'fruitful': 1,
#  'trod': 1,
#  'harness': 1,
#  'bit': 1,
#  'spur': 1,
#  'rust': 1,
#  'forever': 1,
#  'Cruel': 1,
#  'whip': 1,
#  'crack': 1,
#  'picture': 1,
#  'wheat': 1,
#  'barley': 1,
#  'oat': 1,
#  'hay': 1,
#  'bean': 1,
#  'mangel': 1,
#  'wurzel': 1,
#  'bright': 1,
#  'shine': 1,
#  'Purer': 1,
#  'water': 1,
#  'sweet': 1,
#  'blow': 1,
#  'breeze': 1,
#  'geese': 1,
#  'turkey': 1,
#  'toil': 1,
#  'freedom': 1,
#  'sake': 1,
#  'spread': 1,
#  'singing': 1,
#  'throw': 1,
#  'wildest': 1,
#  'excitement': 1,
#  '4of': 1,
#  'pick': 1,
#  'entire': 1,
#  'heart': 1,
#  'minute': 1,
#  'preliminary': 1,
#  'try': 1,
#  'burst': 1,
#  'unison': 1,
#  'low': 1,
#  'whine': 1,
#  'bleat': 1,
#  'whinny': 1,
#  'duck': 1,
#  'quack': 1,
#  'delighted': 1,
#  'right': 1,
#  'succession': 1,
#  'interrupt': 1,
#  'unfortunately': 1,
#  'awake': 1,
#  'sure': 1,
#  'fox': 1,
#  'seize': 1,
#  'gun': 1,
#  'stand': 1,
#  'corner': 1,
#  'charge': 1,
#  'shot': 1,
#  'darkness': 1,
#  'pellet': 1,
#  'bury': 1,
#  'hurriedly': 1,
#  'flee': 1,
#  'sleeping': 1,
#  'bird': 1,
#  'jump': 1}

# %% [markdown]
# <h1>Animal Farm</h1>
# Here we process the way we did for chapter one but now it is done for the whole book

# %%
whole_text = ''

for chapter in chapters:
    whole_text += chapter + '\n'
    
words = token_frequency(whole_text, not_include=['PUNCT', 'NUM', 'SPACE', 'PROPN'], verbos=True)
# Out:
# Chapter          NOUN         compound     chapter          noun, singular or mass
# locked           VERB         ROOT         lock             verb, past participle
# hen              NOUN         compound     hen              noun, singular or mass
# houses           NOUN         dobj         house            noun, plural
# night            NOUN         pobj         night            noun, singular or mass
# drunk            ADJ          acomp        drunk            adjective (English), other noun-modifier (Chinese)
# remember         VERB         xcomp        remember         verb, base form
# shut             VERB         xcomp        shut             verb, base form
# popholes         NOUN         dobj         pophole          noun, plural
# ring             NOUN         pobj         ring             noun, singular or mass
# light            NOUN         pobj         light            noun, singular or mass
# lantern          ADJ          amod         lantern          adjective (English), other noun-modifier (Chinese)
# dancing          NOUN         pobj         dancing          noun, singular or mass
# lurched          VERB         ROOT         lurch            verb, past tense
# yard             NOUN         pobj         yard             noun, singular or mass
# kicked           VERB         conj         kick             verb, past tense
# boots            NOUN         dobj         boot             noun, plural
# door             NOUN         pobj         door             noun, singular or mass
# drew             VERB         conj         draw             verb, past tense
# glass            NOUN         dobj         glass            noun, singular or mass
# beer             NOUN         pobj         beer             noun, singular or mass
# barrel           NOUN         pobj         barrel           noun, singular or mass
# scullery         NOUN         pobj         scullery         noun, singular or mass
# way              NOUN         dobj         way              noun, singular or mass
# bed              NOUN         pobj         bed              noun, singular or mass
# snoring          VERB         relcl        snore            verb, gerund or present participle
# soon             ADV          advmod       soon             adverb
# light            NOUN         nsubj        light            noun, singular or mass
# bedroom          NOUN         pobj         bedroom          noun, singular or mass
# stirring         NOUN         attr         stirring         noun, singular or mass
# fluttering       NOUN         conj         fluttering       noun, singular or mass
# farm             NOUN         compound     farm             noun, singular or mass
# buildings        NOUN         pobj         building         noun, plural
# round            ADJ          advmod       round            adjective (English), other noun-modifier (Chinese)
# day              NOUN         pobj         day              noun, singular or mass
# old              ADJ          amod         old              adjective (English), other noun-modifier (Chinese)
# prize            NOUN         appos        prize            noun, singular or mass
# boar             NOUN         appos        boar             noun, singular or mass
# strange          ADJ          amod         strange          adjective (English), other noun-modifier (Chinese)
# dream            NOUN         dobj         dream            noun, singular or mass
# previous         ADJ          amod         previous         adjective (English), other noun-modifier (Chinese)
# night            NOUN         pobj         night            noun, singular or mass
# wished           VERB         conj         wish             verb, past tense
# communicate      VERB         xcomp        communicate      verb, base form
# animals          NOUN         pobj         animal           noun, plural
# agreed           VERB         ROOT         agree            verb, past participle
# meet             VERB         ccomp        meet             verb, base form
# big              ADJ          amod         big              adjective (English), other noun-modifier (Chinese)
# barn             NOUN         pobj         barn             noun, singular or mass
# soon             ADV          advmod       soon             adverb
# safely           ADV          advmod       safely           adverb
# way              NOUN         pobj         way              noun, singular or mass
# Old              ADJ          amod         old              adjective (English), other noun-modifier (Chinese)
# exhibited        VERB         relcl        exhibit          verb, past participle
# highly           ADV          advmod       highly           adverb
# regarded         VERB         acomp        regard           verb, past participle
# farm             NOUN         pobj         farm             noun, singular or mass
# ready            ADJ          acomp        ready            adjective (English), other noun-modifier (Chinese)
# lose             VERB         xcomp        lose             verb, base form
# hour             NOUN         poss         hour             noun, singular or mass
# sleep            NOUN         dobj         sleep            noun, singular or mass
# order            NOUN         pobj         order            noun, singular or mass
# hear             VERB         acl          hear             verb, base form
# end              NOUN         pobj         end              noun, singular or mass
# big              ADJ          amod         big              adjective (English), other noun-modifier (Chinese)
# barn             NOUN         pobj         barn             noun, singular or mass
# sort             NOUN         pobj         sort             noun, singular or mass
# raised           VERB         amod         raise            verb, past participle
# platform         NOUN         pobj         platform         noun, singular or mass
# ensconced        VERB         ROOT         ensconce         verb, past participle
# bed              NOUN         pobj         bed              noun, singular or mass
# straw            NOUN         pobj         straw            noun, singular or mass
# lantern          NOUN         pobj         lantern          noun, singular or mass
# hung             VERB         relcl        hang             verb, past tense
# beam             NOUN         pobj         beam             noun, singular or mass
# years            NOUN         npadvmod     year             noun, plural
# old              ADJ          acomp        old              adjective (English), other noun-modifier (Chinese)
# lately           ADV          advmod       lately           adverb
# grown            VERB         conj         grow             verb, past participle
# stout            ADJ          advmod       stout            adjective (English), other noun-modifier (Chinese)
# majestic         ADJ          amod         majestic         adjective (English), other noun-modifier (Chinese)
# -looking         NOUN         amod         -looking         noun, singular or mass
# pig              NOUN         attr         pig              noun, singular or mass
# wise             ADJ          amod         wise             adjective (English), other noun-modifier (Chinese)
# benevolent       ADJ          conj         benevolent       adjective (English), other noun-modifier (Chinese)
# appearance       NOUN         pobj         appearance       noun, singular or mass
# spite            NOUN         pobj         spite            noun, singular or mass
# fact             NOUN         pobj         fact             noun, singular or mass
# tushes           NOUN         nsubjpass    tush             noun, plural
# cut              VERB         acl          cut              verb, past participle
# long             ADV          pcomp        long             adverb
# animals          NOUN         nsubj        animal           noun, plural
# began            VERB         ROOT         begin            verb, past tense
# arrive           VERB         xcomp        arrive           verb, base form
# comfortable      ADJ          ccomp        comfortable      adjective (English), other noun-modifier (Chinese)
# different        ADJ          amod         different        adjective (English), other noun-modifier (Chinese)
# fashions         NOUN         pobj         fashion          noun, plural
# came             VERB         ROOT         come             verb, past tense
# dogs             NOUN         nsubj        dog              noun, plural
# pigs             NOUN         conj         pig              noun, plural
# settled          VERB         relcl        settle           verb, past tense
# straw            NOUN         pobj         straw            noun, singular or mass
# immediately      ADV          advmod       immediately      adverb
# platform         NOUN         pobj         platform         noun, singular or mass
# hens             NOUN         nsubj        hen              noun, plural
# perched          VERB         ccomp        perch            verb, past tense
# window           NOUN         compound     window           noun, singular or mass
# sills            NOUN         pobj         sill             noun, plural
# pigeons          NOUN         nsubj        pigeon           noun, plural
# fluttered        VERB         ccomp        flutter          verb, past tense
# rafters          NOUN         pobj         rafter           noun, plural
# sheep            NOUN         nsubj        sheep            noun, plural
# cows             NOUN         conj         cow              noun, plural
# lay              VERB         ROOT         lie              verb, past tense
# pigs             NOUN         pobj         pig              noun, plural
# began            VERB         conj         begin            verb, past tense
# chew             VERB         xcomp        chew             verb, base form
# cud              NOUN         dobj         cud              noun, singular or mass
# cart             NOUN         compound     cart             noun, singular or mass
# horses           NOUN         nsubj        horse            noun, plural
# came             VERB         ROOT         come             verb, past tense
# walking          VERB         advcl        walk             verb, gerund or present participle
# slowly           ADV          advmod       slowly           adverb
# setting          VERB         conj         set              verb, gerund or present participle
# vast             ADJ          amod         vast             adjective (English), other noun-modifier (Chinese)
# hairy            ADJ          amod         hairy            adjective (English), other noun-modifier (Chinese)
# hoofs            NOUN         dobj         hoof             noun, plural
# great            ADJ          amod         great            adjective (English), other noun-modifier (Chinese)
# care             NOUN         pobj         care             noun, singular or mass
# lest             SCONJ        mark         lest             conjunction, subordinating or preposition
# small            ADJ          amod         small            adjective (English), other noun-modifier (Chinese)
# animal           NOUN         attr         animal           noun, singular or mass
# concealed        VERB         acl          conceal          verb, past participle
# straw            NOUN         pobj         straw            noun, singular or mass
# Clover           NOUN         nsubj        clover           noun, singular or mass
# stout            ADJ          amod         stout            adjective (English), other noun-modifier (Chinese)
# motherly         ADJ          amod         motherly         adjective (English), other noun-modifier (Chinese)
# mare             NOUN         attr         mare             noun, singular or mass
# approaching      VERB         acl          approach         verb, gerund or present participle
# middle           ADJ          amod         middle           adjective (English), other noun-modifier (Chinese)
# life             NOUN         dobj         life             noun, singular or mass
# figure           NOUN         dobj         figure           noun, singular or mass
# fourth           ADJ          amod         fourth           adjective (English), other noun-modifier (Chinese)
# foal             NOUN         pobj         foal             noun, singular or mass
# enormous         ADJ          amod         enormous         adjective (English), other noun-modifier (Chinese)
# beast            NOUN         attr         beast            noun, singular or mass
# nearly           ADV          advmod       nearly           adverb
# hands            NOUN         nsubj        hand             noun, plural
# high             ADJ          amod         high             adjective (English), other noun-modifier (Chinese)
# strong           ADJ          conj         strong           adjective (English), other noun-modifier (Chinese)
# ordinary         ADJ          amod         ordinary         adjective (English), other noun-modifier (Chinese)
# horses           NOUN         nsubj        horse            noun, plural
# white            ADJ          amod         white            adjective (English), other noun-modifier (Chinese)
# stripe           NOUN         nsubj        stripe           noun, singular or mass
# nose             NOUN         pobj         nose             noun, singular or mass
# somewhat         ADV          advmod       somewhat         adverb
# stupid           ADJ          amod         stupid           adjective (English), other noun-modifier (Chinese)
# appearance       NOUN         dobj         appearance       noun, singular or mass
# fact             NOUN         pobj         fact             noun, singular or mass
# rate             NOUN         compound     rate             noun, singular or mass
# intelligence     NOUN         pobj         intelligence     noun, singular or mass
# universally      ADV          advmod       universally      adverb
# respected        VERB         conj         respect          verb, past participle
# steadiness       NOUN         pobj         steadiness       noun, singular or mass
# character        NOUN         pobj         character        noun, singular or mass
# tremendous       ADJ          amod         tremendous       adjective (English), other noun-modifier (Chinese)
# powers           NOUN         conj         power            noun, plural
# work             NOUN         pobj         work             noun, singular or mass
# horses           NOUN         nsubj        horse            noun, plural
# came             VERB         ROOT         come             verb, past tense
# donkey           NOUN         appos        donkey           noun, singular or mass
# oldest           ADJ          amod         old              adjective, superlative
# animal           NOUN         attr         animal           noun, singular or mass
# farm             NOUN         pobj         farm             noun, singular or mass
# worst            ADJ          nsubj        bad              adjective, superlative
# tempered         VERB         conj         temper           verb, past participle
# seldom           ADV          advmod       seldom           adverb
# talked           VERB         ccomp        talk             verb, past tense
# usually          ADV          advmod       usually          adverb
# cynical          ADJ          amod         cynical          adjective (English), other noun-modifier (Chinese)
# remark           NOUN         dobj         remark           noun, singular or mass
# instance         NOUN         pobj         instance         noun, singular or mass
# tail             NOUN         dobj         tail             noun, singular or mass
# flies            NOUN         dobj         fly              noun, plural
# sooner           ADV          advmod       soon             adverb
# tail             NOUN         dobj         tail             noun, singular or mass
# flies            NOUN         conj         fly              noun, plural
# animals          NOUN         pobj         animal           noun, plural
# farm             NOUN         pobj         farm             noun, singular or mass
# laughed          VERB         relcl        laugh            verb, past tense
# asked            VERB         advcl        ask              verb, past participle
# laugh            VERB         relcl        laugh            verb, base form
# openly           ADV          advmod       openly           adverb
# admitting        VERB         pcomp        admit            verb, gerund or present participle
# devoted          ADJ          acomp        devoted          adjective (English), other noun-modifier (Chinese)
# usually          ADV          advmod       usually          adverb
# spent            VERB         ROOT         spend            verb, past tense
# Sundays          NOUN         dobj         sunday           noun, plural
# small            ADJ          amod         small            adjective (English), other noun-modifier (Chinese)
# paddock          NOUN         pobj         paddock          noun, singular or mass
# orchard          NOUN         pobj         orchard          noun, singular or mass
# grazing          VERB         compound     graze            verb, gerund or present participle
# speaking         VERB         conj         speak            verb, gerund or present participle
# horses           NOUN         nsubj        horse            noun, plural
# lain             VERB         ROOT         lain             verb, base form
# brood            NOUN         nsubj        brood            noun, singular or mass
# ducklings        NOUN         pobj         duckling         noun, plural
# lost             VERB         relcl        lose             verb, past participle
# mother           NOUN         dobj         mother           noun, singular or mass
# filed            VERB         advcl        file             verb, past participle
# barn             NOUN         pobj         barn             noun, singular or mass
# cheeping         VERB         advcl        cheep            verb, gerund or present participle
# feebly           ADV          advmod       feebly           adverb
# wandering        VERB         conj         wander           verb, gerund or present participle
# find             VERB         advcl        find             verb, base form
# place            NOUN         dobj         place            noun, singular or mass
# trodden          VERB         relcl        tread            verb, past participle
# Clover           NOUN         nsubj        clover           noun, singular or mass
# sort             NOUN         dobj         sort             noun, singular or mass
# wall             NOUN         pobj         wall             noun, singular or mass
# round            VERB         advcl        round            verb, base form
# great            ADJ          amod         great            adjective (English), other noun-modifier (Chinese)
# foreleg          NOUN         pobj         foreleg          noun, singular or mass
# ducklings        NOUN         nsubj        duckling         noun, plural
# nestled          VERB         conj         nestle           verb, past tense
# inside           ADP          prep         inside           conjunction, subordinating or preposition
# promptly         ADV          advmod       promptly         adverb
# fell             VERB         conj         fall             verb, past tense
# asleep           ADJ          acomp        asleep           adjective (English), other noun-modifier (Chinese)
# moment           NOUN         pobj         moment           noun, singular or mass
# foolish          ADJ          amod         foolish          adjective (English), other noun-modifier (Chinese)
# pretty           ADV          advmod       pretty           adverb
# white            ADJ          amod         white            adjective (English), other noun-modifier (Chinese)
# mare             NOUN         appos        mare             noun, singular or mass
# drew             VERB         relcl        draw             verb, past tense
# trap             NOUN         dobj         trap             noun, singular or mass
# mincing          NOUN         appos        mincing          noun, singular or mass
# daintily         ADV          advmod       daintily         adverb
# chewing          VERB         ROOT         chew             verb, gerund or present participle
# lump             NOUN         pobj         lump             noun, singular or mass
# sugar            NOUN         pobj         sugar            noun, singular or mass
# place            NOUN         dobj         place            noun, singular or mass
# near             ADP          prep         near             conjunction, subordinating or preposition
# began            VERB         conj         begin            verb, past tense
# flirting         VERB         xcomp        flirt            verb, gerund or present participle
# white            ADJ          amod         white            adjective (English), other noun-modifier (Chinese)
# mane             NOUN         dobj         mane             noun, singular or mass
# hoping           VERB         advcl        hope             verb, gerund or present participle
# draw             VERB         xcomp        draw             verb, base form
# attention        NOUN         dobj         attention        noun, singular or mass
# red              ADJ          amod         red              adjective (English), other noun-modifier (Chinese)
# ribbons          NOUN         pobj         ribbon           noun, plural
# plaited          VERB         relcl        plait            verb, past participle
# came             VERB         ccomp        come             verb, past tense
# cat              NOUN         nsubj        cat              noun, singular or mass
# looked           VERB         relcl        look             verb, past tense
# round            ADV          advmod       round            adverb
# usual            ADJ          amod         usual            adjective (English), other noun-modifier (Chinese)
# warmest          ADJ          amod         warm             adjective, superlative
# place            NOUN         pobj         place            noun, singular or mass
# finally          ADV          advmod       finally          adverb
# squeezed         VERB         conj         squeeze          verb, past tense
# purred           VERB         ROOT         purr             verb, past tense
# contentedly      ADV          advmod       contentedly      adverb
# speech           NOUN         pobj         speech           noun, singular or mass
# listening        VERB         pcomp        listen           verb, gerund or present participle
# word             NOUN         pobj         word             noun, singular or mass
# animals          NOUN         nsubj        animal           noun, plural
# present          ADJ          acomp        present          adjective (English), other noun-modifier (Chinese)
# tame             NOUN         compound     tame             noun, singular or mass
# raven            NOUN         appos        raven            noun, singular or mass
# slept            VERB         relcl        sleep            verb, past tense
# perch            NOUN         pobj         perch            noun, singular or mass
# door             NOUN         pobj         door             noun, singular or mass
# comfortable      ADJ          ccomp        comfortable      adjective (English), other noun-modifier (Chinese)
# waiting          VERB         conj         wait             verb, gerund or present participle
# attentively      ADV          advmod       attentively      adverb
# cleared          VERB         ROOT         clear            verb, past tense
# throat           NOUN         dobj         throat           noun, singular or mass
# began            VERB         conj         begin            verb, past tense
# Comrades         NOUN         dobj         comrade          noun, plural
# heard            VERB         relcl        hear             verb, past participle
# strange          ADJ          amod         strange          adjective (English), other noun-modifier (Chinese)
# dream            NOUN         pobj         dream            noun, singular or mass
# night            NOUN         npadvmod     night            noun, singular or mass
# come             VERB         ROOT         come             verb, base form
# dream            NOUN         pobj         dream            noun, singular or mass
# later            ADV          advmod       later            adverb
# think            VERB         ROOT         think            verb, base form
# comrades         NOUN         npadvmod     comrade          noun, plural
# shall            AUX          aux          shall            verb, modal auxiliary
# months           NOUN         npadvmod     month            noun, plural
# longer           ADV          advmod       long             adverb, comparative
# die              VERB         advcl        die              verb, non-3rd person singular present
# feel             VERB         conj         feel             verb, non-3rd person singular present
# duty             NOUN         ROOT         duty             noun, singular or mass
# pass             VERB         relcl        pass             verb, base form
# wisdom           NOUN         dobj         wisdom           noun, singular or mass
# acquired         VERB         advcl        acquire          verb, past participle
# long             ADJ          amod         long             adjective (English), other noun-modifier (Chinese)
# life             NOUN         dobj         life             noun, singular or mass
# time             NOUN         dobj         time             noun, singular or mass
# thought          NOUN         pobj         thought          noun, singular or mass
# lay              VERB         advcl        lay              verb, non-3rd person singular present
# stall            NOUN         pobj         stall            noun, singular or mass
# think            VERB         conj         think            verb, non-3rd person singular present
# understand       VERB         ccomp        understand       verb, non-3rd person singular present
# nature           NOUN         dobj         nature           noun, singular or mass
# life             NOUN         pobj         life             noun, singular or mass
# earth            NOUN         pobj         earth            noun, singular or mass
# animal           NOUN         nsubj        animal           noun, singular or mass
# living           VERB         relcl        live             verb, gerund or present participle
# wish             VERB         ccomp        wish             verb, non-3rd person singular present
# speak            VERB         xcomp        speak            verb, base form
# comrades         NOUN         nmod         comrade          noun, plural
# nature           NOUN         nsubj        nature           noun, singular or mass
# life             NOUN         pobj         life             noun, singular or mass
# Let              VERB         advcl        let              verb, base form
# face             VERB         ccomp        face             verb, base form
# lives            NOUN         nsubj        life             noun, plural
# miserable        ADJ          acomp        miserable        adjective (English), other noun-modifier (Chinese)
# laborious        ADJ          conj         laborious        adjective (English), other noun-modifier (Chinese)
# short            ADJ          conj         short            adjective (English), other noun-modifier (Chinese)
# born             VERB         ccomp        bear             verb, past participle
# food             NOUN         dobj         food             noun, singular or mass
# ill              ADJ          amod         ill              adjective (English), other noun-modifier (Chinese)
# breath           NOUN         dobj         breath           noun, singular or mass
# bodies           NOUN         pobj         body             noun, plural
# capable          ADJ          acomp        capable          adjective (English), other noun-modifier (Chinese)
# forced           VERB         conj         force            verb, past participle
# work             VERB         xcomp        work             verb, base form
# atom             NOUN         pobj         atom             noun, singular or mass
# strength         NOUN         pobj         strength         noun, singular or mass
# instant          NOUN         conj         instant          noun, singular or mass
# usefulness       NOUN         nsubj        usefulness       noun, singular or mass
# come             VERB         acl          come             verb, past participle
# end              NOUN         pobj         end              noun, singular or mass
# slaughtered      VERB         relcl        slaughter        verb, past participle
# hideous          ADJ          amod         hideous          adjective (English), other noun-modifier (Chinese)
# cruelty          NOUN         pobj         cruelty          noun, singular or mass
# animal           NOUN         nsubj        animal           noun, singular or mass
# knows            VERB         ROOT         know             verb, 3rd person singular present
# meaning          NOUN         dobj         meaning          noun, singular or mass
# happiness        NOUN         pobj         happiness        noun, singular or mass
# leisure          NOUN         conj         leisure          noun, singular or mass
# year             NOUN         npadvmod     year             noun, singular or mass
# old              ADJ          acomp        old              adjective (English), other noun-modifier (Chinese)
# animal           NOUN         nsubj        animal           noun, singular or mass
# free             ADJ          acomp        free             adjective (English), other noun-modifier (Chinese)
# life             NOUN         nsubj        life             noun, singular or mass
# animal           NOUN         pobj         animal           noun, singular or mass
# misery           NOUN         attr         misery           noun, singular or mass
# slavery          NOUN         conj         slavery          noun, singular or mass
# plain            ADJ          amod         plain            adjective (English), other noun-modifier (Chinese)
# truth            NOUN         attr         truth            noun, singular or mass
# simply           ADV          advmod       simply           adverb
# order            NOUN         pobj         order            noun, singular or mass
# nature           NOUN         pobj         nature           noun, singular or mass
# land             NOUN         nsubj        land             noun, singular or mass
# poor             ADJ          acomp        poor             adjective (English), other noun-modifier (Chinese)
# afford           VERB         ccomp        afford           verb, base form
# decent           ADJ          amod         decent           adjective (English), other noun-modifier (Chinese)
# life             NOUN         dobj         life             noun, singular or mass
# dwell            VERB         relcl        dwell            verb, non-3rd person singular present
# comrades         NOUN         ROOT         comrade          noun, plural
# times            NOUN         quantmod     time             noun, plural
# soil             NOUN         nsubj        soil             noun, singular or mass
# fertile          ADJ          acomp        fertile          adjective (English), other noun-modifier (Chinese)
# climate          NOUN         nsubj        climate          noun, singular or mass
# good             ADJ          acomp        good             adjective (English), other noun-modifier (Chinese)
# capable          ADJ          acomp        capable          adjective (English), other noun-modifier (Chinese)
# affording        VERB         pcomp        afford           verb, gerund or present participle
# food             NOUN         dobj         food             noun, singular or mass
# abundance        NOUN         pobj         abundance        noun, singular or mass
# enormously       ADV          advmod       enormously       adverb
# greater          ADJ          amod         great            adjective, comparative
# number           NOUN         pobj         number           noun, singular or mass
# animals          NOUN         pobj         animal           noun, plural
# inhabit          VERB         advcl        inhabit          verb, base form
# T                NOUN         nsubj        t                noun, singular or mass
# single           ADJ          amod         single           adjective (English), other noun-modifier (Chinese)
# farm             NOUN         appos        farm             noun, singular or mass
# support          VERB         ROOT         support          verb, base form
# dozen            NOUN         nummod       dozen            noun, singular or mass
# horses           NOUN         dobj         horse            noun, plural
# cows             NOUN         appos        cow              noun, plural
# sheep            NOUN         pobj         sheep            noun, singular or mass
# living           VERB         acl          live             verb, gerund or present participle
# comfort          NOUN         pobj         comfort          noun, singular or mass
# dignity          NOUN         conj         dignity          noun, singular or mass
# imagining        NOUN         pobj         imagining        noun, singular or mass
# continue         VERB         ROOT         continue         verb, base form
# miserable        ADJ          amod         miserable        adjective (English), other noun-modifier (Chinese)
# condition        NOUN         pobj         condition        noun, singular or mass
# nearly           ADV          advmod       nearly           adverb
# produce          NOUN         pobj         produce          noun, singular or mass
# labour           NOUN         pobj         labour           noun, singular or mass
# stolen           VERB         ROOT         steal            verb, past participle
# human            ADJ          amod         human            adjective (English), other noun-modifier (Chinese)
# comrades         NOUN         nsubj        comrade          noun, plural
# answer           NOUN         attr         answer           noun, singular or mass
# problems         NOUN         pobj         problem          noun, plural
# summed           VERB         ROOT         sum              verb, past participle
# single           ADJ          amod         single           adjective (English), other noun-modifier (Chinese)
# word             NOUN         pobj         word             noun, singular or mass
# real             ADJ          amod         real             adjective (English), other noun-modifier (Chinese)
# enemy            NOUN         attr         enemy            noun, singular or mass
# Remove           VERB         ROOT         remove           verb, base form
# scene            NOUN         pobj         scene            noun, singular or mass
# root             NOUN         compound     root             noun, singular or mass
# cause            NOUN         nsubjpass    cause            noun, singular or mass
# hunger           NOUN         pobj         hunger           noun, singular or mass
# overwork         NOUN         conj         overwork         noun, singular or mass
# abolished        VERB         conj         abolish          verb, past participle
# Man              NOUN         nsubj        man              noun, singular or mass
# creature         NOUN         attr         creature         noun, singular or mass
# consumes         VERB         relcl        consume          verb, 3rd person singular present
# producing        VERB         pcomp        produce          verb, gerund or present participle
# milk             NOUN         dobj         milk             noun, singular or mass
# lay              VERB         ccomp        lay              verb, base form
# eggs             NOUN         dobj         egg              noun, plural
# weak             ADJ          acomp        weak             adjective (English), other noun-modifier (Chinese)
# pull             VERB         xcomp        pull             verb, base form
# plough           NOUN         dobj         plough           noun, singular or mass
# run              VERB         ROOT         run              verb, base form
# fast             ADV          advmod       fast             adverb
# catch            VERB         xcomp        catch            verb, base form
# rabbits          NOUN         dobj         rabbit           noun, plural
# animals          NOUN         pobj         animal           noun, plural
# sets             VERB         ccomp        set              verb, 3rd person singular present
# work             VERB         xcomp        work             verb, base form
# bare             ADJ          amod         bare             adjective (English), other noun-modifier (Chinese)
# minimum          NOUN         dobj         minimum          noun, singular or mass
# prevent          VERB         relcl        prevent          verb, base form
# starving         VERB         pcomp        starve           verb, gerund or present participle
# rest             NOUN         conj         rest             noun, singular or mass
# labour           NOUN         nsubj        labour           noun, singular or mass
# tills            VERB         ccomp        till             verb, 3rd person singular present
# soil             NOUN         dobj         soil             noun, singular or mass
# dung             NOUN         nsubj        dung             noun, singular or mass
# fertilises       VERB         ROOT         fertilise        verb, 3rd person singular present
# bare             ADJ          amod         bare             adjective (English), other noun-modifier (Chinese)
# skin             NOUN         pobj         skin             noun, singular or mass
# cows             VERB         ccomp        cow              verb, 3rd person singular present
# thousands        NOUN         dobj         thousand         noun, plural
# gallons          NOUN         pobj         gallon           noun, plural
# milk             NOUN         pobj         milk             noun, singular or mass
# year             NOUN         pobj         year             noun, singular or mass
# happened         VERB         ROOT         happen           verb, past participle
# milk             NOUN         pobj         milk             noun, singular or mass
# breeding         VERB         relcl        breed            verb, gerund or present participle
# sturdy           ADJ          amod         sturdy           adjective (English), other noun-modifier (Chinese)
# calves           NOUN         dobj         calf             noun, plural
# drop             NOUN         nsubj        drop             noun, singular or mass
# throats          NOUN         dobj         throat           noun, plural
# enemies          NOUN         pobj         enemy            noun, plural
# hens             VERB         ROOT         hen              verb, 3rd person singular present
# eggs             NOUN         dobj         egg              noun, plural
# laid             VERB         ccomp        lay              verb, past participle
# year             NOUN         npadvmod     year             noun, singular or mass
# eggs             NOUN         pobj         egg              noun, plural
# hatched          VERB         conj         hatch            verb, past participle
# chickens         NOUN         pobj         chicken          noun, plural
# rest             NOUN         nsubj        rest             noun, singular or mass
# market           NOUN         pobj         market           noun, singular or mass
# bring            VERB         advcl        bring            verb, base form
# money            NOUN         dobj         money            noun, singular or mass
# men              NOUN         conj         man              noun, plural
# foals            NOUN         attr         foal             noun, plural
# bore             VERB         relcl        bore             verb, non-3rd person singular present
# support          NOUN         attr         support          noun, singular or mass
# pleasure         NOUN         conj         pleasure         noun, singular or mass
# old              ADJ          amod         old              adjective (English), other noun-modifier (Chinese)
# age              NOUN         pobj         age              noun, singular or mass
# sold             VERB         ccomp        sell             verb, past participle
# year             NOUN         pobj         year             noun, singular or mass
# old              ADJ          amod         old              adjective (English), other noun-modifier (Chinese)
# return           NOUN         pobj         return           noun, singular or mass
# confinements     NOUN         pobj         confinement      noun, plural
# labour           NOUN         dobj         labour           noun, singular or mass
# fields           NOUN         pobj         field            noun, plural
# bare             ADJ          amod         bare             adjective (English), other noun-modifier (Chinese)
# rations          NOUN         pobj         ration           noun, plural
# stall            NOUN         conj         stall            noun, singular or mass
# miserable        ADJ          amod         miserable        adjective (English), other noun-modifier (Chinese)
# lives            NOUN         nsubjpass    life             noun, plural
# lead             VERB         relcl        lead             verb, non-3rd person singular present
# allowed          VERB         ROOT         allow            verb, past participle
# reach            VERB         xcomp        reach            verb, base form
# natural          ADJ          amod         natural          adjective (English), other noun-modifier (Chinese)
# span             NOUN         dobj         span             noun, singular or mass
# grumble          VERB         ROOT         grumble          verb, base form
# lucky            ADJ          amod         lucky            adjective (English), other noun-modifier (Chinese)
# years            NOUN         npadvmod     year             noun, plural
# old              ADJ          acomp        old              adjective (English), other noun-modifier (Chinese)
# children         NOUN         dobj         child            noun, plural
# natural          ADJ          amod         natural          adjective (English), other noun-modifier (Chinese)
# life             NOUN         attr         life             noun, singular or mass
# pig              NOUN         pobj         pig              noun, singular or mass
# animal           NOUN         nsubj        animal           noun, singular or mass
# escapes          VERB         ROOT         escape           verb, 3rd person singular present
# knife            NOUN         dobj         knife            noun, singular or mass
# end              NOUN         pobj         end              noun, singular or mass
# young            ADJ          amod         young            adjective (English), other noun-modifier (Chinese)
# porkers          NOUN         npadvmod     porker           noun, plural
# sitting          VERB         relcl        sit              verb, gerund or present participle
# scream           VERB         ROOT         scream           verb, base form
# lives            NOUN         dobj         life             noun, plural
# block            NOUN         pobj         block            noun, singular or mass
# year             NOUN         pobj         year             noun, singular or mass
# horror           NOUN         pobj         horror           noun, singular or mass
# come             VERB         ROOT         come             verb, base form
# cows             NOUN         dep          cow              noun, plural
# pigs             NOUN         conj         pig              noun, plural
# hens             NOUN         conj         hen              noun, plural
# sheep            NOUN         conj         sheep            noun, singular or mass
# horses           NOUN         nsubj        horse            noun, plural
# dogs             NOUN         conj         dog              noun, plural
# fate             NOUN         dobj         fate             noun, singular or mass
# day              NOUN         appos        day              noun, singular or mass
# great            ADJ          amod         great            adjective (English), other noun-modifier (Chinese)
# muscles          NOUN         nsubj        muscle           noun, plural
# lose             VERB         relcl        lose             verb, non-3rd person singular present
# power            NOUN         dobj         power            noun, singular or mass
# sell             VERB         ROOT         sell             verb, base form
# knacker          NOUN         pobj         knacker          noun, singular or mass
# cut              VERB         relcl        cut              verb, base form
# throat           NOUN         dobj         throat           noun, singular or mass
# boil             VERB         conj         boil             verb, base form
# foxhounds        NOUN         pobj         foxhound         noun, plural
# dogs             NOUN         pobj         dog              noun, plural
# grow             VERB         advcl        grow             verb, non-3rd person singular present
# old              ADJ          acomp        old              adjective (English), other noun-modifier (Chinese)
# toothless        ADJ          conj         toothless        adjective (English), other noun-modifier (Chinese)
# ties             VERB         ROOT         tie              verb, 3rd person singular present
# brick            NOUN         compound     brick            noun, singular or mass
# round            NOUN         dobj         round            noun, singular or mass
# necks            NOUN         appos        neck             noun, plural
# drowns           VERB         conj         drown            verb, 3rd person singular present
# nearest          ADJ          amod         near             adjective, superlative
# pond             NOUN         pobj         pond             noun, singular or mass
# crystal          NOUN         nsubj        crystal          noun, singular or mass
# clear            ADJ          acomp        clear            adjective (English), other noun-modifier (Chinese)
# comrades         NOUN         nsubj        comrade          noun, plural
# evils            NOUN         nsubj        evil             noun, plural
# life             NOUN         pobj         life             noun, singular or mass
# spring           NOUN         relcl        spring           noun, singular or mass
# tyranny          NOUN         pobj         tyranny          noun, singular or mass
# human            ADJ          amod         human            adjective (English), other noun-modifier (Chinese)
# rid              VERB         ROOT         rid              verb, past participle
# produce          NOUN         nsubj        produce          noun, singular or mass
# labour           NOUN         pobj         labour           noun, singular or mass
# overnight        ADV          advmod       overnight        adverb
# rich             ADJ          acomp        rich             adjective (English), other noun-modifier (Chinese)
# free             ADJ          conj         free             adjective (English), other noun-modifier (Chinese)
# work             NOUN         ROOT         work             noun, singular or mass
# night            NOUN         npadvmod     night            noun, singular or mass
# day              NOUN         conj         day              noun, singular or mass
# body             NOUN         conj         body             noun, singular or mass
# soul             NOUN         conj         soul             noun, singular or mass
# overthrow        NOUN         pobj         overthrow        noun, singular or mass
# human            ADJ          amod         human            adjective (English), other noun-modifier (Chinese)
# race             NOUN         pobj         race             noun, singular or mass
# ...
# foolish          ADJ          amod         foolish          adjective (English), other noun-modifier (Chinese)
# custom           NOUN         dobj         custom           noun, singular or mass
# addressing       VERB         pcomp        address          verb, gerund or present participle
# suppressed       VERB         xcomp        suppress         verb, past participle
# strange          ADJ          amod         strange          adjective (English), other noun-modifier (Chinese)
# custom           NOUN         attr         custom           noun, singular or mass
# origin           NOUN         nsubj        origin           noun, singular or mass
# unknown          ADJ          acomp        unknown          adjective (English), other noun-modifier (Chinese)
# marching         NOUN         pobj         marching         noun, singular or mass
# morning          NOUN         npadvmod     morning          noun, singular or mass
# past             ADP          prep         past             conjunction, subordinating or preposition
# boar             NOUN         poss         boar             noun, singular or mass
# skull            NOUN         pobj         skull            noun, singular or mass
# nailed           VERB         relcl        nail             verb, past participle
# post             NOUN         pobj         post             noun, singular or mass
# garden           NOUN         pobj         garden           noun, singular or mass
# suppressed       VERB         ROOT         suppress         verb, past participle
# skull            NOUN         nsubjpass    skull            noun, singular or mass
# buried           VERB         conj         bury             verb, past participle
# visitors         NOUN         nsubj        visitor          noun, plural
# observed         VERB         ROOT         observe          verb, past participle
# green            ADJ          amod         green            adjective (English), other noun-modifier (Chinese)
# flag             NOUN         dobj         flag             noun, singular or mass
# flew             VERB         relcl        fly              verb, past tense
# masthead         NOUN         pobj         masthead         noun, singular or mass
# noted            VERB         ROOT         note             verb, past participle
# white            ADJ          amod         white            adjective (English), other noun-modifier (Chinese)
# hoof             NOUN         nsubjpass    hoof             noun, singular or mass
# horn             NOUN         conj         horn             noun, singular or mass
# previously       ADV          advmod       previously       adverb
# marked           VERB         relcl        mark             verb, past participle
# removed          VERB         ccomp        remove           verb, past participle
# plain            ADJ          advmod       plain            adjective (English), other noun-modifier (Chinese)
# green            ADJ          amod         green            adjective (English), other noun-modifier (Chinese)
# flag             NOUN         attr         flag             noun, singular or mass
# onwards          ADV          pcomp        onwards          adverb
# criticism        NOUN         dobj         criticism        noun, singular or mass
# excellent        ADJ          amod         excellent        adjective (English), other noun-modifier (Chinese)
# neighbourly      ADJ          conj         neighbourly      adjective (English), other noun-modifier (Chinese)
# speech           NOUN         pobj         speech           noun, singular or mass
# referred         VERB         ROOT         refer            verb, past participle
# course           NOUN         nsubj        course           noun, singular or mass
# know             VERB         ROOT         know             verb, non-3rd person singular present
# time             NOUN         pobj         time             noun, singular or mass
# announcing       VERB         acl          announce         verb, gerund or present participle
# abolished        VERB         ccomp        abolish          verb, past participle
# farm             NOUN         nsubj        farm             noun, singular or mass
# known            VERB         xcomp        know             verb, past participle
# believed         VERB         parataxis    believe          verb, past tense
# correct          ADJ          amod         correct          adjective (English), other noun-modifier (Chinese)
# original         ADJ          conj         original         adjective (English), other noun-modifier (Chinese)
# Gentlemen        NOUN         nsubj        gentleman        noun, plural
# concluded        VERB         ROOT         conclude         verb, past tense
# toast            NOUN         dobj         toast            noun, singular or mass
# different        ADJ          amod         different        adjective (English), other noun-modifier (Chinese)
# form             NOUN         pobj         form             noun, singular or mass
# Fill             VERB         ROOT         fill             verb, base form
# glasses          NOUN         dobj         glass            noun, plural
# brim             NOUN         pobj         brim             noun, singular or mass
# Gentlemen        NOUN         nsubj        gentleman        noun, plural
# toast            NOUN         attr         toast            noun, singular or mass
# prosperity       NOUN         pobj         prosperity       noun, singular or mass
# hearty           NOUN         attr         hearty           noun, singular or mass
# cheering         VERB         acl          cheer            verb, gerund or present participle
# mugs             NOUN         nsubjpass    mug              noun, plural
# dregs            NOUN         pobj         dreg             noun, plural
# animals          NOUN         nsubj        animal           noun, plural
# outside          ADV          advmod       outside          adverb
# gazed            VERB         advcl        gaze             verb, past participle
# scene            NOUN         pobj         scene            noun, singular or mass
# strange          ADJ          amod         strange          adjective (English), other noun-modifier (Chinese)
# thing            NOUN         nsubj        thing            noun, singular or mass
# happening        VERB         ccomp        happen           verb, gerund or present participle
# altered          VERB         ccomp        alter            verb, past participle
# faces            NOUN         pobj         face             noun, plural
# pigs             NOUN         pobj         pig              noun, plural
# old              ADJ          amod         old              adjective (English), other noun-modifier (Chinese)
# dim              NOUN         compound     dim              noun, singular or mass
# 51eyes           NOUN         nsubj        51eye            noun, plural
# flitted          VERB         ROOT         flit             verb, past tense
# face             NOUN         pobj         face             noun, singular or mass
# chins            NOUN         dobj         chin             noun, plural
# melting          VERB         xcomp        melt             verb, gerund or present participle
# changing         VERB         conj         change           verb, gerund or present participle
# applause         NOUN         nsubj        applause         noun, singular or mass
# having           AUX          aux          having           verb, gerund or present participle
# come             VERB         advcl        come             verb, past participle
# end              NOUN         pobj         end              noun, singular or mass
# company          NOUN         nsubj        company          noun, singular or mass
# cards            NOUN         dobj         card             noun, plural
# continued        VERB         conj         continue         verb, past tense
# game             NOUN         dobj         game             noun, singular or mass
# interrupted      VERB         relcl        interrupt        verb, past participle
# animals          NOUN         nsubj        animal           noun, plural
# crept            VERB         conj         creep            verb, past tense
# silently         ADV          advmod       silently         adverb
# away             ADV          advmod       away             adverb
# yards            NOUN         npadvmod     yard             noun, plural
# stopped          VERB         advcl        stop             verb, past tense
# short            ADJ          acomp        short            adjective (English), other noun-modifier (Chinese)
# uproar           NOUN         nsubj        uproar           noun, singular or mass
# voices           NOUN         pobj         voice            noun, plural
# coming           VERB         ROOT         come             verb, gerund or present participle
# farmhouse        NOUN         pobj         farmhouse        noun, singular or mass
# rushed           VERB         ROOT         rush             verb, past tense
# looked           VERB         conj         look             verb, past tense
# window           NOUN         pobj         window           noun, singular or mass
# Yes              INTJ         intj         yes              interjection
# violent          ADJ          amod         violent          adjective (English), other noun-modifier (Chinese)
# quarrel          NOUN         nsubj        quarrel          noun, singular or mass
# progress         NOUN         pobj         progress         noun, singular or mass
# shoutings        NOUN         attr         shouting         noun, plural
# hangings         NOUN         appos        hanging          noun, plural
# table            NOUN         pobj         table            noun, singular or mass
# sharp            ADJ          amod         sharp            adjective (English), other noun-modifier (Chinese)
# suspicious       ADJ          amod         suspicious       adjective (English), other noun-modifier (Chinese)
# glances          NOUN         conj         glance           noun, plural
# furious          ADJ          amod         furious          adjective (English), other noun-modifier (Chinese)
# denials          NOUN         conj         denial           noun, plural
# source           NOUN         nsubj        source           noun, singular or mass
# trouble          NOUN         pobj         trouble          noun, singular or mass
# appeared         VERB         ROOT         appear           verb, past tense
# played           VERB         ccomp        play             verb, past participle
# ace              NOUN         dobj         ace              noun, singular or mass
# spades           NOUN         pobj         spade            noun, plural
# simultaneously   ADV          advmod       simultaneously   adverb
# voices           NOUN         nsubj        voice            noun, plural
# shouting         VERB         ROOT         shout            verb, gerund or present participle
# anger            NOUN         pobj         anger            noun, singular or mass
# alike            ADV          advmod       alike            adverb
# question         NOUN         ROOT         question         noun, singular or mass
# happened         VERB         relcl        happen           verb, past participle
# faces            NOUN         pobj         face             noun, plural
# pigs             NOUN         pobj         pig              noun, plural
# creatures        NOUN         nsubj        creature         noun, plural
# outside          ADV          advmod       outside          adverb
# looked           VERB         ROOT         look             verb, past tense
# pig              NOUN         pobj         pig              noun, singular or mass
# man              NOUN         pobj         man              noun, singular or mass
# man              NOUN         pobj         man              noun, singular or mass
# pig              NOUN         pobj         pig              noun, singular or mass
# pig              NOUN         pobj         pig              noun, singular or mass
# man              NOUN         pobj         man              noun, singular or mass
# impossible       ADJ          acomp        impossible       adjective (English), other noun-modifier (Chinese)
# woman            NOUN         appos        woman            noun, singular or mass
# runs             VERB         relcl        run              verb, 3rd person singular present
# website          NOUN         appos        website          noun, singular or mass
# ebook            NOUN         nsubjpass    ebook            noun, singular or mass
# published        VERB         relcl        publish          verb, past participle
# formatted        ADJ          amod         formatted        adjective (English), other noun-modifier (Chinese)
# editions         NOUN         attr         edition          noun, plural
# hope             VERB         conj         hope             verb, non-3rd person singular present
# enjoyed          AUX          aux          enjoyed          verb, past tense
# reading          VERB         ccomp        read             verb, gerund or present participle
# particular       ADJ          amod         particular       adjective (English), other noun-modifier (Chinese)
# book             NOUN         dobj         book             noun, singular or mass
# bought           VERB         advcl        buy              verb, past tense
# collection       NOUN         pobj         collection       noun, singular or mass
# thank            VERB         ROOT         thank            verb, non-3rd person singular present
# support          NOUN         pobj         support          noun, singular or mass
# downloaded       VERB         advcl        download         verb, past tense
# free             ADJ          amod         free             adjective (English), other noun-modifier (Chinese)
# consider         VERB         ROOT         consider         verb, base form
# small            ADJ          amod         small            adjective (English), other noun-modifier (Chinese)
# donation         NOUN         dobj         donation         noun, singular or mass
# help             VERB         ccomp        help             verb, base form
# site             NOUN         dobj         site             noun, singular or mass
# running          VERB         acl          run              verb, gerund or present participle
# bought           VERB         advcl        buy              verb, past tense
# ripped           VERB         ROOT         rip              verb, past participle
# free             ADJ          amod         free             adjective (English), other noun-modifier (Chinese)
# ebooks           NOUN         dobj         ebook            noun, plural
# site             NOUN         pobj         site             noun, singular or mass
# selling          VERB         conj         sell             verb, gerund or present participle
# definitely       ADV          advmod       definitely       adverb
# refund           NOUN         dobj         refund           noun, singular or mass
# Thanks           NOUN         ROOT         thank            noun, plural
# reading          VERB         pcomp        read             verb, gerund or present participle
# hope             VERB         ROOT         hope             verb, non-3rd person singular present
# visit            VERB         ccomp        visit            verb, non-3rd person singular present
# site             NOUN         dobj         site             noun, singular or mass
# new              ADJ          amod         new              adjective (English), other noun-modifier (Chinese)
# books            NOUN         nsubjpass    book             noun, plural
# added            VERB         ccomp        add              verb, past participle
# regularly        ADV          advmod       regularly        adverb
# find             VERB         advcl        find             verb, base form
# interest         NOUN         pobj         interest         noun, singular or mass
# :)               X            dep          :)               unknown

# %%
words
# Out:
# {'animal': 299,
#  'farm': 121,
#  'pig': 116,
#  'come': 95,
#  'work': 95,
#  'time': 88,
#  'day': 87,
#  'windmill': 71,
#  'comrade': 67,
#  'dog': 62,
#  'round': 53,
#  'long': 48,
#  'moment': 48,
#  'man': 47,
#  'leg': 46,
#  'old': 45,
#  'know': 42,
#  'human': 42,
#  'year': 40,
#  'way': 36,
#  'end': 36,
#  'sheep': 36,
#  'good': 36,
#  'farmhouse': 34,
#  'begin': 33,
#  'find': 33,
#  'great': 32,
#  'life': 32,
#  'hard': 32,
#  'yard': 30,
#  'word': 30,
#  'happen': 30,
#  'order': 29,
#  'horse': 29,
#  'look': 29,
#  'think': 29,
#  'little': 29,
#  'morning': 29,
#  'cry': 29,
#  'hen': 28,
#  'night': 28,
#  'set': 27,
#  'stand': 27,
#  'remember': 26,
#  'run': 26,
#  'break': 26,
#  'barn': 25,
#  'hear': 25,
#  'field': 25,
#  'use': 25,
#  'thing': 25,
#  'away': 25,
#  'appear': 25,
#  'soon': 24,
#  'building': 24,
#  'lie': 24,
#  'hoof': 24,
#  'later': 24,
#  'live': 24,
#  'week': 24,
#  'believe': 24,
#  'read': 24,
#  'bed': 23,
#  'speak': 23,
#  'shall': 23,
#  'hour': 22,
#  'cow': 22,
#  'labour': 22,
#  'bad': 21,
#  'place': 21,
#  'gun': 21,
#  'early': 21,
#  'like': 21,
#  'wall': 20,
#  'face': 20,
#  'foot': 20,
#  'eye': 20,
#  'voice': 20,
#  'turn': 20,
#  'death': 20,
#  'need': 20,
#  'announce': 20,
#  'tail': 19,
#  'stall': 19,
#  'food': 19,
#  'suddenly': 19,
#  'half': 19,
#  'stone': 19,
#  'sleep': 18,
#  'sing': 18,
#  'right': 18,
#  'summer': 18,
#  'big': 17,
#  'enemy': 17,
#  'milk': 17,
#  'lead': 17,
#  'young': 17,
#  'tell': 17,
#  'wear': 17,
#  'past': 17,
#  'evening': 17,
#  'plan': 17,
#  'send': 17,
#  'speech': 16,
#  'feel': 16,
#  'pass': 16,
#  'spring': 16,
#  'carry': 16,
#  'song': 16,
#  'certain': 16,
#  'hold': 16,
#  'hay': 16,
#  "'": 16,
#  'learn': 16,
#  'follow': 16,
#  'forward': 16,
#  'far': 16,
#  'straw': 15,
#  'grow': 15,
#  'fact': 15,
#  'walk': 15,
#  'small': 15,
#  'die': 15,
#  'ration': 15,
#  'kind': 15,
#  'late': 15,
#  'hedge': 15,
#  'harvest': 15,
#  'write': 15,
#  'able': 15,
#  'terrible': 15,
#  'immediately': 14,
#  'pigeon': 14,
#  'ask': 14,
#  'sit': 14,
#  'race': 14,
#  'large': 14,
#  'mind': 14,
#  'build': 14,
#  'clover': 13,
#  'hand': 13,
#  'tremendous': 13,
#  'talk': 13,
#  'usual': 13,
#  'understand': 13,
#  'creature': 13,
#  'egg': 13,
#  'minute': 13,
#  'corn': 13,
#  'outside': 13,
#  'ground': 13,
#  'necessary': 13,
#  'rumour': 13,
#  'raise': 12,
#  'white': 12,
#  'finally': 12,
#  'let': 12,
#  'short': 12,
#  'rest': 12,
#  'rebellion': 12,
#  'point': 12,
#  'question': 12,
#  'meeting': 12,
#  'difficulty': 12,
#  'fire': 12,
#  'pasture': 12,
#  'remain': 12,
#  'piece': 12,
#  'notice': 12,
#  'finish': 12,
#  'leave': 12,
#  'flag': 12,
#  'door': 11,
#  'draw': 11,
#  'dream': 11,
#  'lose': 11,
#  'beast': 11,
#  'fly': 11,
#  'orchard': 11,
#  'thought': 11,
#  'lay': 11,
#  'bring': 11,
#  'tune': 11,
#  'try': 11,
#  'black': 11,
#  'mean': 11,
#  'green': 11,
#  'utter': 11,
#  'chapter': 10,
#  'house': 10,
#  'hope': 10,
#  'ribbon': 10,
#  'listen': 10,
#  'number': 10,
#  'produce': 10,
#  'money': 10,
#  'sell': 10,
#  'resolution': 10,
#  'silence': 10,
#  'vote': 10,
#  'discover': 10,
#  'drink': 10,
#  'reason': 10,
#  'dead': 10,
#  'sound': 10,
#  'shed': 10,
#  'rush': 10,
#  'air': 10,
#  'paint': 10,
#  'letter': 10,
#  'agreement': 10,
#  'case': 10,
#  'news': 10,
#  'attack': 10,
#  'pile': 10,
#  'winter': 10,
#  'squealer': 10,
#  'timber': 10,
#  'buy': 10,
#  'light': 9,
#  'kick': 9,
#  'meet': 9,
#  'spite': 9,
#  'window': 9,
#  'slowly': 9,
#  'nearly': 9,
#  'fall': 9,
#  'sugar': 9,
#  'clear': 9,
#  'body': 9,
#  'continue': 9,
#  'surely': 9,
#  'save': 9,
#  'trotter': 9,
#  'forget': 9,
#  'heart': 9,
#  'new': 9,
#  'accord': 9,
#  'fling': 9,
#  'room': 9,
#  'gaze': 9,
#  'form': 9,
#  'honour': 9,
#  'arrangement': 9,
#  'apple': 9,
#  'watch': 9,
#  'intend': 9,
#  'tear': 9,
#  'battle': 9,
#  'quarry': 9,
#  'receive': 9,
#  'stop': 9,
#  'confess': 9,
#  'th': 9,
#  'strange': 8,
#  'high': 8,
#  'nose': 8,
#  'free': 8,
#  'single': 8,
#  'drop': 8,
#  'rat': 8,
#  'creep': 8,
#  'sight': 8,
#  'friend': 8,
#  'kill': 8,
#  'harness': 8,
#  'spread': 8,
#  'singing': 8,
#  'pellet': 8,
#  'secret': 8,
#  'feed': 8,
#  'farmer': 8,
#  'gate': 8,
#  'act': 8,
#  'hide': 8,
#  'ear': 8,
#  'destroy': 8,
#  'yes': 8,
#  'explain': 8,
#  'reduce': 8,
#  'disappear': 8,
#  'effort': 8,
#  'inch': 8,
#  'actually': 8,
#  'happy': 8,
#  'true': 8,
#  'garden': 8,
#  'aside': 8,
#  'decide': 8,
#  'declare': 8,
#  'prove': 8,
#  'drive': 8,
#  'head': 8,
#  'stir': 8,
#  'victory': 8,
#  'cover': 8,
#  'expulsion': 8,
#  'drag': 8,
#  'van': 8,
#  'glass': 7,
#  'agree': 7,
#  'cart': 7,
#  'care': 7,
#  'usually': 7,
#  'file': 7,
#  'near': 7,
#  'cat': 7,
#  'present': 7,
#  'wait': 7,
#  'bear': 7,
#  'force': 7,
#  'support': 7,
#  'problem': 7,
#  'future': 7,
#  'interest': 7,
#  'hole': 7,
#  'merely': 7,
#  'fight': 7,
#  'clever': 7,
#  'equal': 7,
#  'sow': 7,
#  'whip': 7,
#  'barley': 7,
#  'throw': 7,
#  'low': 7,
#  'corner': 7,
#  'complete': 7,
#  'want': 7,
#  'having': 7,
#  'accept': 7,
#  'flight': 7,
#  'road': 7,
#  'gallop': 7,
#  'enter': 7,
#  'table': 7,
#  'book': 7,
#  'writing': 7,
#  'gather': 7,
#  'possible': 7,
#  'cockerel': 7,
#  'debate': 7,
#  'retire': 7,
#  'attempt': 7,
#  'twice': 7,
#  'shout': 7,
#  'blood': 7,
#  'especially': 7,
#  'detail': 7,
#  'cold': 7,
#  'special': 7,
#  'protest': 7,
#  'world': 7,
#  'o': 7,
#  'pay': 7,
#  'r': 7,
#  'beer': 6,
#  'boar': 6,
#  'wish': 6,
#  'appearance': 6,
#  'different': 6,
#  'perch': 6,
#  'approach': 6,
#  'figure': 6,
#  'somewhat': 6,
#  'stupid': 6,
#  'remark': 6,
#  'spend': 6,
#  'warm': 6,
#  'throat': 6,
#  'earth': 6,
#  'strength': 6,
#  'simply': 6,
#  'dozen': 6,
#  'steal': 6,
#  'catch': 6,
#  'return': 6,
#  'allow': 6,
#  'rich': 6,
#  'struggle': 6,
#  'memory': 6,
#  'teach': 6,
#  'blow': 6,
#  'toil': 6,
#  'duck': 6,
#  'sure': 6,
#  'charge': 6,
#  'flee': 6,
#  'skip': 6,
#  'whisk': 6,
#  'principle': 6,
#  'beginning': 6,
#  'contrary': 6,
#  'distance': 6,
#  'expect': 6,
#  'kitchen': 6,
#  'drinking': 6,
#  'weed': 6,
#  'store': 6,
#  'horn': 6,
#  'direction': 6,
#  'hungry': 6,
#  'main': 6,
#  'bar': 6,
#  'trace': 6,
#  'mark': 6,
#  'knoll': 6,
#  'crop': 6,
#  'grass': 6,
#  'snuff': 6,
#  'pool': 6,
#  'shoulder': 6,
#  'spot': 6,
#  'matter': 6,
#  'attend': 6,
#  'onwards': 6,
#  'study': 6,
#  'hind': 6,
#  'fro': 6,
#  'eat': 6,
#  'meal': 6,
#  'fail': 6,
#  'class': 6,
#  'afternoon': 6,
#  'h': 6,
#  'refuse': 6,
#  'unable': 6,
#  'maxim': 6,
#  'imagine': 6,
#  'manage': 6,
#  'change': 6,
#  'stick': 6,
#  'wound': 6,
#  'weather': 6,
#  'win': 6,
#  'floor': 6,
#  'increase': 6,
#  'assemble': 6,
#  'deep': 6,
#  'growl': 6,
#  'warn': 6,
#  'visit': 6,
#  'e': 6,
#  'note': 6,
#  'company': 6,
#  'hang': 5,
#  'cut': 5,
#  'comfortable': 5,
#  'settle': 5,
#  'enormous': 5,
#  'strong': 5,
#  'donkey': 5,
#  'instance': 5,
#  'inside': 5,
#  'red': 5,
#  'month': 5,
#  'miserable': 5,
#  'dignity': 5,
#  'real': 5,
#  'scene': 5,
#  'cause': 5,
#  'abolish': 5,
#  'weak': 5,
#  'bare': 5,
#  'starve': 5,
#  'age': 5,
#  'reach': 5,
#  'argument': 5,
#  'serve': 5,
#  'alcohol': 5,
#  'engage': 5,
#  'water': 5,
#  'excitement': 5,
#  'burst': 5,
#  'bleat': 5,
#  'bury': 5,
#  'bird': 5,
#  'completely': 5,
#  'clearly': 5,
#  'prepare': 5,
#  '-': 5,
#  'fat': 5,
#  'argue': 5,
#  'difficult': 5,
#  'spirit': 5,
#  'season': 5,
#  'hate': 5,
#  'drawing': 5,
#  'help': 5,
#  'triumph': 5,
#  'chase': 5,
#  'hardly': 5,
#  'open': 5,
#  'halt': 5,
#  'today': 5,
#  'wrong': 5,
#  'loud': 5,
#  'task': 5,
#  'business': 5,
#  'leadership': 5,
#  'course': 5,
#  'machine': 5,
#  'grain': 5,
#  'excellent': 5,
#  'impossible': 5,
#  'extra': 5,
#  'express': 5,
#  'general': 5,
#  'object': 5,
#  'effect': 5,
#  'start': 5,
#  'tired': 5,
#  'county': 5,
#  'story': 5,
#  'secretly': 5,
#  'gentleman': 5,
#  'idea': 5,
#  'circulate': 5,
#  'speed': 5,
#  'rage': 5,
#  'march': 5,
#  'ahead': 5,
#  'line': 5,
#  'skull': 5,
#  'stretch': 5,
#  'iron': 5,
#  'somebody': 5,
#  'public': 5,
#  'close': 5,
#  'machinery': 5,
#  'defeat': 5,
#  'previously': 5,
#  "o'clock": 5,
#  'nowadays': 5,
#  'paper': 5,
#  'boulder': 5,
#  'fill': 5,
#  'relation': 5,
#  'sheet': 5,
#  'terror': 5,
#  'traitor': 5,
#  'pronounce': 5,
#  'thick': 5,
#  'neighbour': 5,
#  'came': 5,
#  'smell': 5,
#  'plot': 5,
#  'agent': 5,
#  'add': 5,
#  'toast': 5,
#  'shut': 4,
#  'ring': 4,
#  'lantern': 4,
#  'bedroom': 4,
#  'regard': 4,
#  'ready': 4,
#  'platform': 4,
#  'stout': 4,
#  'chew': 4,
#  'mare': 4,
#  'middle': 4,
#  'respect': 4,
#  'power': 4,
#  'laugh': 4,
#  'mother': 4,
#  'promptly': 4,
#  'asleep': 4,
#  'foolish': 4,
#  'lump': 4,
#  'mane': 4,
#  'tame': 4,
#  'raven': 4,
#  'duty': 4,
#  'ill': 4,
#  'breath': 4,
#  'instant': 4,
#  'truth': 4,
#  'land': 4,
#  'soil': 4,
#  'condition': 4,
#  'answer': 4,
#  'remove': 4,
#  'pull': 4,
#  'plough': 4,
#  'rabbit': 4,
#  'till': 4,
#  'block': 4,
#  'muscle': 4,
#  'message': 4,
#  'prosperity': 4,
#  'uproar': 4,
#  'dash': 4,
#  'repeat': 4,
#  'wing': 4,
#  'adopt': 4,
#  'clothe': 4,
#  'trade': 4,
#  'simple': 4,
#  'vanish': 4,
#  'picture': 4,
#  'wheat': 4,
#  'singe': 4,
#  'interrupt': 4,
#  'fierce': 4,
#  'consider': 4,
#  'shrill': 4,
#  'worth': 4,
#  'easily': 4,
#  'occasionally': 4,
#  '-room': 4,
#  'lash': 4,
#  'frighten': 4,
#  'slip': 4,
#  'successfully': 4,
#  'theirs': 4,
#  'stable': 4,
#  'cruel': 4,
#  'rubbish': 4,
#  'store-': 4,
#  'biscuit': 4,
#  'admiration': 4,
#  'hayfield': 4,
#  'frightened': 4,
#  'fear': 4,
#  'breakfast': 4,
#  'ladder': 4,
#  'succeed': 4,
#  'inscribe': 4,
#  'law': 4,
#  'easy': 4,
#  'bucket': 4,
#  'mix': 4,
#  'mash': 4,
#  'important': 4,
#  'assume': 4,
#  'chaff': 4,
#  'regular': 4,
#  'observe': 4,
#  'hoisting': 4,
#  'flagstaff': 4,
#  'treat': 4,
#  'roof': 4,
#  'autumn': 4,
#  'explanation': 4,
#  'forth': 4,
#  'collect': 4,
#  'l': 4,
#  'neighbouring': 4,
#  'complain': 4,
#  'pretend': 4,
#  'rapidly': 4,
#  'fully': 4,
#  'affair': 4,
#  'signal': 4,
#  'emerge': 4,
#  'rear': 4,
#  'straight': 4,
#  'exclaim': 4,
#  'celebration': 4,
#  'solemn': 4,
#  'supply': 4,
#  'pain': 4,
#  'stroke': 4,
#  'report': 4,
#  'enjoy': 4,
#  'decision': 4,
#  'violent': 4,
#  'successful': 4,
#  'quietly': 4,
#  'operate': 4,
#  'electric': 4,
#  'lift': 4,
#  'procure': 4,
#  'waste': 4,
#  'slogan': 4,
#  'turnip': 4,
#  'privately': 4,
#  'huge': 4,
#  'deliver': 4,
#  'bleating': 4,
#  'quarter': 4,
#  'sacrifice': 4,
#  'heavy': 4,
#  'compose': 4,
#  'poem': 4,
#  'reality': 4,
#  'occur': 4,
#  'load': 4,
#  'site': 4,
#  'seed': 4,
#  'simultaneously': 4,
#  'convince': 4,
#  'mill': 4,
#  'foundation': 4,
#  'roar': 4,
#  'rebuild': 4,
#  'potato': 4,
#  'tooth': 4,
#  'pause': 4,
#  'surprise': 4,
#  'w': 4,
#  'forbid': 4,
#  'thank': 4,
#  'belly': 4,
#  'deadly': 4,
#  'pound': 4,
#  'bank': 4,
#  'glance': 4,
#  'procession': 4,
#  'pension': 4,
#  'mug': 4,
#  'boot': 3,
#  'fluttering': 3,
#  'previous': 3,
#  'arrive': 3,
#  'fashion': 3,
#  'rate': 3,
#  'character': 3,
#  'seldom': 3,
#  'admit': 3,
#  'devoted': 3,
#  'paddock': 3,
#  'graze': 3,
#  'duckling': 3,
#  'tread': 3,
#  'attention': 3,
#  'nature': 3,
#  'laborious': 3,
#  'capable': 3,
#  'slaughter': 3,
#  'cruelty': 3,
#  'happiness': 3,
#  'leisure': 3,
#  'slavery': 3,
#  't': 3,
#  'root': 3,
#  'hunger': 3,
#  'fast': 3,
#  'prevent': 3,
#  'dung': 3,
#  'calf': 3,
#  'market': 3,
#  'pleasure': 3,
#  'natural': 3,
#  'porker': 3,
#  'knacker': 3,
#  'boil': 3,
#  'brick': 3,
#  'neck': 3,
#  'evil': 3,
#  'overthrow': 3,
#  'beneath': 3,
#  'perfect': 3,
#  'majority': 3,
#  'smoke': 3,
#  'touch': 3,
#  'remind': 3,
#  'ago': 3,
#  'tiding': 3,
#  'bit': 3,
#  'mangel': 3,
#  'wildest': 3,
#  'pick': 3,
#  'shot': 3,
#  'activity': 3,
#  'organise': 3,
#  'sale': 3,
#  'talker': 3,
#  'quick': 3,
#  'refer': 3,
#  'difference': 3,
#  'firmly': 3,
#  'existence': 3,
#  'mysterious': 3,
#  'sky': 3,
#  'cloud': 3,
#  'tale': 3,
#  'faithful': 3,
#  'achieve': 3,
#  'master': 3,
#  'bin': 3,
#  'wake': 3,
#  'butt': 3,
#  'defend': 3,
#  'heel': 3,
#  'track': 3,
#  'five-': 3,
#  'decorate': 3,
#  'fetch': 3,
#  'hat': 3,
#  'everybody': 3,
#  'command': 3,
#  'gambol': 3,
#  'roll': 3,
#  'mouthful': 3,
#  'tour': 3,
#  'inspection': 3,
#  'survey': 3,
#  'spinney': 3,
#  'tip': 3,
#  'whisper': 3,
#  'luxury': 3,
#  'admire': 3,
#  'manner': 3,
#  'sharply': 3,
#  'pot': 3,
#  'brush': 3,
#  'commandment': 3,
#  '.': 3,
#  'neatly': 3,
#  'correct': 3,
#  'benefit': 3,
#  'quickly': 3,
#  'uneasy': 3,
#  'fairly': 3,
#  'considerable': 3,
#  'sweat': 3,
#  'success': 3,
#  'tool': 3,
#  'sun': 3,
#  'sharp': 3,
#  'style': 3,
#  'possess': 3,
#  'threshing': 3,
#  'worker': 3,
#  'mighty': 3,
#  'push': 3,
#  'bushel': 3,
#  'reappear': 3,
#  'oppose': 3,
#  'reading': 3,
#  'failure': 3,
#  'advantage': 3,
#  'paw': 3,
#  's': 3,
#  'scrap': 3,
#  'alphabet': 3,
#  'b': 3,
#  'shake': 3,
#  'forelock': 3,
#  'c': 3,
#  'contain': 3,
#  'thoroughly': 3,
#  'influence': 3,
#  'develop': 3,
#  'committee': 3,
#  'litter': 3,
#  'windfall': 3,
#  'share': 3,
#  'equally': 3,
#  'privilege': 3,
#  'dislike': 3,
#  'sole': 3,
#  'health': 3,
#  'instruction': 3,
#  'property': 3,
#  'pack': 3,
#  'wonder': 3,
#  'owner': 3,
#  'term': 3,
#  'anxious': 3,
#  'countryside': 3,
#  'fence': 3,
#  'stack': 3,
#  'deal': 3,
#  'create': 3,
#  'squeal': 3,
#  'strike': 3,
#  'lad': 3,
#  'mud': 3,
#  'panic': 3,
#  'shoe': 3,
#  'purpose': 3,
#  'decoration': 3,
#  'confer': 3,
#  'brass': 3,
#  'discussion': 3,
#  'twelfth': 3,
#  'anniversary': 3,
#  'stroll': 3,
#  'smart': 3,
#  'mention': 3,
#  'occupy': 3,
#  'demand': 3,
#  'following': 3,
#  'liable': 3,
#  'improvement': 3,
#  'complicated': 3,
#  'bitter': 3,
#  'suitable': 3,
#  'whimper': 3,
#  'closely': 3,
#  'production': 3,
#  'realise': 3,
#  'sentence': 3,
#  'imagination': 3,
#  'doubt': 3,
#  'cast': 3,
#  'bound': 3,
#  'spare': 3,
#  'silent': 3,
#  'shock': 3,
#  'trust': 3,
#  'discipline': 3,
#  'certainly': 3,
#  'feeling': 3,
#  'addition': 3,
#  'stump': 3,
#  'sly': 3,
#  'slave': 3,
#  'sand': 3,
#  'crowbar': 3,
#  'rope': 3,
#  'critical': 3,
#  'slope': 3,
#  'accumulate': 3,
#  'despair': 3,
#  'strain': 3,
#  'instead': 3,
#  'lot': 3,
#  'method': 3,
#  'oil': 3,
#  'nail': 3,
#  'contact': 3,
#  'probably': 3,
#  'exist': 3,
#  'mistake': 3,
#  'arrange': 3,
#  'avoid': 3,
#  'partly': 3,
#  'cease': 3,
#  'title': 3,
#  'rule': 3,
#  'level': 3,
#  'pace': 3,
#  'rigid': 3,
#  'd': 3,
#  'rebuilding': 3,
#  'issue': 3,
#  'fresh': 3,
#  'instruct': 3,
#  'price': 3,
#  'murder': 3,
#  'league': 3,
#  'decree': 3,
#  'cowshe': 3,
#  'sniff': 3,
#  'document': 3,
#  'bleed': 3,
#  'taste': 3,
#  'execution': 3,
#  'huddle': 3,
#  'society': 3,
#  'ad': 3,
#  'appoint': 3,
#  'list': 3,
#  'cent': 3,
#  'birthday': 3,
#  'deed': 3,
#  'purchase': 3,
#  'inspect': 3,
#  'congratulate': 3,
#  'period': 3,
#  'muzzle': 3,
#  'limp': 3,
#  'trouble': 3,
#  'mouth': 3,
#  'medicine': 3,
#  'supervision': 3,
#  'dim': 3,
#  'visitor': 3,
#  'drunk': 2,
#  'barrel': 2,
#  'scullery': 2,
#  'stirring': 2,
#  'communicate': 2,
#  'sort': 2,
#  'beam': 2,
#  'rafter': 2,
#  'vast': 2,
#  'lest': 2,
#  'conceal': 2,
#  'foal': 2,
#  'stripe': 2,
#  'temper': 2,
#  'openly': 2,
#  'sunday': 2,
#  'brood': 2,
#  'foreleg': 2,
#  'pretty': 2,
#  'flirt': 2,
#  'purr': 2,
#  'wisdom': 2,
#  'acquire': 2,
#  'plain': 2,
#  'poor': 2,
#  'afford': 2,
#  'enormously': 2,
#  'comfort': 2,
#  'sum': 2,
#  'skin': 2,
#  ...}

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
df = pd.DataFrame({'word':words.keys(), 'frequency':words.values()})

# %%
df.head(20)
# Out:
#         word  frequency
# 0     animal        299
# 1       farm        121
# 2        pig        116
# 3       come         95
# 4       work         95
# 5       time         88
# 6        day         87
# 7   windmill         71
# 8    comrade         67
# 9        dog         62
# 10     round         53
# 11      long         48
# 12    moment         48
# 13       man         47
# 14       leg         46
# 15       old         45
# 16      know         42
# 17     human         42
# 18      year         40
# 19       way         36

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data=df.iloc[:20], x='word', y='frequency');

# %%
df_indexed = df.set_index('word')
df_indexed.head(20)
# Out:
#           frequency
# word
# animal          299
# farm            121
# pig             116
# come             95
# work             95
# time             88
# day              87
# windmill         71
# comrade          67
# dog              62
# round            53
# long             48
# moment           48
# man              47
# leg              46
# old              45
# know             42
# human            42
# year             40
# way              36

# %%
wordcloud = WordCloud(width=1200, height=800, background_color='#FFFFFF').generate_from_frequencies(words)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')

# %% [markdown]
# ### Try looking at word cloud for only Verbs

# %%
verbs = token_frequency(whole_text, only_include=['VERB'], verbos=True)
# Out:
# locked           VERB         ROOT         lock             verb, past participle
# remember         VERB         xcomp        remember         verb, base form
# shut             VERB         xcomp        shut             verb, base form
# lurched          VERB         ROOT         lurch            verb, past tense
# kicked           VERB         conj         kick             verb, past tense
# drew             VERB         conj         draw             verb, past tense
# snoring          VERB         relcl        snore            verb, gerund or present participle
# wished           VERB         conj         wish             verb, past tense
# communicate      VERB         xcomp        communicate      verb, base form
# agreed           VERB         ROOT         agree            verb, past participle
# meet             VERB         ccomp        meet             verb, base form
# exhibited        VERB         relcl        exhibit          verb, past participle
# regarded         VERB         acomp        regard           verb, past participle
# lose             VERB         xcomp        lose             verb, base form
# hear             VERB         acl          hear             verb, base form
# raised           VERB         amod         raise            verb, past participle
# ensconced        VERB         ROOT         ensconce         verb, past participle
# hung             VERB         relcl        hang             verb, past tense
# grown            VERB         conj         grow             verb, past participle
# cut              VERB         acl          cut              verb, past participle
# began            VERB         ROOT         begin            verb, past tense
# arrive           VERB         xcomp        arrive           verb, base form
# came             VERB         ROOT         come             verb, past tense
# settled          VERB         relcl        settle           verb, past tense
# perched          VERB         ccomp        perch            verb, past tense
# fluttered        VERB         ccomp        flutter          verb, past tense
# lay              VERB         ROOT         lie              verb, past tense
# began            VERB         conj         begin            verb, past tense
# chew             VERB         xcomp        chew             verb, base form
# came             VERB         ROOT         come             verb, past tense
# walking          VERB         advcl        walk             verb, gerund or present participle
# setting          VERB         conj         set              verb, gerund or present participle
# concealed        VERB         acl          conceal          verb, past participle
# approaching      VERB         acl          approach         verb, gerund or present participle
# respected        VERB         conj         respect          verb, past participle
# came             VERB         ROOT         come             verb, past tense
# tempered         VERB         conj         temper           verb, past participle
# talked           VERB         ccomp        talk             verb, past tense
# laughed          VERB         relcl        laugh            verb, past tense
# asked            VERB         advcl        ask              verb, past participle
# laugh            VERB         relcl        laugh            verb, base form
# admitting        VERB         pcomp        admit            verb, gerund or present participle
# spent            VERB         ROOT         spend            verb, past tense
# grazing          VERB         compound     graze            verb, gerund or present participle
# speaking         VERB         conj         speak            verb, gerund or present participle
# lain             VERB         ROOT         lain             verb, base form
# lost             VERB         relcl        lose             verb, past participle
# filed            VERB         advcl        file             verb, past participle
# cheeping         VERB         advcl        cheep            verb, gerund or present participle
# wandering        VERB         conj         wander           verb, gerund or present participle
# find             VERB         advcl        find             verb, base form
# trodden          VERB         relcl        tread            verb, past participle
# round            VERB         advcl        round            verb, base form
# nestled          VERB         conj         nestle           verb, past tense
# fell             VERB         conj         fall             verb, past tense
# drew             VERB         relcl        draw             verb, past tense
# chewing          VERB         ROOT         chew             verb, gerund or present participle
# began            VERB         conj         begin            verb, past tense
# flirting         VERB         xcomp        flirt            verb, gerund or present participle
# hoping           VERB         advcl        hope             verb, gerund or present participle
# draw             VERB         xcomp        draw             verb, base form
# plaited          VERB         relcl        plait            verb, past participle
# came             VERB         ccomp        come             verb, past tense
# looked           VERB         relcl        look             verb, past tense
# squeezed         VERB         conj         squeeze          verb, past tense
# purred           VERB         ROOT         purr             verb, past tense
# listening        VERB         pcomp        listen           verb, gerund or present participle
# slept            VERB         relcl        sleep            verb, past tense
# waiting          VERB         conj         wait             verb, gerund or present participle
# cleared          VERB         ROOT         clear            verb, past tense
# began            VERB         conj         begin            verb, past tense
# heard            VERB         relcl        hear             verb, past participle
# come             VERB         ROOT         come             verb, base form
# think            VERB         ROOT         think            verb, base form
# die              VERB         advcl        die              verb, non-3rd person singular present
# feel             VERB         conj         feel             verb, non-3rd person singular present
# pass             VERB         relcl        pass             verb, base form
# acquired         VERB         advcl        acquire          verb, past participle
# lay              VERB         advcl        lay              verb, non-3rd person singular present
# think            VERB         conj         think            verb, non-3rd person singular present
# understand       VERB         ccomp        understand       verb, non-3rd person singular present
# living           VERB         relcl        live             verb, gerund or present participle
# wish             VERB         ccomp        wish             verb, non-3rd person singular present
# speak            VERB         xcomp        speak            verb, base form
# Let              VERB         advcl        let              verb, base form
# face             VERB         ccomp        face             verb, base form
# born             VERB         ccomp        bear             verb, past participle
# forced           VERB         conj         force            verb, past participle
# work             VERB         xcomp        work             verb, base form
# come             VERB         acl          come             verb, past participle
# slaughtered      VERB         relcl        slaughter        verb, past participle
# knows            VERB         ROOT         know             verb, 3rd person singular present
# afford           VERB         ccomp        afford           verb, base form
# dwell            VERB         relcl        dwell            verb, non-3rd person singular present
# affording        VERB         pcomp        afford           verb, gerund or present participle
# inhabit          VERB         advcl        inhabit          verb, base form
# support          VERB         ROOT         support          verb, base form
# living           VERB         acl          live             verb, gerund or present participle
# continue         VERB         ROOT         continue         verb, base form
# stolen           VERB         ROOT         steal            verb, past participle
# summed           VERB         ROOT         sum              verb, past participle
# Remove           VERB         ROOT         remove           verb, base form
# abolished        VERB         conj         abolish          verb, past participle
# consumes         VERB         relcl        consume          verb, 3rd person singular present
# producing        VERB         pcomp        produce          verb, gerund or present participle
# lay              VERB         ccomp        lay              verb, base form
# pull             VERB         xcomp        pull             verb, base form
# run              VERB         ROOT         run              verb, base form
# catch            VERB         xcomp        catch            verb, base form
# sets             VERB         ccomp        set              verb, 3rd person singular present
# work             VERB         xcomp        work             verb, base form
# prevent          VERB         relcl        prevent          verb, base form
# starving         VERB         pcomp        starve           verb, gerund or present participle
# tills            VERB         ccomp        till             verb, 3rd person singular present
# fertilises       VERB         ROOT         fertilise        verb, 3rd person singular present
# cows             VERB         ccomp        cow              verb, 3rd person singular present
# happened         VERB         ROOT         happen           verb, past participle
# breeding         VERB         relcl        breed            verb, gerund or present participle
# hens             VERB         ROOT         hen              verb, 3rd person singular present
# laid             VERB         ccomp        lay              verb, past participle
# hatched          VERB         conj         hatch            verb, past participle
# bring            VERB         advcl        bring            verb, base form
# bore             VERB         relcl        bore             verb, non-3rd person singular present
# sold             VERB         ccomp        sell             verb, past participle
# lead             VERB         relcl        lead             verb, non-3rd person singular present
# allowed          VERB         ROOT         allow            verb, past participle
# reach            VERB         xcomp        reach            verb, base form
# grumble          VERB         ROOT         grumble          verb, base form
# escapes          VERB         ROOT         escape           verb, 3rd person singular present
# sitting          VERB         relcl        sit              verb, gerund or present participle
# scream           VERB         ROOT         scream           verb, base form
# come             VERB         ROOT         come             verb, base form
# lose             VERB         relcl        lose             verb, non-3rd person singular present
# sell             VERB         ROOT         sell             verb, base form
# cut              VERB         relcl        cut              verb, base form
# boil             VERB         conj         boil             verb, base form
# grow             VERB         advcl        grow             verb, non-3rd person singular present
# ties             VERB         ROOT         tie              verb, 3rd person singular present
# drowns           VERB         conj         drown            verb, 3rd person singular present
# rid              VERB         ROOT         rid              verb, past participle
# know             VERB         ROOT         know             verb, base form
# come             VERB         ccomp        come             verb, base form
# know             VERB         conj         know             verb, non-3rd person singular present
# Fix              VERB         ROOT         fix              verb, base form
# pass             VERB         ROOT         pass             verb, base form
# come             VERB         relcl        come             verb, non-3rd person singular present
# carry            VERB         advcl        carry            verb, base form
# remember         VERB         ROOT         remember         verb, base form
# falter           VERB         ccomp        falter           verb, base form
# lead             VERB         ROOT         lead             verb, base form
# listen           VERB         ROOT         listen           verb, base form
# tell             VERB         advcl        tell             verb, non-3rd person singular present
# serves           VERB         ROOT         serve            verb, 3rd person singular present
# let              VERB         ROOT         let              verb, base form
# speaking         VERB         advcl        speak            verb, gerund or present participle
# crept            VERB         ROOT         creep            verb, past participle
# sitting          VERB         conj         sit              verb, gerund or present participle
# listening        VERB         advcl        listen           verb, gerund or present participle
# caught           VERB         ROOT         catch            verb, past participle
# saved            VERB         ccomp        save             verb, past tense
# raised           VERB         ROOT         raise            verb, past tense
# settled          VERB         relcl        settle           verb, past participle
# Let              VERB         ROOT         let              verb, base form
# propose          VERB         ccomp        propose          verb, non-3rd person singular present
# agreed           VERB         conj         agree            verb, past participle
# rats             VERB         nsubj        rat              verb, 3rd person singular present
# discovered       VERB         relcl        discover         verb, past participle
# voted            VERB         xcomp        vote             verb, past participle
# continued        VERB         ROOT         continue         verb, past tense
# repeat           VERB         ccomp        repeat           verb, non-3rd person singular present
# remember         VERB         ROOT         remember         verb, base form
# remember         VERB         ROOT         remember         verb, base form
# fighting         VERB         pcomp        fight            verb, gerund or present participle
# come             VERB         ccomp        come             verb, base form
# resemble         VERB         advcl        resemble         verb, base form
# conquered        VERB         advcl        conquer          verb, past participle
# adopt            VERB         ROOT         adopt            verb, base form
# live             VERB         ROOT         live             verb, base form
# sleep            VERB         conj         sleep            verb, base form
# wear             VERB         conj         wear             verb, base form
# drink            VERB         conj         drink            verb, base form
# smoke            VERB         conj         smoke            verb, base form
# touch            VERB         conj         touch            verb, base form
# engage           VERB         conj         engage           verb, base form
# tyrannise        VERB         ROOT         tyrannise        verb, base form
# kill             VERB         ROOT         kill             verb, base form
# tell             VERB         ROOT         tell             verb, base form
# describe         VERB         ROOT         describe         verb, base form
# vanished         VERB         advcl        vanish           verb, past participle
# reminded         VERB         ROOT         remind           verb, past tense
# forgotten        VERB         relcl        forget           verb, past participle
# used             VERB         acl          use              verb, past participle
# sing             VERB         xcomp        sing             verb, base form
# knew             VERB         relcl        know             verb, past tense
# known            VERB         ROOT         know             verb, past participle
# passed           VERB         conj         pass             verb, past participle
# came             VERB         ROOT         come             verb, past tense
# came             VERB         ccomp        come             verb, past tense
# sung             VERB         advcl        sing             verb, past participle
# lost             VERB         conj         lose             verb, past participle
# sing             VERB         ROOT         sing             verb, base form
# taught           VERB         advcl        teach            verb, past participle
# sing             VERB         conj         sing             verb, base form
# cleared          VERB         ROOT         clear            verb, past tense
# began            VERB         conj         begin            verb, past tense
# sing             VERB         xcomp        sing             verb, base form
# sang             VERB         conj         sing             verb, past tense
# ran              VERB         ccomp        run              verb, past tense
# coming           VERB         ccomp        come             verb, gerund or present participle
# vanish           VERB         ccomp        vanish           verb, base form
# spur             VERB         nsubj        spur             verb, base form
# rust             VERB         conj         rust             verb, base form
# whips            VERB         ROOT         whip             verb, 3rd person singular present
# crack            VERB         ccomp        crack            verb, base form
# picture          VERB         ROOT         picture          verb, base form
# shine            VERB         ccomp        shine            verb, base form
# blow             VERB         conj         blow             verb, base form
# sets             VERB         relcl        set              verb, 3rd person singular present
# labour           VERB         advcl        labour           verb, base form
# die              VERB         advcl        die              verb, non-3rd person singular present
# break            VERB         advcl        break            verb, non-3rd person singular present
# toil             VERB         ROOT         toil             verb, base form
# spread           VERB         conj         spread           verb, base form
# threw            VERB         ROOT         throw            verb, past tense
# reached          VERB         advcl        reach            verb, past participle
# begun            VERB         ROOT         begin            verb, past participle
# singing          VERB         xcomp        singe            verb, gerund or present participle
# picked           VERB         ROOT         pick             verb, past participle
# burst            VERB         ROOT         burst            verb, past tense
# lowed            VERB         ccomp        low              verb, past tense
# whined           VERB         ccomp        whine            verb, past tense
# bleated          VERB         ccomp        bleat            verb, past tense
# whinnied         VERB         ccomp        whinny           verb, past tense
# quacked          VERB         ROOT         quack            verb, past tense
# sang             VERB         relcl        sing             verb, past tense
# continued        VERB         conj         continue         verb, past participle
# singing          VERB         xcomp        singe            verb, gerund or present participle
# interrupted      VERB         advcl        interrupt        verb, past participle
# awoke            VERB         ROOT         awake            verb, past tense
# sprang           VERB         relcl        spring           verb, past tense
# seized           VERB         ROOT         seize            verb, past tense
# stood            VERB         relcl        stand            verb, past tense
# fly              VERB         conj         fly              verb, base form
# buried           VERB         ROOT         bury             verb, past tense
# broke            VERB         conj         break            verb, past tense
# fled             VERB         ROOT         flee             verb, past tense
# jumped           VERB         ccomp        jump             verb, past tense
# settled          VERB         ROOT         settle           verb, past tense
# died             VERB         ROOT         die              verb, past tense
# buried           VERB         ROOT         bury             verb, past participle
# know             VERB         ccomp        know             verb, base form
# predicted        VERB         acl          predict          verb, past participle
# thinking         VERB         pobj         think            verb, gerund or present participle
# prepare          VERB         xcomp        prepare          verb, base form
# organising       VERB         conj         organise         verb, gerund or present participle
# fell             VERB         ROOT         fall             verb, past tense
# recognised       VERB         relcl        recognise        verb, past participle
# breeding         VERB         relcl        breed            verb, gerund or present participle
# looking          VERB         amod         look             verb, gerund or present participle
# considered       VERB         conj         consider         verb, past participle
# known            VERB         nsubj        know             verb, past participle
# twinkling        VERB         acl          twinkle          verb, gerund or present participle
# arguing          VERB         conj         argue            verb, gerund or present participle
# skipping         VERB         pcomp        skip             verb, gerund or present participle
# whisking         VERB         conj         whisk            verb, gerund or present participle
# turn             VERB         ccomp        turn             verb, base form
# elaborated       VERB         ROOT         elaborate        verb, past participle
# held             VERB         ROOT         hold             verb, past tense
# expounded        VERB         conj         expound          verb, past tense
# met              VERB         ROOT         meet             verb, past tense
# talked           VERB         ROOT         talk             verb, past tense
# referred         VERB         relcl        refer            verb, past tense
# feeds            VERB         conj         feed             verb, 3rd person singular present
# starve           VERB         ROOT         starve           verb, base form
# asked            VERB         ROOT         ask              verb, past tense
# care             VERB         pcomp        care             verb, base form
# happens          VERB         ccomp        happen           verb, 3rd person singular present
# happen           VERB         xcomp        happen           verb, base form
# work             VERB         ccomp        work             verb, non-3rd person singular present
# asked            VERB         ROOT         ask              verb, past participle
# asked            VERB         relcl        ask              verb, past tense
# need             VERB         ROOT         need             verb, base form
# want             VERB         relcl        want             verb, non-3rd person singular present
# allowed          VERB         ccomp        allow            verb, past participle
# wear             VERB         xcomp        wear             verb, base form
# asked            VERB         ROOT         ask              verb, past tense
# understand       VERB         ccomp        understand       verb, base form
# agreed           VERB         ROOT         agree            verb, past tense
# sound            VERB         conj         sound            verb, base form
# counteract       VERB         acl          counteract       verb, base form
# claimed          VERB         ROOT         claim            verb, past tense
# know             VERB         xcomp        know             verb, base form
# 6called          VERB         acl          6calle           verb, past participle
# died             VERB         advcl        die              verb, past tense
# situated         VERB         ccomp        situate          verb, past participle
# grew             VERB         conj         grow             verb, past tense
# hated            VERB         ROOT         hate             verb, past tense
# told             VERB         advcl        tell             verb, past tense
# believed         VERB         conj         believe          verb, past tense
# argue            VERB         xcomp        argue            verb, base form
# persuade         VERB         xcomp        persuade         verb, base form
# thinking         VERB         pcomp        think            verb, gerund or present participle
# accepted         VERB         advcl        accept           verb, past participle
# absorbed         VERB         conj         absorb           verb, past tense
# told             VERB         relcl        tell             verb, past participle
# passed           VERB         conj         pass             verb, past tense
# led              VERB         conj         lead             verb, past tense
# ended            VERB         relcl        end              verb, past tense
# turned           VERB         advcl        turn             verb, past tense
# achieved         VERB         ROOT         achieve          verb, past participle
# expected         VERB         advcl        expect           verb, past participle
# fallen           VERB         conj         fall             verb, past participle
# disheartened     VERB         acomp        dishearten       verb, past participle
# losing           VERB         pcomp        lose             verb, gerund or present participle
# drinking         VERB         pcomp        drink            verb, gerund or present participle
# lounge           VERB         relcl        lounge           verb, base form
# reading          VERB         advcl        read             verb, gerund or present participle
# feeding          VERB         conj         feed             verb, gerund or present participle
# soaked           VERB         acl          soak             verb, past participle
# wanted           VERB         ccomp        want             verb, past tense
# neglected        VERB         ROOT         neglect          verb, past participle
# came             VERB         ROOT         come             verb, past tense
# cutting          VERB         pcomp        cut              verb, gerund or present participle
# come             VERB         ccomp        come             verb, base form
# milked           VERB         ROOT         milk             verb, past participle
# rabbiting        VERB         dobj         rabbit           verb, gerund or present participle
# bothering        VERB         pcomp        bother           verb, gerund or present participle
# feed             VERB         xcomp        feed             verb, base form
# sleep            VERB         pobj         sleep            verb, base form
# came             VERB         advcl        come             verb, past tense
# unfed            VERB         ROOT         unfe             verb, past participle
# stand            VERB         ROOT         stand            verb, base form
# broke            VERB         ROOT         break            verb, past tense
# began            VERB         conj         begin            verb, past tense
# help             VERB         xcomp        help             verb, base form
# woke             VERB         ccomp        wake             verb, past tense
# lashing          VERB         advcl        lash             verb, gerund or present participle
# bear             VERB         advcl        bear             verb, base form
# planned          VERB         advcl        plan             verb, past participle
# flung            VERB         ROOT         fling            verb, past tense
# found            VERB         ROOT         find             verb, past tense
# butted           VERB         ccomp        butt             verb, past participle
# kicked           VERB         conj         kick             verb, past tense
# behave           VERB         ccomp        behave           verb, base form
# used             VERB         relcl        use              verb, past participle
# thrashing        VERB         pcomp        thrash           verb, gerund or present participle
# maltreating      VERB         conj         maltreat         verb, gerund or present participle
# chose            VERB         advcl        choose           verb, past tense
# frightened       VERB         conj         frighten         verb, past tense
# trying           VERB         advcl        try              verb, gerund or present participle
# defend           VERB         xcomp        defend           verb, base form
# led              VERB         relcl        lead             verb, past tense
# pursuing         VERB         acl          pursue           verb, gerund or present participle
# looked           VERB         ROOT         look             verb, past tense
# happening        VERB         ccomp        happen           verb, gerund or present participle
# flung            VERB         conj         fling            verb, past tense
# slipped          VERB         conj         slip             verb, past tense
# sprang           VERB         ROOT         spring           verb, past tense
# flapped          VERB         conj         flap             verb, past participle
# croaking         VERB         advcl        croak            verb, gerund or present participle
# chased           VERB         ROOT         chase            verb, past participle
# slammed          VERB         conj         slam             verb, past tense
# barred           VERB         amod         bar              verb, past participle
# knew             VERB         advcl        know             verb, past tense
# happening        VERB         ccomp        happen           verb, gerund or present participle
# carried          VERB         ccomp        carry            verb, past participle
# expelled         VERB         ROOT         expel            verb, past participle
# believe          VERB         relcl        believe          verb, base form
# gallop           VERB         xcomp        gallop           verb, base form
# hiding           VERB         ccomp        hide             verb, gerund or present participle
# raced            VERB         advcl        race             verb, past tense
# wipe             VERB         xcomp        wipe             verb, base form
# hated            VERB         amod         hate             verb, past participle
# broken           VERB         ccomp        break            verb, past participle
# used             VERB         relcl        use              verb, past participle
# castrate         VERB         xcomp        castrate         verb, base form
# flung            VERB         ROOT         fling            verb, past participle
# thrown           VERB         ROOT         throw            verb, past participle
# burning          VERB         relcl        burn             verb, gerund or present participle
# capered          VERB         acl          caper            verb, past participle
# threw            VERB         ROOT         throw            verb, past tense
# decorated        VERB         relcl        decorate         verb, past participle
# considered       VERB         ROOT         consider         verb, past participle
# heard            VERB         advcl        hear             verb, past tense
# fetched          VERB         ROOT         fetch            verb, past tense
# wore             VERB         relcl        wear             verb, past tense
# flung            VERB         conj         fling            verb, past tense
# destroyed        VERB         ROOT         destroy          verb, past participle
# reminded         VERB         relcl        remind           verb, past tense
# led              VERB         ROOT         lead             verb, past tense
# served           VERB         conj         serve            verb, past tense
# sang             VERB         ROOT         sing             verb, past tense
# running          VERB         advcl        run              verb, gerund or present participle
# settled          VERB         conj         settle           verb, past tense
# slept            VERB         conj         sleep            verb, past tense
# slept            VERB         advcl        sleep            verb, past participle
# woke             VERB         ROOT         wake             verb, past tense
# remembering      VERB         advcl        remember         verb, gerund or present participle
# happened         VERB         relcl        happen           verb, past participle
# raced            VERB         conj         race             verb, past tense
# commanded        VERB         relcl        command          verb, past tense
# rushed           VERB         ROOT         rush             verb, past tense
# gazed            VERB         conj         gaze             verb, past tense
# thought          VERB         pobj         think            verb, past tense
# gambolled        VERB         ccomp        gambol           verb, past tense
# hurled           VERB         ROOT         hurl             verb, past tense
# rolled           VERB         ccomp        roll             verb, past tense
# cropped          VERB         ccomp        crop             verb, past tense
# kicked           VERB         ROOT         kick             verb, past tense
# snuffed          VERB         conj         snuff            verb, past tense
# surveyed         VERB         conj         survey           verb, past participle
# believe          VERB         conj         believe          verb, base form
# filed            VERB         ROOT         file             verb, past tense
# halted           VERB         conj         halt             verb, past participle
# butted           VERB         ROOT         butt             verb, past tense
# entered          VERB         conj         enter            verb, past tense
# walking          VERB         advcl        walk             verb, gerund or present participle
# disturbing       VERB         pcomp        disturb          verb, gerund or present participle
# speak            VERB         xcomp        speak            verb, base form
# gazing           VERB         conj         gaze             verb, gerund or present participle
# coming           VERB         ROOT         come             verb, gerund or present participle
# discovered       VERB         relcl        discover         verb, past participle
# missing          VERB         xcomp        miss             verb, gerund or present participle
# found            VERB         ROOT         find             verb, past tense
# remained         VERB         ccomp        remain           verb, past participle
# holding          VERB         conj         hold             verb, gerund or present participle
# admiring         VERB         conj         admire           verb, gerund or present participle
# reproached       VERB         ROOT         reproach         verb, past tense
# hanging          VERB         acl          hang             verb, gerund or present participle
# stove            VERB         conj         stove            verb, base form
# touched          VERB         ROOT         touch            verb, past participle
# passed           VERB         ROOT         pass             verb, past participle
# preserved        VERB         acl          preserve         verb, past participle
# agreed           VERB         ROOT         agree            verb, past participle
# live             VERB         ccomp        live             verb, base form
# begin            VERB         ROOT         begin            verb, non-3rd person singular present
# attended         VERB         relcl        attend           verb, past participle
# revealed         VERB         ROOT         reveal           verb, past tense
# taught           VERB         ccomp        teach            verb, past participle
# read             VERB         xcomp        read             verb, base form
# write            VERB         conj         write            verb, base form
# belonged         VERB         relcl        belong           verb, past participle
# thrown           VERB         conj         throw            verb, past participle
# sent             VERB         ROOT         send             verb, past tense
# led              VERB         conj         lead             verb, past tense
# barred           VERB         amod         bar              verb, past participle
# painted          VERB         conj         paint            verb, past tense
# painted          VERB         conj         paint            verb, past participle
# sent             VERB         relcl        send             verb, past tense
# caused           VERB         relcl        cause            verb, past tense
# set              VERB         xcomp        set              verb, past participle
# explained        VERB         ROOT         explain          verb, past tense
# succeeded        VERB         ccomp        succeed          verb, past participle
# reducing         VERB         pcomp        reduce           verb, gerund or present participle
# inscribed        VERB         ccomp        inscribe         verb, past participle
# form             VERB         ROOT         form             verb, base form
# live             VERB         relcl        live             verb, base form
# balance          VERB         advcl        balance          verb, base form
# climbed          VERB         ROOT         climb            verb, past tense
# set              VERB         conj         set              verb, past participle
# work             VERB         xcomp        work             verb, base form
# holding          VERB         pcomp        hold             verb, gerund or present participle
# written          VERB         ROOT         write            verb, past participle
# read             VERB         relcl        read             verb, past participle
# ran              VERB         ccomp        run              verb, past tense
# wear             VERB         ROOT         wear             verb, base form
# sleep            VERB         ROOT         sleep            verb, base form
# drink            VERB         ROOT         drink            verb, base form
# kill             VERB         ROOT         kill             verb, base form
# written          VERB         ROOT         write            verb, past participle
# written          VERB         pcomp        write            verb, past participle
# read             VERB         ROOT         read             verb, past tense
# nodded           VERB         ROOT         nod              verb, past tense
# began            VERB         conj         begin            verb, past tense
# learn            VERB         xcomp        learn            verb, base form
# cried            VERB         ROOT         cry              verb, past tense
# throwing         VERB         advcl        throw            verb, gerund or present participle
# Let              VERB         ROOT         let              verb, base form
# set              VERB         ROOT         set              verb, past tense
# milked           VERB         ROOT         milk             verb, past participle
# bursting         VERB         conj         burst            verb, gerund or present participle
# sent             VERB         acl          send             verb, past tense
# milked           VERB         conj         milk             verb, past tense
# adapted          VERB         ROOT         adapt            verb, past participle
# frothing         VERB         pcomp        froth            verb, gerund or present participle
# looked           VERB         relcl        look             verb, past tense
# happen           VERB         xcomp        happen           verb, base form
# used             VERB         ccomp        use              verb, past tense
# mix              VERB         xcomp        mix              verb, base form
# mind             VERB         parataxis    mind             verb, non-3rd person singular present
# cried            VERB         ROOT         cry              verb, past tense
# placing          VERB         advcl        place            verb, gerund or present participle
# attended         VERB         ROOT         attend           verb, past participle
# lead             VERB         ROOT         lead             verb, base form
# follow           VERB         ROOT         follow           verb, base form
# waiting          VERB         ROOT         wait             verb, gerund or present participle
# trooped          VERB         ROOT         troop            verb, past tense
# begin            VERB         advcl        begin            verb, base form
# came             VERB         advcl        come             verb, past tense
# noticed          VERB         conj         notice           verb, past participle
# disappeared      VERB         ccomp        disappear        verb, past participle
# toiled           VERB         relcl        toil             verb, past tense
# sweated          VERB         conj         sweat            verb, past tense
# rewarded         VERB         ROOT         reward           verb, past participle
# hoped            VERB         advcl        hope             verb, past participle
# designed         VERB         ROOT         design           verb, past participle
# use              VERB         xcomp        use              verb, base form
# involved         VERB         relcl        involve          verb, past tense
# standing         VERB         xcomp        stand            verb, gerund or present participle
# think            VERB         ccomp        think            verb, base form
# knew             VERB         ROOT         know             verb, past tense
# understood       VERB         conj         understand       verb, past tense
# mowing           VERB         pcomp        mow              verb, gerund or present participle
# raking           VERB         conj         rake             verb, gerund or present participle
# work             VERB         ROOT         work             verb, base form
# directed         VERB         conj         direct           verb, past tense
# supervised       VERB         conj         supervise        verb, past tense
# assume           VERB         ccomp        assume           verb, base form
# harness          VERB         ROOT         harness          verb, base form
# needed           VERB         conj         need             verb, past participle
# round            VERB         conj         round            verb, base form
# walking          VERB         pcomp        walk             verb, gerund or present participle
# worked           VERB         ROOT         work             verb, past tense
# turning          VERB         pcomp        turn             verb, gerund or present participle
# gathering        VERB         conj         gather           verb, gerund or present participle
# toiled           VERB         ROOT         toil             verb, past participle
# fro              VERB         conj         fro              verb, base form
# carrying         VERB         advcl        carry            verb, gerund or present participle
# finished         VERB         ROOT         finish           verb, past tense
# gathered         VERB         ROOT         gather           verb, past participle
# stolen           VERB         ROOT         steal            verb, past participle
# conceived        VERB         advcl        conceive         verb, past participle
# produced         VERB         acl          produce          verb, past participle
# doled            VERB         advcl        dole             verb, past tense
# eat              VERB         relcl        eat              verb, base form
# met              VERB         ccomp        meet             verb, past tense
# harvested        VERB         advcl        harvest          verb, past tense
# tread            VERB         xcomp        tread            verb, base form
# blow             VERB         conj         blow             verb, base form
# possessed        VERB         advcl        possess          verb, past tense
# pulled           VERB         conj         pull             verb, past tense
# rest             VERB         xcomp        rest             verb, base form
# pushing          VERB         ROOT         push             verb, gerund or present participle
# pulling          VERB         conj         pull             verb, gerund or present participle
# needed           VERB         xcomp        need             verb, past participle
# began            VERB         advcl        begin            verb, past tense
# work             VERB         ccomp        work             verb, base form
# adopted          VERB         ROOT         adopt            verb, past participle
# worked           VERB         ROOT         work             verb, past tense
# according        VERB         prep         accord           verb, gerund or present participle
# saved            VERB         ROOT         save             verb, past tense
# gathering        VERB         pcomp        gather           verb, gerund or present participle
# stole            VERB         ccomp        steal            verb, past tense
# grumbled         VERB         ROOT         grumble          verb, past tense
# disappeared      VERB         ccomp        disappear        verb, past participle
# shirked          VERB         ROOT         shirk            verb, past tense
# 11had            VERB         conj         11had            verb, past tense
# leaving          VERB         pcomp        leave            verb, gerund or present participle
# noticed          VERB         ROOT         notice           verb, past participle
# found            VERB         ccomp        find             verb, past participle
# vanish           VERB         ROOT         vanish           verb, base form
# reappear         VERB         conj         reappear         verb, base form
# happened         VERB         advcl        happen           verb, past participle
# purred           VERB         conj         purr             verb, past tense
# believe          VERB         xcomp        believe          verb, base form
# shirking         VERB         advcl        shirk            verb, gerund or present participle
# volunteering     VERB         conj         volunteer        verb, gerund or present participle
# express          VERB         ROOT         express          verb, base form
# asked            VERB         advcl        ask              verb, past participle
# live             VERB         ccomp        live             verb, non-3rd person singular present
# observed         VERB         relcl        observe          verb, past participle
# came             VERB         ROOT         come             verb, past tense
# found            VERB         ROOT         find             verb, past participle
# painted          VERB         conj         paint            verb, past participle
# run              VERB         ROOT         run              verb, past participle
# explained        VERB         parataxis    explain          verb, past tense
# represent        VERB         xcomp        represent        verb, base form
# signified        VERB         advcl        signify          verb, past tense
# arise            VERB         relcl        arise            verb, base form
# overthrown       VERB         ccomp        overthrow        verb, past participle
# trooped          VERB         ROOT         troop            verb, past tense
# known            VERB         relcl        know             verb, past participle
# coming           VERB         amod         come             verb, gerund or present participle
# planned          VERB         ROOT         plan             verb, past participle
# debated          VERB         conj         debate           verb, past participle
# understood       VERB         ROOT         understand       verb, past tense
# ...
# came             VERB         ROOT         come             verb, past tense
# worn             VERB         relcl        wear             verb, past participle
# developed        VERB         advcl        develop          verb, past participle
# complaining      VERB         pcomp        complain         verb, gerund or present participle
# criticising      VERB         advcl        criticise        verb, gerund or present participle
# happened         VERB         ccomp        happen           verb, past tense
# uttered          VERB         conj         utter            verb, past participle
# burst            VERB         ROOT         burst            verb, past tense
# stopping         VERB         pcomp        stop             verb, gerund or present participle
# quieted          VERB         relcl        quiet            verb, past participle
# utter            VERB         acl          utter            verb, base form
# passed           VERB         advcl        pass             verb, past participle
# marched          VERB         ROOT         march            verb, past participle
# felt             VERB         ROOT         feel             verb, past tense
# nuzzling         VERB         ccomp        nuzzle           verb, gerund or present participle
# looked           VERB         ROOT         look             verb, past tense
# looked           VERB         ROOT         look             verb, past tense
# tugged           VERB         ROOT         tug              verb, past tense
# led              VERB         conj         lead             verb, past tense
# written          VERB         relcl        write            verb, past participle
# stood            VERB         ROOT         stand            verb, past tense
# gazing           VERB         xcomp        gaze             verb, gerund or present participle
# failing          VERB         ccomp        fail             verb, gerund or present participle
# read             VERB         ROOT         read             verb, past participle
# written          VERB         ccomp        write            verb, past participle
# appears          VERB         ROOT         appear           verb, 3rd person singular present
# looks            VERB         ccomp        look             verb, 3rd person singular present
# used             VERB         advcl        use              verb, past tense
# consented        VERB         ROOT         consent          verb, past tense
# break            VERB         xcomp        break            verb, base form
# read             VERB         conj         read             verb, past tense
# written          VERB         ccomp        write            verb, past participle
# ran              VERB         ccomp        run              verb, past tense
# supervising      VERB         relcl        supervise        verb, gerund or present participle
# carried          VERB         advcl        carry            verb, past tense
# learn            VERB         xcomp        learn            verb, base form
# bought           VERB         ccomp        buy              verb, past participle
# arranging        VERB         conj         arrange          verb, gerund or present participle
# install          VERB         xcomp        install          verb, base form
# strolling        VERB         xcomp        stroll           verb, gerund or present participle
# appearing        VERB         advcl        appear           verb, gerund or present participle
# breeches         VERB         conj         breeche          verb, 3rd person singular present
# appeared         VERB         advcl        appear           verb, past tense
# used             VERB         relcl        use              verb, past participle
# wear             VERB         xcomp        wear             verb, base form
# drove            VERB         ROOT         drive            verb, past tense
# neighbouring     VERB         compound     neighbour        verb, gerund or present participle
# invited          VERB         ROOT         invite           verb, past participle
# expressed        VERB         conj         express          verb, past tense
# weeding          VERB         ROOT         weed             verb, gerund or present participle
# worked           VERB         ROOT         work             verb, past tense
# raising          VERB         advcl        raise            verb, gerund or present participle
# knowing          VERB         conj         know             verb, gerund or present participle
# came             VERB         ROOT         come             verb, past tense
# mingled          VERB         amod         mingle           verb, past participle
# stricken         VERB         ROOT         stricken         verb, past participle
# happening        VERB         advcl        happen           verb, gerund or present participle
# meeting          VERB         ROOT         meet             verb, gerund or present participle
# began            VERB         ROOT         begin            verb, past tense
# creep            VERB         xcomp        creep            verb, base form
# paused           VERB         parataxis    pause            verb, past tense
# frightened       VERB         ROOT         frighten         verb, past tense
# led              VERB         conj         lead             verb, past tense
# tiptoed          VERB         ROOT         tiptoe           verb, past tense
# peered           VERB         acomp        peer             verb, past participle
# round            VERB         advcl        round            verb, base form
# sat              VERB         ROOT         sit              verb, past tense
# occupying        VERB         advcl        occupy           verb, gerund or present participle
# appeared         VERB         ROOT         appear           verb, past tense
# enjoying         VERB         ROOT         enjoy            verb, gerund or present participle
# broken           VERB         conj         break            verb, past participle
# drink            VERB         acl          drink            verb, base form
# circulating      VERB         ROOT         circulate        verb, gerund or present participle
# refilled         VERB         conj         refill           verb, past participle
# noticed          VERB         ROOT         notice           verb, past tense
# wondering        VERB         amod         wonder           verb, gerund or present participle
# gazed            VERB         relcl        gaze             verb, past tense
# stood            VERB         ROOT         stand            verb, past participle
# ask              VERB         ROOT         ask              verb, base form
# drink            VERB         xcomp        drink            verb, base form
# felt             VERB         relcl        feel             verb, past tense
# present          VERB         amod         present          verb, non-3rd person singular present
# feel             VERB         xcomp        feel             verb, base form
# come             VERB         ccomp        come             verb, past participle
# shared           VERB         acl          share            verb, past participle
# respected        VERB         amod         respect          verb, past participle
# regarded         VERB         relcl        regard           verb, past participle
# occurred         VERB         ccomp        occur            verb, past participle
# felt             VERB         ROOT         feel             verb, past participle
# operated         VERB         conj         operate          verb, past participle
# assumed          VERB         ROOT         assume           verb, past participle
# prevail          VERB         ccomp        prevail          verb, base form
# dispelled        VERB         ROOT         dispel           verb, past participle
# visited          VERB         ROOT         visit            verb, past participle
# inspected        VERB         conj         inspect          verb, past tense
# find             VERB         conj         find             verb, base form
# believed         VERB         ROOT         believe          verb, past tense
# received         VERB         conj         receive          verb, past tense
# observed         VERB         ROOT         observe          verb, past participle
# intended         VERB         relcl        intend           verb, past tense
# introduce        VERB         xcomp        introduce        verb, base form
# end              VERB         ROOT         end              verb, base form
# emphasising      VERB         pcomp        emphasise        verb, gerund or present participle
# subsisted        VERB         relcl        subsist          verb, past tense
# subsist          VERB         xcomp        subsist          verb, base form
# spring           VERB         xcomp        spring           verb, base form
# overcome         VERB         conj         overcome         verb, past participle
# utter            VERB         xcomp        utter            verb, base form
# turned           VERB         relcl        turn             verb, past tense
# managed          VERB         ROOT         manage           verb, past tense
# contend          VERB         relcl        contend          verb, base form
# set              VERB         ROOT         set              verb, past tense
# congratulated    VERB         conj         congratulate     verb, past tense
# working          VERB         compound     work             verb, gerund or present participle
# pampering        VERB         pcomp        pamper           verb, gerund or present participle
# observed         VERB         relcl        observe          verb, past participle
# ask              VERB         ccomp        ask              verb, base form
# rise             VERB         xcomp        rise             verb, base form
# concluded        VERB         ROOT         conclude         verb, past tense
# stamping         VERB         conj         stamp            verb, gerund or present participle
# left             VERB         ccomp        leave            verb, past tense
# came             VERB         conj         come             verb, past tense
# clink            VERB         advcl        clink            verb, base form
# died             VERB         advcl        die              verb, past participle
# remained         VERB         relcl        remain           verb, past participle
# intimated        VERB         ROOT         intimate         verb, past tense
# circulated       VERB         dep          circulate        verb, past participle
# think            VERB         relcl        think            verb, base form
# credited         VERB         ROOT         credit           verb, past participle
# attempting       VERB         pcomp        attempt          verb, gerund or present participle
# stir             VERB         xcomp        stir             verb, base form
# live             VERB         xcomp        live             verb, base form
# control          VERB         relcl        control          verb, base form
# added            VERB         parataxis    add              verb, past tense
# believe          VERB         ROOT         believe          verb, base form
# lingered         VERB         ccomp        linger           verb, past tense
# promoting        VERB         pcomp        promote          verb, gerund or present participle
# addressing       VERB         pcomp        address          verb, gerund or present participle
# suppressed       VERB         xcomp        suppress         verb, past participle
# nailed           VERB         relcl        nail             verb, past participle
# suppressed       VERB         ROOT         suppress         verb, past participle
# buried           VERB         conj         bury             verb, past participle
# observed         VERB         ROOT         observe          verb, past participle
# flew             VERB         relcl        fly              verb, past tense
# noted            VERB         ROOT         note             verb, past participle
# marked           VERB         relcl        mark             verb, past participle
# removed          VERB         ccomp        remove           verb, past participle
# referred         VERB         ROOT         refer            verb, past participle
# know             VERB         ROOT         know             verb, non-3rd person singular present
# announcing       VERB         acl          announce         verb, gerund or present participle
# abolished        VERB         ccomp        abolish          verb, past participle
# known            VERB         xcomp        know             verb, past participle
# believed         VERB         parataxis    believe          verb, past tense
# concluded        VERB         ROOT         conclude         verb, past tense
# Fill             VERB         ROOT         fill             verb, base form
# cheering         VERB         acl          cheer            verb, gerund or present participle
# gazed            VERB         advcl        gaze             verb, past participle
# happening        VERB         ccomp        happen           verb, gerund or present participle
# altered          VERB         ccomp        alter            verb, past participle
# flitted          VERB         ROOT         flit             verb, past tense
# melting          VERB         xcomp        melt             verb, gerund or present participle
# changing         VERB         conj         change           verb, gerund or present participle
# come             VERB         advcl        come             verb, past participle
# continued        VERB         conj         continue         verb, past tense
# interrupted      VERB         relcl        interrupt        verb, past participle
# crept            VERB         conj         creep            verb, past tense
# stopped          VERB         advcl        stop             verb, past tense
# coming           VERB         ROOT         come             verb, gerund or present participle
# rushed           VERB         ROOT         rush             verb, past tense
# looked           VERB         conj         look             verb, past tense
# appeared         VERB         ROOT         appear           verb, past tense
# played           VERB         ccomp        play             verb, past participle
# shouting         VERB         ROOT         shout            verb, gerund or present participle
# happened         VERB         relcl        happen           verb, past participle
# looked           VERB         ROOT         look             verb, past tense
# runs             VERB         relcl        run              verb, 3rd person singular present
# published        VERB         relcl        publish          verb, past participle
# hope             VERB         conj         hope             verb, non-3rd person singular present
# reading          VERB         ccomp        read             verb, gerund or present participle
# bought           VERB         advcl        buy              verb, past tense
# thank            VERB         ROOT         thank            verb, non-3rd person singular present
# downloaded       VERB         advcl        download         verb, past tense
# consider         VERB         ROOT         consider         verb, base form
# help             VERB         ccomp        help             verb, base form
# running          VERB         acl          run              verb, gerund or present participle
# bought           VERB         advcl        buy              verb, past tense
# ripped           VERB         ROOT         rip              verb, past participle
# selling          VERB         conj         sell             verb, gerund or present participle
# reading          VERB         pcomp        read             verb, gerund or present participle
# hope             VERB         ROOT         hope             verb, non-3rd person singular present
# visit            VERB         ccomp        visit            verb, non-3rd person singular present
# added            VERB         ccomp        add              verb, past participle
# find             VERB         advcl        find             verb, base form

# %%
verbs
# Out:
# {'come': 94,
#  'work': 43,
#  'know': 42,
#  'begin': 33,
#  'find': 33,
#  'happen': 30,
#  'think': 29,
#  'stand': 27,
#  'remember': 26,
#  'set': 26,
#  'look': 26,
#  'run': 26,
#  'break': 26,
#  'hear': 25,
#  'appear': 25,
#  'live': 24,
#  'believe': 24,
#  'read': 24,
#  'speak': 23,
#  'announce': 20,
#  'lie': 19,
#  'use': 19,
#  'turn': 19,
#  'cry': 19,
#  'sing': 18,
#  'lead': 17,
#  'tell': 17,
#  'wear': 17,
#  'send': 17,
#  'feel': 16,
#  'pass': 16,
#  'carry': 16,
#  'learn': 16,
#  'follow': 16,
#  'grow': 15,
#  'die': 15,
#  'write': 15,
#  'walk': 14,
#  'ask': 14,
#  'sleep': 14,
#  'sit': 14,
#  'build': 14,
#  'understand': 13,
#  'hold': 13,
#  'raise': 12,
#  'notice': 12,
#  'finish': 12,
#  'draw': 11,
#  'lose': 11,
#  'talk': 11,
#  'round': 11,
#  'lay': 11,
#  'let': 11,
#  'bring': 11,
#  'remain': 11,
#  'leave': 11,
#  'listen': 10,
#  'sell': 10,
#  'discover': 10,
#  'need': 10,
#  'try': 10,
#  'race': 10,
#  'rush': 10,
#  'utter': 10,
#  'buy': 10,
#  'meet': 9,
#  'fall': 9,
#  'continue': 9,
#  'save': 9,
#  'drink': 9,
#  'forget': 9,
#  'fling': 9,
#  'gaze': 9,
#  'intend': 9,
#  'receive': 9,
#  'confess': 9,
#  'produce': 8,
#  'creep': 8,
#  'kill': 8,
#  'spread': 8,
#  'spring': 8,
#  'feed': 8,
#  'end': 8,
#  'destroy': 8,
#  'explain': 8,
#  'reduce': 8,
#  'disappear': 8,
#  'decide': 8,
#  'declare': 8,
#  'prove': 8,
#  'watch': 8,
#  'drive': 8,
#  'fire': 8,
#  'stir': 8,
#  'mean': 8,
#  'stop': 8,
#  'drag': 8,
#  'order': 8,
#  'agree': 7,
#  'hope': 7,
#  'wait': 7,
#  'bear': 7,
#  'fight': 7,
#  'throw': 7,
#  'want': 7,
#  'accept': 7,
#  'hide': 7,
#  'enter': 7,
#  'form': 7,
#  'gather': 7,
#  'retire': 7,
#  'drop': 7,
#  'pay': 7,
#  'kick': 6,
#  'spend': 6,
#  'steal': 6,
#  'catch': 6,
#  'allow': 6,
#  'teach': 6,
#  'toil': 6,
#  'flee': 6,
#  'whisk': 6,
#  'expect': 6,
#  'snuff': 6,
#  'attend': 6,
#  'paint': 6,
#  'eat': 6,
#  'refuse': 6,
#  'imagine': 6,
#  'manage': 6,
#  'win': 6,
#  'assemble': 6,
#  'shout': 6,
#  'warn': 6,
#  'hang': 5,
#  'cut': 5,
#  'settle': 5,
#  'approach': 5,
#  'abolish': 5,
#  'starve': 5,
#  'serve': 5,
#  'engage': 5,
#  'bleat': 5,
#  'fly': 5,
#  'bury': 5,
#  'prepare': 5,
#  'argue': 5,
#  'skip': 5,
#  'hate': 5,
#  'bar': 5,
#  'halt': 5,
#  'fro': 5,
#  'accord': 5,
#  'express': 5,
#  'fail': 5,
#  'change': 5,
#  'circulate': 5,
#  'march': 5,
#  'attempt': 5,
#  'cover': 5,
#  'complete': 5,
#  'protest': 5,
#  'pronounce': 5,
#  'add': 5,
#  'shut': 4,
#  'regard': 4,
#  'chew': 4,
#  'file': 4,
#  'clear': 4,
#  'face': 4,
#  'force': 4,
#  'remove': 4,
#  'pull': 4,
#  'reach': 4,
#  'vote': 4,
#  'repeat': 4,
#  'adopt': 4,
#  'vanish': 4,
#  'blow': 4,
#  'singe': 4,
#  'burst': 4,
#  'interrupt': 4,
#  'consider': 4,
#  'sound': 4,
#  'milk': 4,
#  'lash': 4,
#  'frighten': 4,
#  'slip': 4,
#  'chase': 4,
#  'gallop': 4,
#  'succeed': 4,
#  'inscribe': 4,
#  'mix': 4,
#  'assume': 4,
#  'observe': 4,
#  'treat': 4,
#  'collect': 4,
#  'complain': 4,
#  'pretend': 4,
#  'emerge': 4,
#  'stretch': 4,
#  'exclaim': 4,
#  'report': 4,
#  'enjoy': 4,
#  'sow': 4,
#  'operate': 4,
#  'lift': 4,
#  'procure': 4,
#  'increase': 4,
#  'defeat': 4,
#  'deliver': 4,
#  'compose': 4,
#  'occur': 4,
#  'fill': 4,
#  'act': 4,
#  'visit': 4,
#  'convince': 4,
#  'rebuild': 4,
#  'wound': 4,
#  'forbid': 4,
#  'return': 4,
#  'wish': 3,
#  'arrive': 3,
#  'laugh': 3,
#  'admit': 3,
#  'graze': 3,
#  'tread': 3,
#  'support': 3,
#  'prevent': 3,
#  'boil': 3,
#  'remind': 3,
#  'labour': 3,
#  'organise': 3,
#  'refer': 3,
#  'care': 3,
#  'achieve': 3,
#  'help': 3,
#  'wake': 3,
#  'plan': 3,
#  'butt': 3,
#  'defend': 3,
#  'decorate': 3,
#  'fetch': 3,
#  'command': 3,
#  'gambol': 3,
#  'roll': 3,
#  'survey': 3,
#  'admire': 3,
#  'cause': 3,
#  'place': 3,
#  'possess': 3,
#  'push': 3,
#  'reappear': 3,
#  'oppose': 3,
#  'study': 3,
#  'shake': 3,
#  'contain': 3,
#  'develop': 3,
#  'start': 3,
#  'dislike': 3,
#  'wonder': 3,
#  'create': 3,
#  'dash': 3,
#  'strike': 3,
#  'confer': 3,
#  'stroll': 3,
#  'stroke': 3,
#  'occupy': 3,
#  'demand': 3,
#  'supply': 3,
#  'waste': 3,
#  'realise': 3,
#  'cast': 3,
#  'bound': 3,
#  'growl': 3,
#  'accumulate': 3,
#  'weed': 3,
#  'exist': 3,
#  'arrange': 3,
#  'avoid': 3,
#  'cease': 3,
#  'issue': 3,
#  'instruct': 3,
#  'cowshe': 3,
#  'charge': 3,
#  'pause': 3,
#  'bleed': 3,
#  'taste': 3,
#  'tear': 3,
#  'huddle': 3,
#  'r': 3,
#  'appoint': 3,
#  'like': 3,
#  'inspect': 3,
#  'congratulate': 3,
#  'limp': 3,
#  'mark': 3,
#  'communicate': 2,
#  'perch': 2,
#  'conceal': 2,
#  'respect': 2,
#  'temper': 2,
#  'flirt': 2,
#  'purr': 2,
#  'acquire': 2,
#  'slaughter': 2,
#  'afford': 2,
#  'breed': 2,
#  'hatch': 2,
#  'grumble': 2,
#  'escape': 2,
#  'tie': 2,
#  'drown': 2,
#  'rid': 2,
#  'fix': 2,
#  'falter': 2,
#  'resemble': 2,
#  'conquer': 2,
#  'touch': 2,
#  'describe': 2,
#  'whip': 2,
#  'pick': 2,
#  'seize': 2,
#  'jump': 2,
#  'twinkle': 2,
#  'claim': 2,
#  'neglect': 2,
#  'behave': 2,
#  'choose': 2,
#  'flap': 2,
#  'expel': 2,
#  'wipe': 2,
#  'burn': 2,
#  'hurl': 2,
#  'disturb': 2,
#  'miss': 2,
#  'preserve': 2,
#  'reveal': 2,
#  'belong': 2,
#  'nod': 2,
#  'troop': 2,
#  'involve': 2,
#  'direct': 2,
#  'supervise': 2,
#  'rest': 2,
#  'shirk': 2,
#  'arise': 2,
#  'object': 2,
#  'tame': 2,
#  'join': 2,
#  'trace': 2,
#  'stare': 2,
#  'ripen': 2,
#  'litter': 2,
#  'share': 2,
#  'reserve': 2,
#  'mingle': 2,
#  'suffer': 2,
#  'practise': 2,
#  'tremble': 2,
#  'stack': 2,
#  'launch': 2,
#  'peck': 2,
#  'rear': 2,
#  'overtake': 2,
#  'gore': 2,
#  'trample': 2,
#  'sink': 2,
#  'paw': 2,
#  'fear': 2,
#  'stun': 2,
#  'recover': 2,
#  'emphasise': 2,
#  'prance': 2,
#  'mention': 2,
#  'suggest': 2,
#  'improve': 2,
#  'examine': 2,
#  'contemplate': 2,
#  'urinate': 2,
#  'bind': 2,
#  'advocate': 2,
#  'advise': 2,
#  'pitch': 2,
#  'crowd': 2,
#  'close': 2,
#  'trust': 2,
#  'appreciate': 2,
#  'suppose': 2,
#  'undo': 2,
#  'present': 2,
#  'mat': 2,
#  'fence': 2,
#  'silence': 2,
#  'assure': 2,
#  'puzzle': 2,
#  'spell': 2,
#  'marvel': 2,
#  'dream': 2,
#  'pace': 2,
#  'capture': 2,
#  'invent': 2,
#  'guard': 2,
#  'surround': 2,
#  'smash': 2,
#  'punish': 2,
#  'rumour': 2,
#  'neighbour': 2,
#  'smell': 2,
#  'plot': 2,
#  'attack': 2,
#  'rally': 2,
#  'formulate': 2,
#  'frisk': 2,
#  'state': 2,
#  'hand': 2,
#  'urge': 2,
#  'murder': 2,
#  'slay': 2,
#  'plough': 2,
#  'protect': 2,
#  'dare': 2,
#  'establish': 2,
#  'emembere': 2,
#  'm': 2,
#  'execute': 2,
#  'leak': 2,
#  'instal': 2,
#  'overcome': 2,
#  'cart': 2,
#  'alter': 2,
#  'knock': 2,
#  'celebrate': 2,
#  'brace': 2,
#  'introduce': 2,
#  'purchase': 2,
#  'trouble': 2,
#  'point': 2,
#  'play': 2,
#  'elect': 2,
#  'determine': 2,
#  'profess': 2,
#  'stamp': 2,
#  'whisper': 2,
#  'subsist': 2,
#  'conclude': 2,
#  'suppress': 2,
#  'lock': 1,
#  'lurch': 1,
#  'snore': 1,
#  'exhibit': 1,
#  'ensconce': 1,
#  'flutter': 1,
#  'lain': 1,
#  'cheep': 1,
#  'wander': 1,
#  'nestle': 1,
#  'plait': 1,
#  'squeeze': 1,
#  'dwell': 1,
#  'inhabit': 1,
#  'sum': 1,
#  'consume': 1,
#  'till': 1,
#  'fertilise': 1,
#  'cow': 1,
#  'hen': 1,
#  'bore': 1,
#  'scream': 1,
#  'propose': 1,
#  'rat': 1,
#  'smoke': 1,
#  'tyrannise': 1,
#  'spur': 1,
#  'rust': 1,
#  'crack': 1,
#  'picture': 1,
#  'shine': 1,
#  'low': 1,
#  'whine': 1,
#  'whinny': 1,
#  'quack': 1,
#  'awake': 1,
#  'predict': 1,
#  'recognise': 1,
#  'elaborate': 1,
#  'expound': 1,
#  'counteract': 1,
#  '6calle': 1,
#  'situate': 1,
#  'persuade': 1,
#  'absorb': 1,
#  'dishearten': 1,
#  'lounge': 1,
#  'soak': 1,
#  'rabbit': 1,
#  'bother': 1,
#  'unfe': 1,
#  'thrash': 1,
#  'maltreat': 1,
#  'pursue': 1,
#  'croak': 1,
#  'slam': 1,
#  'castrate': 1,
#  'caper': 1,
#  'crop': 1,
#  'reproach': 1,
#  'stove': 1,
#  'balance': 1,
#  'climb': 1,
#  'adapt': 1,
#  'froth': 1,
#  'mind': 1,
#  'sweat': 1,
#  'reward': 1,
#  'design': 1,
#  'mow': 1,
#  'rake': 1,
#  'harness': 1,
#  'conceive': 1,
#  'dole': 1,
#  'harvest': 1,
#  '11had': 1,
#  'volunteer': 1,
#  'represent': 1,
#  'signify': 1,
#  'overthrow': 1,
#  'debate': 1,
#  'count': 1,
#  'resolve': 1,
#  'busy': 1,
#  'institute': 1,
#  'exercise': 1,
#  'refresh': 1,
#  'spelt': 1,
#  'grasp': 1,
#  'distinguish': 1,
#  'whelp': 1,
#  'wean': 1,
#  'murmur': 1,
#  'depend': 1,
#  'sympathise': 1,
#  'adjoin': 1,
#  'hunt': 1,
#  'scorn': 1,
#  'insist': 1,
#  'tolerate': 1,
#  'flourish': 1,
#  'torture': 1,
#  'rebel': 1,
#  'devour': 1,
#  'shoot': 1,
#  'whistle': 1,
#  'coo': 1,
#  'thresh': 1,
#  'whirl': 1,
#  'alight': 1,
#  'mute': 1,
#  'deal': 1,
#  'prod': 1,
#  'hobnail': 1,
#  'score': 1,
#  'bite': 1,
#  'leapt': 1,
#  'yell': 1,
#  'hiss': 1,
#  'harm': 1,
#  'reassemble': 1,
#  'recount': 1,
#  'plant': 1,
#  'consist': 1,
#  'excuse': 1,
#  'divide': 1,
#  'clip': 1,
#  'ratify': 1,
#  'disagree': 1,
#  'canvass': 1,
#  'bide': 1,
#  'light': 1,
#  'warm': 1,
#  'conjure': 1,
#  'closet': 1,
#  'grip': 1,
#  'deny': 1,
#  'quarry': 1,
#  'maintain': 1,
#  '19starve': 1,
#  'recapture': 1,
#  'reinstate': 1,
#  'train': 1,
#  'reply': 1,
#  'sordid': 1,
#  'stud': 1,
#  'snap': 1,
#  'gain': 1,
#  'spare': 1,
#  'terrify': 1,
#  'solve': 1,
#  'wag': 1,
#  'mount': 1,
#  'relate': 1,
#  'preside': 1,
#  'salute': 1,
#  'dismay': 1,
#  'marshal': 1,
#  'voice': 1,
#  'rub': 1,
#  'disinter': 1,
#  'require': 1,
#  'disperse': 1,
#  'grudge': 1,
#  'thieve': 1,
#  'absent': 1,
#  'foresee': 1,
#  'utilise': 1,
#  'topple': 1,
#  'shatter': 1,
#  'transport': 1,
#  'yoke': 1,
#  'strain': 1,
#  'claw': 1,
#  'overstrain': 1,
#  'outweigh': 1,
#  'obtain': 1,
#  'override': 1,
#  'welcome': 1,
#  'smooth': 1,
#  'dismiss': 1,
#  '24dreame': 1,
#  'mistake': 1,
#  'rouse': 1,
#  'reconcile': 1,
#  'prosper': 1,
#  'pig': 1,
#  'rob': 1,
#  'reassure': 1,
#  'compensate': 1,
#  'plod': 1,
#  '-finishe': 1,
#  'impose': 1,
#  'rage': 1,
#  'rock': 1,
#  'squawk': 1,
#  'pluck': 1,
#  'level': 1,
#  'scatter': 1,
#  'twitch': 1,
#  'overthrown': 1,
#  'roar': 1,
#  'avenge': 1,
#  'jus': 1,
#  'shock': 1,
#  'rejoice': 1,
#  'frost': 1,
#  'discolour': 1,
#  'embolden': 1,
#  'resort': 1,
#  'select': 1,
#  'remark': 1,
#  'deceive': 1,
#  'surrender': 1,
#  'thwart': 1,
#  'decreed': 1,
#  'capitulate': 1,
#  'nest': 1,
#  'hesitate': 1,
#  'incline': 1,
#  'frequent': 1,
#  'perform': 1,
#  'upset': 1,
#  'gnaw': 1,
#  'attribute': 1,
#  'block': 1,
#  'decree': 1,
#  'detect': 1,
#  '-curdle': 1,
#  'pervade': 1,
#  'menace': 1,
#  'stupefy': 1,
#  'outdo': 1,
#  'encourage': 1,
#  'fit': 1,
#  'tuck': 1,
#  'lure': 1,
#  'lurk': 1,
#  'award': 1,
#  'cower': 1,
#  'squeal': 1,
#  'pin': 1,
#  'shriek': 1,
#  'crush': 1,
#  'slink': 1,
#  'bruise': 1,
#  'howl': 1,
#  'prompt': 1,
#  'collaborate': 1,
#  'incite': 1,
#  'disobey': 1,
#  'secrete': 1,
#  'ffere': 1,
#  'league': 1,
#  'witness': 1,
#  'fidget': 1,
#  'swish': 1,
#  'lumber': 1,
#  'curl': 1,
#  'gild': 1,
#  'aim': 1,
#  'roam': 1,
#  'lack': 1,
#  'ause': 1,
#  'h': 1,
#  'ie': 1,
#  'eddle': 1,
#  'ippe': 1,
#  'sa': 1,
#  'violate': 1,
#  'eague': 1,
#  'disbelieve': 1,
#  'ette': 1,
#  'nhabite': 1,
#  'entitle': 1,
#  'love': 1,
#  'approve': 1,
#  'surmount': 1,
#  'offer': 1,
#  'renew': 1,
#  'arouse': 1,
#  'skulk': 1,
#  'inspire': 1,
#  'poison': 1,
#  'conduct': 1,
#  'distrust': 1,
#  'prefer': 1,
#  'near': 1,
#  'bribe': 1,
#  'flog': 1,
#  'amuse': 1,
#  'clamour': 1,
#  'counsel': 1,
#  'commit': 1,
#  'swallow': 1,
#  'censure': 1,
#  'negotiate': 1,
#  'forsake': 1,
#  'insult': 1,
#  'originate': 1,
#  'smile': 1,
#  'repose': 1,
#  'pile': 1,
#  'rustle': 1,
#  'choke': 1,
#  'speed': 1,
#  '-': 1,
#  'sally': 1,
#  'open': 1,
#  'peep': 1,
#  'include': 1,
#  'pencil': 1,
#  'drill': 1,
#  'pack': 1,
#  'blast': 1,
#  'venture': 1,
#  'deafen': 1,
#  'swirl': 1,
#  'drift': 1,
#  'heed': 1,
#  'sweep': 1,
#  'chip': 1,
#  'bay': 1,
#  'beam': 1,
#  'split': 1,
#  'lodge': 1,
#  'smart': 1,
#  'bestow': 1,
#  'overlook': 1,
#  'impart': 1,
#  'contrive': 1,
#  'exhaust': 1,
#  'sprawl': 1,
#  'escort': 1,
#  'discuss': 1,
#  'survive': 1,
#  'fade': 1,
#  'doubtless': 1,
#  'guess': 1,
#  '41purchase': 1,
#  'discourage': 1,
#  'waft': 1,
#  'disuse': 1,
#  'sniff': 1,
#  'offset': 1,
#  'flank': 1,
#  'comfort': 1,
#  'proclaim': 1,
#  'inflict': 1,
#  'reason': 1,
#  'heal': 1,
#  'shrink': 1,
#  'glaze': 1,
#  'trickle': 1,
#  'matter': 1,
#  'administer': 1,
#  'devote': 1,
#  'astonish': 1,
#  'bray': 1,
#  '-looke': 1,
#  'crown': 1,
#  'chorus': 1,
#  'drum': 1,
#  'appeal': 1,
#  'quicken': 1,
#  'dart': 1,
#  'proceed': 1,
#  'relieve': 1,
#  'enlarge': 1,
#  'generate': 1,
#  'mill': 1,
#  'denounce': 1,
#  'expend': 1,
#  'rack': 1,
#  'compare': 1,
#  'demonstrate': 1,
#  'speculate': 1,
#  'england!—owne': 1,
#  'swell': 1,
#  'abandon': 1,
#  'hum': 1,
#  'fulfil': 1,
#  'browse': 1,
#  'stay': 1,
#  'startle': 1,
#  'neigh': 1,
#  'criticise': 1,
#  'quiet': 1,
#  'nuzzle': 1,
#  'tug': 1,
#  'consent': 1,
#  'install': 1,
#  'breeche': 1,
#  'invite': 1,
#  'stricken': 1,
#  'tiptoe': 1,
#  'peer': 1,
#  'refill': 1,
#  'prevail': 1,
#  'dispel': 1,
#  'contend': 1,
#  'pamper': 1,
#  'rise': 1,
#  'clink': 1,
#  'intimate': 1,
#  'credit': 1,
#  'control': 1,
#  'linger': 1,
#  'promote': 1,
#  'address': 1,
#  'nail': 1,
#  'note': 1,
#  'cheer': 1,
#  'flit': 1,
#  'melt': 1,
#  'publish': 1,
#  'thank': 1,
#  'download': 1,
#  'rip': 1}

# %%
verbs_df = pd.DataFrame({'word':verbs.keys(), 'frequency':verbs.values()})
verbs_df
# Out:
#          word  frequency
# 0        come         94
# 1        work         43
# 2        know         42
# 3       begin         33
# 4        find         33
# ..        ...        ...
# 861      melt          1
# 862   publish          1
# 863     thank          1
# 864  download          1
# 865       rip          1
#
# [866 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data=verbs_df.iloc[:20], x='word', y='frequency');

# %%
wordcloud = WordCloud(width=1200, height=800, background_color='#FFFFFF').generate_from_frequencies(verbs)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud);

# %%
propns = token_frequency(whole_text, only_include=['PROPN'], verbos=True)
# Out:
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Manor            PROPN        compound     Manor            noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Mrs.             PROPN        compound     Mrs.             noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Word             PROPN        nsubj        Word             noun, proper singular
# Major            PROPN        nsubj        Major            noun, proper singular
# Middle           PROPN        compound     Middle           noun, proper singular
# White            PROPN        compound     White            noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Major            PROPN        nsubjpass    Major            noun, proper singular
# Willingdon       PROPN        compound     Willingdon       noun, proper singular
# Beauty           PROPN        attr         Beauty           noun, proper singular
# Major            PROPN        nsubjpass    Major            noun, proper singular
# Bluebell         PROPN        appos        Bluebell         noun, proper singular
# Jessie           PROPN        conj         Jessie           noun, proper singular
# Pincher          PROPN        conj         Pincher          noun, proper singular
# Boxer            PROPN        conj         Boxer            noun, proper singular
# Clover           PROPN        conj         Clover           noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Muriel           PROPN        nsubj        Muriel           noun, proper singular
# white            PROPN        compound     white            noun, proper singular
# goat             PROPN        conj         goat             noun, proper singular
# Benjamin         PROPN        conj         Benjamin         noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# God              PROPN        nsubj        God              noun, proper singular
# Boxer            PROPN        pobj         Boxer            noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Boxer            PROPN        pobj         Boxer            noun, proper singular
# Clover           PROPN        conj         Clover           noun, proper singular
# Major            PROPN        poss         Major            noun, proper singular
# Moses            PROPN        pobj         Moses            noun, proper singular
# Major            PROPN        nsubj        Major            noun, proper singular
# w                PROPN        pobj         w                noun, proper singular
# England          PROPN        pobj         England          noun, proper singular
# England          PROPN        pobj         England          noun, proper singular
# England          PROPN        pobj         England          noun, proper singular
# Man              PROPN        compound     Man              noun, proper singular
# .                PROPN        compound     .                noun, proper singular
# Man              PROPN        nsubj        Man              noun, proper singular
# Man              PROPN        dobj         Man              noun, proper singular
# lord             PROPN        attr         lord             noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# Clover           PROPN        appos        Clover           noun, proper singular
# cruel            PROPN        amod         cruel            noun, proper singular
# Boxer            PROPN        appos        Boxer            noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Man              PROPN        pobj         Man              noun, proper singular
# Rebellion        PROPN        nsubj        Rebellion        noun, proper singular
# Man              PROPN        nsubj        Man              noun, proper singular
# Man              PROPN        nsubj        Man              noun, proper singular
# Major            PROPN        nsubj        Major            noun, proper singular
# Major            PROPN        nsubj        Major            noun, proper singular
# Major            PROPN        nsubj        Major            noun, proper singular
# Man              PROPN        pobj         Man              noun, proper singular
# Man              PROPN        pobj         Man              noun, proper singular
# Man              PROPN        pobj         Man              noun, proper singular
# Man              PROPN        nsubj        Man              noun, proper singular
# Beasts           PROPN        oprd         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Old              PROPN        compound     Old              noun, proper singular
# Major            PROPN        nsubj        Major            noun, proper singular
# Clementine       PROPN        pobj         Clementine       noun, proper singular
# La               PROPN        compound     La               noun, proper singular
# Cucuracha        PROPN        conj         Cucuracha        noun, proper singular
# Beasts           PROPN        nsubj        Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Ireland          PROPN        pobj         Ireland          noun, proper singular
# Hearken          PROPN        ROOT         Hearken          noun, proper singular
# Tyrant           PROPN        compound     Tyrant           noun, proper singular
# Man              PROPN        nsubj        Man              noun, proper singular
# England          PROPN        pobj         England          noun, proper singular
# Cruel            PROPN        nsubj        Cruel            noun, proper singular
# hay              PROPN        conj         hay              noun, proper singular
# Clover           PROPN        conj         Clover           noun, proper singular
# England          PROPN        pobj         England          noun, proper singular
# Purer            PROPN        nsubj        Purer            noun, proper singular
# geese            PROPN        conj         geese            noun, proper singular
# England          PROPN        pobj         England          noun, proper singular
# Ireland          PROPN        pobj         Ireland          noun, proper singular
# Hearken          PROPN        ROOT         Hearken          noun, proper singular
# Major            PROPN        nsubj        Major            noun, proper singular
# Beasts           PROPN        pobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        dobj         Jones            noun, proper singular
# Major            PROPN        nsubj        Major            noun, proper singular
# March            PROPN        pobj         March            noun, proper singular
# Major            PROPN        poss         Major            noun, proper singular
# Rebellion        PROPN        nsubj        Rebellion        noun, proper singular
# Major            PROPN        pobj         Major            noun, proper singular
# Snowball         PROPN        oprd         Snowball         noun, proper singular
# Napoleon         PROPN        conj         Napoleon         noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Berkshire        PROPN        amod         Berkshire        noun, proper singular
# Berkshire        PROPN        ROOT         Berkshire        noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        pobj         Napoleon         noun, proper singular
# Squealer         PROPN        oprd         Squealer         noun, proper singular
# Squealer         PROPN        pobj         Squealer         noun, proper singular
# white            PROPN        pobj         white            noun, proper singular
# Major            PROPN        poss         Major            noun, proper singular
# Animalism        PROPN        pobj         Animalism        noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Animalism        PROPN        pobj         Animalism        noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# Master           PROPN        pobj         Master           noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Rebellion        PROPN        nsubj        Rebellion        noun, proper singular
# Animalism        PROPN        pobj         Animalism        noun, proper singular
# Mollie           PROPN        pobj         Mollie           noun, proper singular
# Snowball         PROPN        dobj         Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Mollie           PROPN        dobj         Mollie           noun, proper singular
# Comrade          PROPN        nsubj        Comrade          noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# Moses            PROPN        pobj         Moses            noun, proper singular
# Moses            PROPN        nsubj        Moses            noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Sugarcandy       PROPN        compound     Sugarcandy       noun, proper singular
# Mountain         PROPN        appos        Mountain         noun, proper singular
# Moses            PROPN        nsubj        Moses            noun, proper singular
# Sugarcandy       PROPN        compound     Sugarcandy       noun, proper singular
# Mountain         PROPN        pobj         Mountain         noun, proper singular
# Sunday           PROPN        npadvmod     Sunday           noun, proper singular
# Moses            PROPN        dobj         Moses            noun, proper singular
# Sugarcandy       PROPN        compound     Sugarcandy       noun, proper singular
# Mountain         PROPN        pobj         Mountain         noun, proper singular
# Boxer            PROPN        conj         Boxer            noun, proper singular
# Clover           PROPN        conj         Clover           noun, proper singular
# Beasts           PROPN        pobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Rebellion        PROPN        nsubjpass    Rebellion        noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Windsor          PROPN        compound     Windsor          noun, proper singular
# Moses            PROPN        dobj         Moses            noun, proper singular
# June             PROPN        nsubj        June             noun, proper singular
# Midsummer        PROPN        poss         Midsummer        noun, proper singular
# Eve              PROPN        pobj         Eve              noun, proper singular
# Saturday         PROPN        attr         Saturday         noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Willingdon       PROPN        pobj         Willingdon       noun, proper singular
# Red              PROPN        compound     Red              noun, proper singular
# Lion             PROPN        pobj         Lion             noun, proper singular
# Sunday           PROPN        pobj         Sunday           noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# News             PROPN        pobj         News             noun, proper singular
# World            PROPN        pobj         World            noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Mrs.             PROPN        compound     Mrs.             noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Moses            PROPN        nsubj        Moses            noun, proper singular
# Jones            PROPN        dobj         Jones            noun, proper singular
# Rebellion        PROPN        nsubjpass    Rebellion        noun, proper singular
# Jones            PROPN        nsubjpass    Jones            noun, proper singular
# Manor            PROPN        compound     Manor            noun, proper singular
# Farm             PROPN        nsubj        Farm             noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubjpass    Jones            noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Beasts           PROPN        dobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        conj         Napoleon         noun, proper singular
# Brussels         PROPN        compound     Brussels         noun, proper singular
# Queen            PROPN        compound     Queen            noun, proper singular
# Victoria         PROPN        pobj         Victoria         noun, proper singular
# Mollie           PROPN        nsubjpass    Mollie           noun, proper singular
# Mrs.             PROPN        compound     Mrs.             noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        conj         Napoleon         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Snowball         PROPN        attr         Snowball         noun, proper singular
# MANOR            PROPN        compound     MANOR            noun, proper singular
# FARM             PROPN        dobj         FARM             noun, proper singular
# ANIMAL           PROPN        compound     ANIMAL           noun, proper singular
# FARM             PROPN        dobj         FARM             noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        conj         Napoleon         noun, proper singular
# Animalism        PROPN        pobj         Animalism        noun, proper singular
# Seven            PROPN        compound     Seven            noun, proper singular
# Commandments     PROPN        pobj         Commandments     noun, proper plural
# Seven            PROPN        compound     Seven            noun, proper singular
# Commandments     PROPN        nsubjpass    Commandments     noun, proper plural
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Squealer         PROPN        pobj         Squealer         noun, proper singular
# Commandments     PROPN        nsubjpass    Commandments     noun, proper plural
# S                PROPN        pobj         S                noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Commandments     PROPN        dobj         Commandments     noun, proper plural
# Snowball         PROPN        dobj         Snowball         noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Napoleon         PROPN        dobj         Napoleon         noun, proper singular
# Comrade          PROPN        compound     Comrade          noun, proper singular
# S                PROPN        compound     S                noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Clover           PROPN        conj         Clover           noun, proper singular
# Gee              PROPN        nmod         Gee              noun, proper singular
# Jones            PROPN        dobj         Jones            noun, proper singular
# Boxer            PROPN        conj         Boxer            noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Mollie           PROPN        dep          Mollie           noun, proper singular
# Old              PROPN        compound     Old              noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# Rebellion        PROPN        pobj         Rebellion        noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Rebellion        PROPN        pobj         Rebellion        noun, proper singular
# Jones            PROPN        nsubjpass    Jones            noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Mrs.             PROPN        compound     Mrs.             noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# Sunday           PROPN        compound     Sunday           noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# England          PROPN        pobj         England          noun, proper singular
# Republic         PROPN        dobj         Republic         noun, proper singular
# Animals          PROPN        pobj         Animals          noun, proper plural
# Meeting          PROPN        pobj         Meeting          noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        conj         Napoleon         noun, proper singular
# Meeting          PROPN        nsubj        Meeting          noun, proper singular
# Beasts           PROPN        pobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Committees       PROPN        oprd         Committees       noun, proper plural
# Egg              PROPN        compound     Egg              noun, proper singular
# Production       PROPN        compound     Production       noun, proper singular
# Committee        PROPN        dobj         Committee        noun, proper singular
# Clean            PROPN        compound     Clean            noun, proper singular
# Tails            PROPN        compound     Tails            noun, proper plural
# League           PROPN        appos        League           noun, proper singular
# Wild             PROPN        compound     Wild             noun, proper singular
# Comrades         PROPN        poss         Comrades         noun, proper plural
# Re-              PROPN        compound     Re-              noun, proper singular
# education        PROPN        compound     education        noun, proper singular
# Committee        PROPN        dobj         Committee        noun, proper singular
# Whiter           PROPN        compound     Whiter           noun, proper singular
# Wool             PROPN        compound     Wool             noun, proper singular
# Movement         PROPN        dobj         Movement         noun, proper singular
# Re-              PROPN        compound     Re-              noun, proper singular
# education        PROPN        compound     education        noun, proper singular
# Committee        PROPN        dobj         Committee        noun, proper singular
# sparro           PROPN        nsubj        sparro           noun, proper singular
# w                PROPN        appos        w                noun, proper singular
# Seven            PROPN        compound     Seven            noun, proper singular
# Commandments     PROPN        pobj         Commandments     noun, proper plural
# Muriel           PROPN        nsubj        Muriel           noun, proper singular
# goat             PROPN        appos        goat             noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# D.               PROPN        compound     D.               noun, proper singular
# C                PROPN        conj         C                noun, proper singular
# D                PROPN        appos        D                noun, proper singular
# E                PROPN        dobj         E                noun, proper singular
# F                PROPN        appos        F                noun, proper singular
# G                PROPN        conj         G                noun, proper singular
# D.               PROPN        npadvmod     D.               noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# stupider         PROPN        compound     stupider         noun, proper singular
# Seven            PROPN        compound     Seven            noun, proper singular
# Commandments     PROPN        dobj         Commandments     noun, proper plural
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Seven            PROPN        nummod       Seven            noun, proper singular
# Commandments     PROPN        nsubjpass    Commandments     noun, proper plural
# Animalism        PROPN        pobj         Animalism        noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Man              PROPN        pobj         Man              noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Seven            PROPN        compound     Seven            noun, proper singular
# Commandments     PROPN        pobj         Commandments     noun, proper plural
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Jessie           PROPN        nsubj        Jessie           noun, proper singular
# Bluebell         PROPN        conj         Bluebell         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        appos        Snowball         noun, proper singular
# Napoleon         PROPN        conj         Napoleon         noun, proper singular
# Squealer         PROPN        nsubjpass    Squealer         noun, proper singular
# Science          PROPN        pobj         Science          noun, proper singular
# d                PROPN        compound     d                noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Squealer         PROPN        dobj         Squealer         noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        conj         Napoleon         noun, proper singular
# Rebellion        PROPN        pobj         Rebellion        noun, proper singular
# Beasts           PROPN        pobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Red              PROPN        compound     Red              noun, proper singular
# Lion             PROPN        pobj         Lion             noun, proper singular
# Willingdon       PROPN        pobj         Willingdon       noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        dobj         Farm             noun, proper singular
# Foxwood          PROPN        oprd         Foxwood          noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        appos        Pilkington       noun, proper singular
# Pinchfield       PROPN        oprd         Pinchfield       noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Frederick        PROPN        attr         Frederick        noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Manor            PROPN        compound     Manor            noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Manor            PROPN        compound     Manor            noun, proper singular
# Farm             PROPN        oprd         Farm             noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Frederick        PROPN        nsubj        Frederick        noun, proper singular
# Pilkington       PROPN        conj         Pilkington       noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# -hot             PROPN        nmod         -hot             noun, proper singular
# Nature           PROPN        pobj         Nature           noun, proper singular
# Frederick        PROPN        conj         Frederick        noun, proper singular
# Pilkington       PROPN        conj         Pilkington       noun, proper singular
# cow              PROPN        compound     cow              noun, proper singular
# Beasts           PROPN        pobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# October          PROPN        pobj         October          noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Foxwood          PROPN        pobj         Foxwood          noun, proper singular
# Pinchfield       PROPN        conj         Pinchfield       noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Julius           PROPN        compound     Julius           noun, proper singular
# Caesar           PROPN        poss         Caesar           noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# geese            PROPN        nsubj        geese            noun, proper singular
# geese            PROPN        dobj         geese            noun, proper plural
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Muriel           PROPN        nsubj        Muriel           noun, proper singular
# Benjamin         PROPN        conj         Benjamin         noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Jones            PROPN        nsubjpass    Jones            noun, proper singular
# Boxer            PROPN        attr         Boxer            noun, proper singular
# Foxwood          PROPN        pobj         Foxwood          noun, proper singular
# geese            PROPN        pobj         geese            noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Snowball         PROPN        dobj         Snowball         noun, proper singular
# Boxer            PROPN        dobj         Boxer            noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# Beasts           PROPN        nsubjpass    Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Hero             PROPN        appos        Hero             noun, proper singular
# Class            PROPN        appos        Class            noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Boxer            PROPN        conj         Boxer            noun, proper singular
# Sundays          PROPN        pobj         Sundays          noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Hero             PROPN        attr         Hero             noun, proper singular
# Second           PROPN        compound     Second           noun, proper singular
# Class            PROPN        appos        Class            noun, proper singular
# Battle           PROPN        oprd         Battle           noun, proper singular
# Cowshed          PROPN        pobj         Cowshed          noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# October          PROPN        pobj         October          noun, proper singular
# Battle           PROPN        pobj         Battle           noun, proper singular
# Cowshed          PROPN        pobj         Cowshed          noun, proper singular
# Midsummer        PROPN        compound     Midsummer        noun, proper singular
# Day              PROPN        pobj         Day              noun, proper singular
# Rebellion        PROPN        pobj         Rebellion        noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# Clover           PROPN        nsubj        Clover           noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        dobj         Farm             noun, proper singular
# Foxwood          PROPN        pobj         Foxwood          noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        poss         Pilkington       noun, proper singular
# Mollie           PROPN        npadvmod     Mollie           noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# Mollie           PROPN        ROOT         Mollie           noun, proper singular
# Mollie           PROPN        dobj         Mollie           noun, proper singular
# Clover           PROPN        dobj         Clover           noun, proper singular
# Clover           PROPN        dobj         Clover           noun, proper singular
# Mollie           PROPN        poss         Mollie           noun, proper singular
# Mollie           PROPN        nsubj        Mollie           noun, proper singular
# Willingdon       PROPN        pobj         Willingdon       noun, proper singular
# Mollie           PROPN        dobj         Mollie           noun, proper singular
# January          PROPN        pobj         January          noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Napoleon         PROPN        conj         Napoleon         noun, proper singular
# Meetings         PROPN        pobj         Meetings         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Farmer           PROPN        nmod         Farmer           noun, proper singular
# Stock            PROPN        compound     Stock            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# House            PROPN        pobj         House            noun, proper singular
# Bricklayer       PROPN        appos        Bricklayer       noun, proper singular
# Electricity      PROPN        conj         Electricity      noun, proper singular
# Beginners        PROPN        pobj         Beginners        noun, proper plural
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Napoleon         PROPN        pobj         Napoleon         noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# Windmill         PROPN        nsubj        Windmill         noun, proper singular
# Battle           PROPN        pobj         Battle           noun, proper singular
# Cowshed          PROPN        pobj         Cowshed          noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        dobj         Jones            noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        conj         Napoleon         noun, proper singular
# Napoleon         PROPN        pobj         Napoleon         noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Napoleon         PROPN        pobj         Napoleon         noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Sunday           PROPN        pobj         Sunday           noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Napoleon         PROPN        pobj         Napoleon         noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Major            PROPN        nsubj        Major            noun, proper singular
# Sunday           PROPN        compound     Sunday           noun, proper singular
# Sunday           PROPN        compound     Sunday           noun, proper singular
# Beasts           PROPN        dobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Boxer            PROPN        nsubjpass    Boxer            noun, proper singular
# suddenl          PROPN        compound     suddenl          noun, proper singular
# y                PROPN        npadvmod     y                noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Squealer         PROPN        nsubjpass    Squealer         noun, proper singular
# Comrade          PROPN        compound     Comrade          noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Comrade          PROPN        compound     Comrade          noun, proper singular
# Napoleon         PROPN        pobj         Napoleon         noun, proper singular
# Snowball         PROPN        dobj         Snowball         noun, proper singular
# Snowball         PROPN        appos        Snowball         noun, proper singular
# Battle           PROPN        pobj         Battle           noun, proper singular
# Cowshed          PROPN        pobj         Cowshed          noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# Battle           PROPN        pobj         Battle           noun, proper singular
# Cowshed          PROPN        pobj         Cowshed          noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Jones            PROPN        dobj         Jones            noun, proper singular
# Sunday           PROPN        compound     Sunday           noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Comrade          PROPN        compound     Comrade          noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Sunday           PROPN        compound     Sunday           noun, proper singular
# Major            PROPN        pobj         Major            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Squealer         PROPN        pobj         Squealer         noun, proper singular
# Minimus          PROPN        oprd         Minimus          noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Beasts           PROPN        pobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Sunday           PROPN        pobj         Sunday           noun, proper singular
# Snowball         PROPN        poss         Snowball         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# Napoleon         PROPN        nsubjpass    Napoleon         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        poss         Napoleon         noun, proper singular
# Napoleon         PROPN        poss         Napoleon         noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# Comrade          PROPN        compound     Comrade          noun, proper singular
# Napoleon         PROPN        poss         Napoleon         noun, proper singular
# Snowball         PROPN        pobj         Snowball         noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# Tactics          PROPN        conj         Tactics          noun, proper singular
# merry            PROPN        compound     merry            noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# August           PROPN        compound     August           noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Sunday           PROPN        compound     Sunday           noun, proper singular
# Muriel           PROPN        nsubj        Muriel           noun, proper singular
# Benjamin         PROPN        conj         Benjamin         noun, proper singular
# Boxer            PROPN        pobj         Boxer            noun, proper singular
# Boxer            PROPN        attr         Boxer            noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# 23there          PROPN        nsubj        23there          noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Sunday           PROPN        compound     Sunday           noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        nsubj        Farm             noun, proper singular
# Willingdon       PROPN        pobj         Willingdon       noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Meeting          PROPN        pobj         Meeting          noun, proper singular
# Jones            PROPN        nsubjpass    Jones            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Meetings         PROPN        dobj         Meetings         noun, proper plural
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Whymper          PROPN        nsubj        Whymper          noun, proper singular
# Willingdon       PROPN        pobj         Willingdon       noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Monday           PROPN        compound     Monday           noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        nsubj        Farm             noun, proper singular
# Beasts           PROPN        pobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# ...
# Muriel           PROPN        nsubj        Muriel           noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# Alfred           PROPN        compound     Alfred           noun, proper singular
# Simmonds         PROPN        appos        Simmonds         noun, proper singular
# Horse            PROPN        compound     Horse            noun, proper singular
# Slaughterer      PROPN        conj         Slaughterer      noun, proper singular
# Glue             PROPN        compound     Glue             noun, proper singular
# Boiler           PROPN        conj         Boiler           noun, proper singular
# Willingdon       PROPN        npadvmod     Willingdon       noun, proper singular
# Hides            PROPN        pobj         Hides            noun, proper singular
# Bone             PROPN        compound     Bone             noun, proper singular
# Meal             PROPN        conj         Meal             noun, proper singular
# Kennels          PROPN        nsubj        Kennels          noun, proper singular
# Boxer            PROPN        dobj         Boxer            noun, proper singular
# van              PROPN        nsubj        van              noun, proper singular
# van              PROPN        nsubj        van              noun, proper singular
# Boxer            PROPN        ROOT         Boxer            noun, proper singular
# Boxer            PROPN        nmod         Boxer            noun, proper singular
# Boxer            PROPN        ROOT         Boxer            noun, proper singular
# Boxer            PROPN        ROOT         Boxer            noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# white            PROPN        compound     white            noun, proper singular
# van              PROPN        pobj         van              noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Clover           PROPN        dobj         Clover           noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Boxer            PROPN        npadvmod     Boxer            noun, proper singular
# Boxer            PROPN        nsubj        Boxer            noun, proper singular
# Clover           PROPN        nsubj        Clover           noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# van              PROPN        dobj         van              noun, proper singular
# van              PROPN        dobj         van              noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# van              PROPN        nsubj        van              noun, proper singular
# Boxer            PROPN        nsubjpass    Boxer            noun, proper singular
# Willingdon       PROPN        pobj         Willingdon       noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# Rebellion        PROPN        pobj         Rebellion        noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        nsubj        Farm             noun, proper singular
# Comrade          PROPN        compound     Comrade          noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Squealer         PROPN        poss         Squealer         noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# Boxer            PROPN        dobj         Boxer            noun, proper singular
# Horse            PROPN        compound     Horse            noun, proper singular
# Slaughterer      PROPN        oprd         Slaughterer      noun, proper singular
# Boxer            PROPN        nsubjpass    Boxer            noun, proper singular
# knacker          PROPN        pobj         knacker          noun, proper singular
# Squealer         PROPN        attr         Squealer         noun, proper singular
# Leader           PROPN        dobj         Leader           noun, proper singular
# Comrade          PROPN        compound     Comrade          noun, proper singular
# Napoleon         PROPN        appos        Napoleon         noun, proper singular
# van              PROPN        nsubj        van              noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Sunday           PROPN        compound     Sunday           noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# Comrade          PROPN        compound     Comrade          noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Willingdon       PROPN        pobj         Willingdon       noun, proper singular
# whisky           PROPN        pobj         whisky           noun, proper singular
# Years            PROPN        nsubj        Years            noun, proper plural
# Rebellion        PROPN        pobj         Rebellion        noun, proper singular
# Clover           PROPN        pobj         Clover           noun, proper singular
# Benjamin         PROPN        conj         Benjamin         noun, proper singular
# Moses            PROPN        conj         Moses            noun, proper singular
# Muriel           PROPN        nsubj        Muriel           noun, proper singular
# Bluebell         PROPN        nsubj        Bluebell         noun, proper singular
# Jessie           PROPN        conj         Jessie           noun, proper singular
# Pincher          PROPN        conj         Pincher          noun, proper singular
# Jones            PROPN        nsubj        Jones            noun, proper singular
# Snowball         PROPN        nsubjpass    Snowball         noun, proper singular
# Boxer            PROPN        nsubjpass    Boxer            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# Boxer            PROPN        poss         Boxer            noun, proper singular
# Rebellion        PROPN        nsubj        Rebellion        noun, proper singular
# Clover           PROPN        pobj         Clover           noun, proper singular
# B.               PROPN        npadvmod     B.               noun, proper singular
# Rebellion        PROPN        pobj         Rebellion        noun, proper singular
# Animalism        PROPN        pobj         Animalism        noun, proper singular
# Clover           PROPN        pobj         Clover           noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        pobj         Pilkington       noun, proper singular
# Whymper          PROPN        nsubj        Whymper          noun, proper singular
# Snowball         PROPN        nsubj        Snowball         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Animalism        PROPN        pobj         Animalism        noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# Rebellion        PROPN        pobj         Rebellion        noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Squealer         PROPN        poss         Squealer         noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Jones            PROPN        pobj         Jones            noun, proper singular
# Seven            PROPN        compound     Seven            noun, proper singular
# Commandments     PROPN        pobj         Commandments     noun, proper plural
# Republic         PROPN        nsubjpass    Republic         noun, proper singular
# Animals          PROPN        pobj         Animals          noun, proper plural
# Major            PROPN        nsubj        Major            noun, proper singular
# England          PROPN        pobj         England          noun, proper singular
# Beasts           PROPN        pobj         Beasts           noun, proper plural
# England          PROPN        pobj         England          noun, proper singular
# Master           PROPN        appos        Master           noun, proper singular
# Squealer         PROPN        nsubj        Squealer         noun, proper singular
# Squealer         PROPN        poss         Squealer         noun, proper singular
# Clover           PROPN        poss         Clover           noun, proper singular
# Clover           PROPN        nsubj        Clover           noun, proper singular
# Squealer         PROPN        attr         Squealer         noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# Seven            PROPN        compound     Seven            noun, proper singular
# Commandments     PROPN        nsubjpass    Commandments     noun, proper plural
# Seven            PROPN        compound     Seven            noun, proper singular
# Benjamin         PROPN        dobj         Benjamin         noun, proper singular
# Benjamin         PROPN        nsubj        Benjamin         noun, proper singular
# John             PROPN        compound     John             noun, proper singular
# Bull             PROPN        pobj         Bull             noun, proper singular
# Tit              PROPN        compound     Tit              noun, proper singular
# Bits             PROPN        conj         Bits             noun, proper singular
# Daily            PROPN        compound     Daily            noun, proper singular
# Mirror           PROPN        conj         Mirror           noun, proper singular
# Napoleon         PROPN        nsubjpass    Napoleon         noun, proper singular
# 49mouth          PROPN        pobj         49mouth          noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Jones            PROPN        poss         Jones            noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Mrs.             PROPN        compound     Mrs.             noun, proper singular
# Jones            PROPN        nsubjpass    Jones            noun, proper singular
# Sundays          PROPN        pobj         Sundays          noun, proper singular
# Clover           PROPN        nsubj        Clover           noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        nsubj        Pilkington       noun, proper singular
# Foxwood          PROPN        pobj         Foxwood          noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        dobj         Farm             noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        nsubj        Pilkington       noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        nsubj        Pilkington       noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        nsubj        Pilkington       noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        pobj         Pilkington       noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Napoleon         PROPN        poss         Napoleon         noun, proper singular
# Comrade          PROPN        pobj         Comrade          noun, proper singular
# Sunday           PROPN        compound     Sunday           noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        poss         Pilkington       noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        nsubj        Pilkington       noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Napoleon         PROPN        appos        Napoleon         noun, proper singular
# Animal           PROPN        compound     Animal           noun, proper singular
# Farm             PROPN        appos        Farm             noun, proper singular
# Henceforward     PROPN        nsubj        Henceforward     noun, proper singular
# Manor            PROPN        compound     Manor            noun, proper singular
# Farm"—which      PROPN        pobj         Farm"—which      noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Manor            PROPN        compound     Manor            noun, proper singular
# Farm             PROPN        pobj         Farm             noun, proper singular
# Clover           PROPN        poss         Clover           noun, proper singular
# Napoleon         PROPN        nsubj        Napoleon         noun, proper singular
# Mr.              PROPN        compound     Mr.              noun, proper singular
# Pilkington       PROPN        conj         Pilkington       noun, proper singular
# END              PROPN        compound     END              noun, proper singular
# Julie            PROPN        attr         Julie            noun, proper singular
# Global           PROPN        compound     Global           noun, proper singular
# Grey             PROPN        dobj         Grey             noun, proper singular
# Amazon           PROPN        pobj         Amazon           noun, proper singular

# %%
propns
# Out:
# {'Napoleon': 168,
#  'Snowball': 128,
#  'Boxer': 96,
#  'Jones': 83,
#  'Squealer': 57,
#  'Farm': 52,
#  'Animal': 50,
#  'Mr.': 44,
#  'Frederick': 34,
#  'Clover': 33,
#  'Benjamin': 31,
#  'England': 28,
#  'Pilkington': 28,
#  'Comrade': 26,
#  'Mollie': 20,
#  'Sunday': 20,
#  'Major': 19,
#  'Rebellion': 18,
#  'Beasts': 18,
#  'Whymper': 16,
#  'Foxwood': 15,
#  'Seven': 14,
#  'Commandments': 14,
#  'Muriel': 13,
#  'Battle': 13,
#  'Willingdon': 12,
#  'Man': 12,
#  'Pinchfield': 11,
#  'Moses': 10,
#  'Cowshed': 10,
#  'Animalism': 8,
#  'van': 8,
#  'Manor': 7,
#  'Hero': 7,
#  'Leader': 7,
#  'Sugarcandy': 6,
#  'Mountain': 6,
#  'Class': 6,
#  'Mrs.': 5,
#  'w': 5,
#  'geese': 5,
#  'C': 5,
#  'd': 5,
#  'Commandment': 5,
#  'Bluebell': 4,
#  'Jessie': 4,
#  'al': 4,
#  'white': 3,
#  'S': 3,
#  'Republic': 3,
#  'Animals': 3,
#  'Meeting': 3,
#  'Committee': 3,
#  'Sundays': 3,
#  'January': 3,
#  'Meetings': 3,
#  'y': 3,
#  'Minimus': 3,
#  'February': 3,
#  'f': 3,
#  'Pincher': 2,
#  'goat': 2,
#  'Old': 2,
#  'Ireland': 2,
#  'Hearken': 2,
#  'March': 2,
#  'Berkshire': 2,
#  'Master': 2,
#  'Midsummer': 2,
#  'Red': 2,
#  'Lion': 2,
#  'FARM': 2,
#  'Re-': 2,
#  'education': 2,
#  'D.': 2,
#  'October': 2,
#  'Second': 2,
#  'Windmill': 2,
#  'Monday': 2,
#  'Fourth': 2,
#  'Sixth': 2,
#  'sh': 2,
#  'k': 2,
#  'anim': 2,
#  'm': 2,
#  'Crown': 2,
#  'Derby': 2,
#  'big': 2,
#  'Demonstration': 2,
#  'Horse': 2,
#  'Slaughterer': 2,
#  'Word': 1,
#  'Middle': 1,
#  'White': 1,
#  'Beauty': 1,
#  'God': 1,
#  '.': 1,
#  'lord': 1,
#  'cruel': 1,
#  'Clementine': 1,
#  'La': 1,
#  'Cucuracha': 1,
#  'Tyrant': 1,
#  'Cruel': 1,
#  'hay': 1,
#  'Purer': 1,
#  'Windsor': 1,
#  'June': 1,
#  'Eve': 1,
#  'Saturday': 1,
#  'News': 1,
#  'World': 1,
#  'Brussels': 1,
#  'Queen': 1,
#  'Victoria': 1,
#  'MANOR': 1,
#  'ANIMAL': 1,
#  'Gee': 1,
#  'Committees': 1,
#  'Egg': 1,
#  'Production': 1,
#  'Clean': 1,
#  'Tails': 1,
#  'League': 1,
#  'Wild': 1,
#  'Comrades': 1,
#  'Whiter': 1,
#  'Wool': 1,
#  'Movement': 1,
#  'sparro': 1,
#  'D': 1,
#  'E': 1,
#  'F': 1,
#  'G': 1,
#  'stupider': 1,
#  'Science': 1,
#  '-hot': 1,
#  'Nature': 1,
#  'cow': 1,
#  'Julius': 1,
#  'Caesar': 1,
#  'Day': 1,
#  'Farmer': 1,
#  'Stock': 1,
#  'House': 1,
#  'Bricklayer': 1,
#  'Electricity': 1,
#  'Beginners': 1,
#  'suddenl': 1,
#  'Tactics': 1,
#  'merry': 1,
#  'August': 1,
#  '23there': 1,
#  'November': 1,
#  '26Second': 1,
#  'Black': 1,
#  'Minorca': 1,
#  '29said': 1,
#  'Humanity': 1,
#  '-air': 1,
#  'whereat': 1,
#  'l': 1,
#  'hen': 1,
#  'b': 1,
#  'ne': 1,
#  'hich': 1,
#  'h': 1,
#  'B': 1,
#  'sa': 1,
#  'M': 1,
#  'uriel': 1,
#  't': 1,
#  'sl': 1,
#  'o': 1,
#  'Father': 1,
#  'Terror': 1,
#  'Mankind': 1,
#  'Protector': 1,
#  'Sheep': 1,
#  'Ducklings': 1,
#  's.': 1,
#  'Lord': 1,
#  'Fire': 1,
#  'Calm': 1,
#  'Sleeps': 1,
#  'Thou': 1,
#  'Ere': 1,
#  'Pinkeye': 1,
#  'dynamos': 1,
#  'Mill': 1,
#  'Tomorrow': 1,
#  '36All': 1,
#  'china': 1,
#  'Courage': 1,
#  'Terrified': 1,
#  'Green': 1,
#  'Banner': 1,
#  'Fifth': 1,
#  'December': 1,
#  'march': 1,
#  'Spontaneous': 1,
#  'April': 1,
#  'President': 1,
#  'unanim': 1,
#  'ee': 1,
#  'Good': 1,
#  'Fools': 1,
#  'Alfred': 1,
#  'Simmonds': 1,
#  'Glue': 1,
#  'Boiler': 1,
#  'Hides': 1,
#  'Bone': 1,
#  'Meal': 1,
#  'Kennels': 1,
#  'knacker': 1,
#  'whisky': 1,
#  'Years': 1,
#  'B.': 1,
#  'John': 1,
#  'Bull': 1,
#  'Tit': 1,
#  'Bits': 1,
#  'Daily': 1,
#  'Mirror': 1,
#  '49mouth': 1,
#  'Henceforward': 1,
#  'Farm"—which': 1,
#  'END': 1,
#  'Julie': 1,
#  'Global': 1,
#  'Grey': 1,
#  'Amazon': 1}

# %%
propn_df = pd.DataFrame({'word':propns.keys(), 'frequency':propns.values()})
propn_df
# Out:
#          word  frequency
# 0    Napoleon        168
# 1    Snowball        128
# 2       Boxer         96
# 3       Jones         83
# 4    Squealer         57
# ..        ...        ...
# 228       END          1
# 229     Julie          1
# 230    Global          1
# 231      Grey          1
# 232    Amazon          1
#
# [233 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data=propn_df.iloc[:20], x='word', y='frequency');

# %%
wordcloud = WordCloud(width=1200, height=800, background_color='#FFFFFF').generate_from_frequencies(propns)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud);
